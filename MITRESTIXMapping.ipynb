# %%
# List of TTPs to check
ttp_list = [
    'T1194', 'T1088', 'T1346', 'T1065', 'T1500', 'T1311', 'T1432', 'T1002', 'T1043', 
    'T1433', 'T1329', 'T1312', 'T1179', 'T1517', 'T1093', 'T0872', 'T1079', 'T1009', 
    'T0840', 'T1099', 'T1053.004', 'T1045', 'T1426', 'T1100', 'T1512', 'T1022', 'T1438', 
    'T1420', 'T1532', 'T1508', 'T0871', 'T1533', 'T1476', 'T1077', 'T1191', 'T1402', 
    'T1341', 'T1024', 'T1117', 'T1047.001', 'T1345', 'T1004', 'T1497.004', 'T1064', 
    'T1247', 'T1089', 'T1249', 'T1086', 'T1260', 'T1061', 'T0853', 'T1143', 'T0847', 
    'T1122', 'T1084', 'T1351', 'T1268', 'T0807', 'T1023', 'T1107', 'T1444', 'T1660', 
    'T0831', 'T0809', 'T1081', 'T1101', 'T1437', 'T1076', 'T1503.004', 'T1035', 'T1412', 
    'T1308', 'T1328', 'T1013', 'T1031', 'T1060', 'T1193', 'T1085', 'T0855', 'T1513', 
    'T1116', 'T1168', 'T1094', 'T1447', 'T1138', 'T1063', 'T1183', 'T1032', 'T1158', 
    'T1418', 'T1502', 'T1337', 'T1145', 'T1575', 'T1347', 'T1503.003', 'T1503', 'T1429', 
    'T1544', 'T1050', 'T1108', 'T1073', 'T1015', 'T1038', 'T1192', 'T1362', 'T1066'
]

# %%
len(ttp_list)
# Out:
# 107

# %%
# List of STIX file versions with raw URLs for each version
enterprise_versions = [
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-1.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-2.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-3.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-4.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-5.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-5.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-5.2.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-6.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-6.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-6.2.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-6.3.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-7.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-7.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-7.2.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-8.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-8.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-8.2.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-9.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-10.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-10.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-11.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-11.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-11.2.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-11.3.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-12.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-12.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-13.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-13.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-14.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-14.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-15.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-15.1.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-16.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/enterprise-attack/enterprise-attack-16.1.json"
]

# %%
len(enterprise_versions)
# Out:
# 34

# %%
ics_versions = [
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-8.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-8.1.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-8.2.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-9.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-10.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-10.1.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-11.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-11.1.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-11.2.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-11.3.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-12.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-12.1.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-13.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-13.1.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-14.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-14.1.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-15.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-15.1.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-16.0.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/ics-attack/ics-attack-16.1.json"    
]

# %%
len(ics_versions)
# Out:
# 20

# %%
mobile_versions = [
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-1.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-2.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-3.0.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-4.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-5.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-5.1.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-5.2.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-6.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-6.1.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-6.2.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-6.3.json", 
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-7.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-7.1.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-7.2.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-8.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-8.1.json",   
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-8.2.json",
    "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-9.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-10.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-10.1.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-11.0-beta.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-11.1-beta.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-11.2-beta.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-11.3.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-12.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-12.1.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-13.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-13.1.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-14.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-14.1.json",
      "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-15.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-15.1.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-16.0.json",
     "https://raw.githubusercontent.com/mitre-attack/attack-stix-data/master/mobile-attack/mobile-attack-16.1.json"
]

# %%
len(mobile_versions)
# Out:
# 34

# %%
import requests

def get_stix_data(url):
    """
    Fetches STIX data for a given MITRE ATT&CK version from a URL.

    Parameters
    ----------
    url : str
        URL to fetch the STIX data.

    Returns
    -------
    dict
        Parsed STIX data as JSON.
    """
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise ValueError(f"Error fetching data from {url}. Status code: {response.status_code}")

def track_ttps_across_versions(domain_versions):
    """
    Tracks all TTPs across all ATT&CK versions, including their introduction, deprecation, revocation, and domain.

    Parameters
    ----------
    domain_versions : list of tuples
        List of tuples containing (domain, url) pairs for the STIX data.

    Returns
    -------
    dict
        Dictionary containing TTP metadata.
    """
    ttp_map = {}

    for domain, url in domain_versions:
        # Extract version from the URL
        version = url.split("/")[-1].replace(f"{domain}-attack-", "").replace(".json", "")
        
        try:
            print(f"Fetching data for {domain} version {version}...")
            stix_data = get_stix_data(url)
            #print(stix_data)
        except ValueError as e:
            print(e)
            continue

        # Iterate over STIX objects to find attack patterns
        for obj in stix_data.get('objects', []):
            if obj.get('type') == 'attack-pattern':
                #print(obj)
                ttp_id = None

                for ref in obj.get('external_references', []):
                    if ref.get('source_name') in ['mitre-attack', 'mitre-ics-attack', 'mitre-attack-mobile', 'mitre-mobile-attack']:
                        ttp_id = ref.get('external_id')
                        break

                if not ttp_id:
                    continue

                # If the TTP is already in the map, ensure the first appearance is the earliest one
                if ttp_id in ttp_map:
                    # Update first appearance if this version is earlier
                    if version < ttp_map[ttp_id]['first_appearance']:
                        ttp_map[ttp_id]['first_appearance'] = version
                else:
                    # Otherwise, add a new entry for the TTP
                    ttp_map[ttp_id] = {
                        'first_appearance': version,
                        'deprecated_version': None,
                        'revoked_version': None,
                        'domain': domain
                    }

                # Track deprecated version if not already set
                if obj.get('x_mitre_deprecated') and ttp_map[ttp_id]['deprecated_version'] is None:
                    ttp_map[ttp_id]['deprecated_version'] = version

                # Track revoked version, ensuring it captures the first instance
                if obj.get('revoked'):
                    if ttp_map[ttp_id]['revoked_version'] is None or version < ttp_map[ttp_id]['revoked_version']:
                        ttp_map[ttp_id]['revoked_version'] = version

    return ttp_map



# Combine all versions
all_versions = enterprise_versions + ics_versions + mobile_versions


def extract_domain_from_url(url):
    """
    Extracts the domain (e.g., 'ics-attack', 'mobile-attack') from the URL.

    Parameters
    ----------
    url : str
        The URL of the STIX data file.

    Returns
    -------
    str
        The domain extracted from the URL.
    """
    # Extract the part between 'master/' and the next '/'
    return url.split("/")[-2]

def prepare_domain_versions(url_list):
    """
    Prepares a list of (domain, URL) tuples from the list of URLs.

    Parameters
    ----------
    url_list : list
        List of URLs.

    Returns
    -------
    list
        List of tuples where each tuple contains (domain, URL).
    """
    return [(extract_domain_from_url(url), url) for url in url_list]

# Prepare the domain versions as tuples (domain, URL)
domain_versions = prepare_domain_versions(all_versions)

# Track the TTPs across all domains and versions
ttp_data = track_ttps_across_versions(domain_versions)

print(len(ttp_data))

deprecated_count = 0  # Count of TTPs with deprecated_version not None
revoked_count = 0  # Count of TTPs with revoked_version not None

# Iterate over the TTP data
for ttp, details in ttp_data.items():
    # Check for deprecated version not None
    if details['deprecated_version'] is not None:
        deprecated_count += 1
    # Check for revoked version not None
    if details['revoked_version'] is not None:
        revoked_count += 1

print(f"Count of TTPs with deprecated_version not None, i.e. total TTPs deprecated: {deprecated_count}")
print(f"Count of TTPs with revoked_version not None, i.e. total TTPs revoked: {revoked_count}")
# Output the results
# for ttp_id, info in ttp_data.items():
#     print(f"TTP ID: {ttp_id}")
#     print(f"  Domain: {info['domain']}")
#     print(f"  First Appearance: {info['first_appearance']}")
#     print(f"  Deprecated Version: {info['deprecated_version']}")
#     print(f"  Revoked Version: {info['revoked_version']}\n")
# Out:
# Fetching data for enterprise-attack version enterprise-attack-1.0...
# Fetching data for enterprise-attack version enterprise-attack-2.0...
# Fetching data for enterprise-attack version enterprise-attack-3.0...
# Fetching data for enterprise-attack version enterprise-attack-4.0...
# Fetching data for enterprise-attack version enterprise-attack-5.0...
# Fetching data for enterprise-attack version enterprise-attack-5.1...
# Fetching data for enterprise-attack version enterprise-attack-5.2...
# Fetching data for enterprise-attack version enterprise-attack-6.0...
# Fetching data for enterprise-attack version enterprise-attack-6.1...
# Fetching data for enterprise-attack version enterprise-attack-6.2...
# Fetching data for enterprise-attack version enterprise-attack-6.3...
# Fetching data for enterprise-attack version enterprise-attack-7.0...
# Fetching data for enterprise-attack version enterprise-attack-7.1...
# Fetching data for enterprise-attack version enterprise-attack-7.2...
# Fetching data for enterprise-attack version enterprise-attack-8.0...
# Fetching data for enterprise-attack version enterprise-attack-8.1...
# Fetching data for enterprise-attack version enterprise-attack-8.2...
# Fetching data for enterprise-attack version enterprise-attack-9.0...
# Fetching data for enterprise-attack version enterprise-attack-10.0...
# Fetching data for enterprise-attack version enterprise-attack-10.1...
# Fetching data for enterprise-attack version enterprise-attack-11.0...
# Fetching data for enterprise-attack version enterprise-attack-11.1...
# Fetching data for enterprise-attack version enterprise-attack-11.2...
# Fetching data for enterprise-attack version enterprise-attack-11.3...
# Fetching data for enterprise-attack version enterprise-attack-12.0...
# Fetching data for enterprise-attack version enterprise-attack-12.1...
# Fetching data for enterprise-attack version enterprise-attack-13.0...
# Fetching data for enterprise-attack version enterprise-attack-13.1...
# Fetching data for enterprise-attack version enterprise-attack-14.0...
# Fetching data for enterprise-attack version enterprise-attack-14.1...
# Fetching data for enterprise-attack version enterprise-attack-15.0...
# Fetching data for enterprise-attack version enterprise-attack-15.1...
# Fetching data for enterprise-attack version enterprise-attack-16.0...
# Fetching data for enterprise-attack version enterprise-attack-16.1...
# Fetching data for ics-attack version ics-attack-8.0...
# Fetching data for ics-attack version ics-attack-8.1...
# Fetching data for ics-attack version ics-attack-8.2...
# Fetching data for ics-attack version ics-attack-9.0...
# Fetching data for ics-attack version ics-attack-10.0...
# Fetching data for ics-attack version ics-attack-10.1...
# Fetching data for ics-attack version ics-attack-11.0...
# Fetching data for ics-attack version ics-attack-11.1...
# Fetching data for ics-attack version ics-attack-11.2...
# Fetching data for ics-attack version ics-attack-11.3...
# Fetching data for ics-attack version ics-attack-12.0...
# Fetching data for ics-attack version ics-attack-12.1...
# Fetching data for ics-attack version ics-attack-13.0...
# Fetching data for ics-attack version ics-attack-13.1...
# Fetching data for ics-attack version ics-attack-14.0...
# Fetching data for ics-attack version ics-attack-14.1...
# Fetching data for ics-attack version ics-attack-15.0...
# Fetching data for ics-attack version ics-attack-15.1...
# Fetching data for ics-attack version ics-attack-16.0...
# Fetching data for ics-attack version ics-attack-16.1...
# Fetching data for mobile-attack version mobile-attack-1.0...
# Fetching data for mobile-attack version mobile-attack-2.0...
# Fetching data for mobile-attack version mobile-attack-3.0...
# Fetching data for mobile-attack version mobile-attack-4.0...
# Fetching data for mobile-attack version mobile-attack-5.0...
# Fetching data for mobile-attack version mobile-attack-5.1...
# Fetching data for mobile-attack version mobile-attack-5.2...
# Fetching data for mobile-attack version mobile-attack-6.0...
# Fetching data for mobile-attack version mobile-attack-6.1...
# Fetching data for mobile-attack version mobile-attack-6.2...
# Fetching data for mobile-attack version mobile-attack-6.3...
# Fetching data for mobile-attack version mobile-attack-7.0...
# Fetching data for mobile-attack version mobile-attack-7.1...
# Fetching data for mobile-attack version mobile-attack-7.2...
# Fetching data for mobile-attack version mobile-attack-8.0...
# Fetching data for mobile-attack version mobile-attack-8.1...
# Fetching data for mobile-attack version mobile-attack-8.2...
# Fetching data for mobile-attack version mobile-attack-9.0...
# Fetching data for mobile-attack version mobile-attack-10.0...
# Fetching data for mobile-attack version mobile-attack-10.1...
# Fetching data for mobile-attack version mobile-attack-11.0-beta...
# Fetching data for mobile-attack version mobile-attack-11.1-beta...
# Fetching data for mobile-attack version mobile-attack-11.2-beta...
# Fetching data for mobile-attack version mobile-attack-11.3...
# Fetching data for mobile-attack version mobile-attack-12.0...
# Fetching data for mobile-attack version mobile-attack-12.1...
# Fetching data for mobile-attack version mobile-attack-13.0...
# Fetching data for mobile-attack version mobile-attack-13.1...
# Fetching data for mobile-attack version mobile-attack-14.0...
# Fetching data for mobile-attack version mobile-attack-14.1...
# Fetching data for mobile-attack version mobile-attack-15.0...
# Fetching data for mobile-attack version mobile-attack-15.1...
# Fetching data for mobile-attack version mobile-attack-16.0...
# Fetching data for mobile-attack version mobile-attack-16.1...
# 1158
# Count of TTPs with deprecated_version not None, i.e. total TTPs deprecated: 39
# Count of TTPs with revoked_version not None, i.e. total TTPs revoked: 184

# %%
def get_matching_ttps(ttp_data: dict, ttp_list: list) -> dict:
    """
    Matches TTPs from the ttp_list with their corresponding data in ttp_data.
    
    Parameters
    ----------
    ttp_data : dict
        Dictionary containing TTP data.
    ttp_list : list
        List of TTPs to match.

    Returns
    -------
    dict
        Dictionary of matched TTPs with their corresponding data from ttp_data.
    """
    # Initialize an empty dictionary to store matched TTPs
    matched_ttps = {}

    # Iterate over the TTPs in the list
    for ttp in ttp_list:
        if ttp in ttp_data:
            matched_ttps[ttp] = ttp_data[ttp]  # Add to the result if TTP exists in ttp_data

        else:
            matched_ttps[ttp] = "No information"

    return matched_ttps

# Example usage:
matched_result = get_matching_ttps(ttp_data, ttp_list)
print(len(matched_result))
# Output the result
for ttp, data in matched_result.items():
    print(f"{ttp}: {data}")
# Out:
# 107
# T1194: {'first_appearance': 'enterprise-attack-10.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1088: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1346: No information
# T1065: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1500: {'first_appearance': 'enterprise-attack-10.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1311: No information
# T1432: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': 'mobile-attack-11.0-beta', 'domain': 'mobile-attack'}
# T1002: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1043: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': 'enterprise-attack-7.0', 'revoked_version': None, 'domain': 'enterprise-attack'}
# T1433: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': 'mobile-attack-11.0-beta', 'domain': 'mobile-attack'}
# T1329: No information
# T1312: No information
# T1179: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1517: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1093: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T0872: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T1079: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1009: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T0840: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T1099: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1053.004: {'first_appearance': 'enterprise-attack-10.0', 'deprecated_version': 'enterprise-attack-10.0', 'revoked_version': None, 'domain': 'enterprise-attack'}
# T1045: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1426: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1100: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1512: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1022: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1438: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': 'mobile-attack-11.0-beta', 'domain': 'mobile-attack'}
# T1420: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1532: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1508: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': 'mobile-attack-11.0-beta', 'domain': 'mobile-attack'}
# T0871: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T1533: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1476: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': 'mobile-attack-11.0-beta', 'revoked_version': None, 'domain': 'mobile-attack'}
# T1077: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1191: {'first_appearance': 'enterprise-attack-10.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1402: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': 'mobile-attack-11.0-beta', 'domain': 'mobile-attack'}
# T1341: No information
# T1024: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1117: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1047.001: No information
# T1345: No information
# T1004: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1497.004: No information
# T1064: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': 'enterprise-attack-7.0', 'revoked_version': None, 'domain': 'enterprise-attack'}
# T1247: No information
# T1089: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1249: No information
# T1086: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1260: No information
# T1061: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': 'enterprise-attack-7.0', 'revoked_version': None, 'domain': 'enterprise-attack'}
# T0853: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T1143: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T0847: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T1122: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1084: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1351: No information
# T1268: No information
# T0807: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T1023: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1107: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1444: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': 'mobile-attack-11.0-beta', 'revoked_version': None, 'domain': 'mobile-attack'}
# T1660: {'first_appearance': 'mobile-attack-14.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T0831: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T0809: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T1081: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1101: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1437: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1076: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1503.004: No information
# T1035: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1412: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': 'mobile-attack-11.0-beta', 'domain': 'mobile-attack'}
# T1308: No information
# T1328: No information
# T1013: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1031: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1060: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1193: {'first_appearance': 'enterprise-attack-10.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1085: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T0855: {'first_appearance': 'ics-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'ics-attack'}
# T1513: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1116: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1168: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1094: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1447: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': 'mobile-attack-11.0-beta', 'domain': 'mobile-attack'}
# T1138: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1063: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1183: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1032: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1158: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1418: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1502: {'first_appearance': 'enterprise-attack-10.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1337: No information
# T1145: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1575: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1347: No information
# T1503.003: No information
# T1503: {'first_appearance': 'enterprise-attack-10.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1429: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1544: {'first_appearance': 'mobile-attack-10.0', 'deprecated_version': None, 'revoked_version': None, 'domain': 'mobile-attack'}
# T1050: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1108: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': 'enterprise-attack-7.0', 'revoked_version': None, 'domain': 'enterprise-attack'}
# T1073: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1015: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1038: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1192: {'first_appearance': 'enterprise-attack-10.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}
# T1362: No information
# T1066: {'first_appearance': 'enterprise-attack-1.0', 'deprecated_version': None, 'revoked_version': 'enterprise-attack-10.0', 'domain': 'enterprise-attack'}

# %%
def segregate_ttps(ttp_data: dict) -> dict:
    """
    Segregates TTPs by domain and counts how many are deprecated and/or revoked.
    
    Parameters
    ----------
    ttp_data : dict
        Dictionary containing TTP data.

    Returns
    -------
    dict
        Dictionary containing counts of TTPs by domain, deprecated status, and revoked status.
    """
    # Initialize counters for each domain
    domain_counts = {
        'mobile-attack': {'total': 0, 'deprecated': 0, 'revoked': 0},
        'enterprise-attack': {'total': 0, 'deprecated': 0, 'revoked': 0},
        'ics-attack': {'total': 0, 'deprecated': 0, 'revoked': 0}
    }

    # Iterate over the TTPs in the data
    for ttp, details in ttp_data.items():
        domain = details.get('domain')

        if domain in domain_counts:
            # Increment total count for this domain
            domain_counts[domain]['total'] += 1

            # Check for deprecated and revoked versions
            if details.get('deprecated_version') is not None:
                domain_counts[domain]['deprecated'] += 1

            if details.get('revoked_version') is not None:
                domain_counts[domain]['revoked'] += 1

    return domain_counts

# Example usage:
ttp_stats = segregate_ttps(matched_result)

# Output the segregation
for domain, stats in ttp_stats.items():
    print(f"{domain}:")
    print(f"  Total TTPs: {stats['total']}")
    print(f"  Deprecated TTPs: {stats['deprecated']}")
    print(f"  Revoked TTPs: {stats['revoked']}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[122], line 40
#      37     return domain_counts
#      39 # Example usage:
# ---> 40 ttp_stats = segregate_ttps(matched_result)
#      42 # Output the segregation
#      43 for domain, stats in ttp_stats.items():
#
# Cell In[122], line 24, in segregate_ttps(ttp_data)
#      22 # Iterate over the TTPs in the data
#      23 for ttp, details in ttp_data.items():
# ---> 24     domain = details.get('domain')
#      26     if domain in domain_counts:
#      27         # Increment total count for this domain
#      28         domain_counts[domain]['total'] += 1
#
# AttributeError: 'str' object has no attribute 'get'
