# %%
import os
import re
import json
from bs4 import BeautifulSoup
from collections import defaultdict
from collections import Counter

# %%
def get_download_files(folder_paths):
    """Recursively find .download files in given folders."""
    download_files = []
    for folder in folder_paths:
        for root, _, files in os.walk(folder):
            for file in files:
                if file.endswith('.download'):
                    download_files.append(os.path.join(root, file))
    return download_files

def extract_html_title(file_path):
    """Extract the <title> from HTML content. Return None if unreadable."""
    try:
        with open(file_path, 'r', encoding='utf-8') as f:
            soup = BeautifulSoup(f, 'html.parser')
        title_tag = soup.find('title')
        return title_tag.get_text(strip=True) if title_tag else ''
    except UnicodeDecodeError:
        return None
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return None


def normalize_title(title):
    """Normalize title text for comparison."""
    title = title.lower()
    title = re.sub(r'\s+', ' ', title)
    return title.strip()

def find_duplicate_titles(file_paths):
    """Build map of normalized title -> list of file paths."""
    title_map = defaultdict(list)
    skipped_files = []

    for path in file_paths:
        title = extract_html_title(path)
        if title is None:
            skipped_files.append(path)
            continue

        normalized = normalize_title(title)
        if normalized:
            title_map[normalized].append({
                'original_title': title,
                'file_path': path
            })

    duplicates = {title: items for title, items in title_map.items() if len(items) > 1}
    return duplicates, skipped_files


def write_json_report(duplicates, output_file='duplicate_titles_report.json'):
    """Write duplicate report to a JSON file."""
    with open(output_file, 'w', encoding='utf-8') as f:
        json.dump(duplicates, f, indent=2, ensure_ascii=False)
    
    print(f"\nJSON report saved to {output_file}")

def main():

    folder_paths = [
        r'C:\Users\ricewater\Documents\CTIDownloads\malpedia_20220718\malpedia_20220718\documents',
        r'C:\Users\ricewater\Documents\CTIDownloads\20241204_malpedia_downloads\20241204_malpedia_downloads',
        #r'C:\Users\ricewater\Documents\CTIDownloads\downloads\downloads\20241008_downloads'
    ]

    download_files = get_download_files(folder_paths)
    print(f"Found {len(download_files)} .download files...")

    duplicates, skipped = find_duplicate_titles(download_files)

    print(f"\n Parsed HTML files: {len(download_files) - len(skipped)}")
    print(f" Skipped non-HTML/binary files: {len(skipped)}")
    print(f" Duplicate title groups found: {len(duplicates)}")

    write_json_report(duplicates)

    # Optional: log skipped files
    with open('skipped_non_html_files.json', 'w', encoding='utf-8') as f:
        json.dump(skipped, f, indent=2)
    print("Skipped files saved to skipped_non_html_files.json")



if __name__ == '__main__':
    main()
# Out:
# Found 14983 .download files...
#
#  Parsed HTML files: 13879
#  Skipped non-HTML/binary files: 1104
#  Duplicate title groups found: 362
#
# JSON report saved to duplicate_titles_report.json
# Skipped files saved to skipped_non_html_files.json

# %%
## For MITRE dataset

Found 920 .download files...

 Parsed HTML files: 782
 Skipped non-HTML/binary files: 138
 Duplicate title groups found: 122

##For Malpedia dataset (part of it)

Found 3620 .download files...

 Parsed HTML files: 3428
 Skipped non-HTML/binary files: 192
 Duplicate title groups found: 94


##For Malpedia Dataset complete
Found 14983 .download files...

 Parsed HTML files: 13879
 Skipped non-HTML/binary files: 1104
 Duplicate title groups found: 362
# Out:
#   Cell In[19], line 3
#     Found 920 .download files...
#           ^
# SyntaxError: invalid syntax

# %%
def read_bib_file(file_path):
    """
    Reads the content of a .bib file.

    Parameters
    ----------
    file_path : str
        Path to the .bib file.

    Returns
    -------
    str
        Contents of the file as a single string.
    """
    with open(file_path, 'r', encoding='utf-8') as f:
        return f.read()

def find_duplicate_titles(bib_text):
    """
    Identifies duplicate titles in a BibTeX string.

    Parameters
    ----------
    bib_text : str
        Contents of the .bib file.

    Returns
    -------
    dict
        A dictionary with duplicate titles and their counts.
    """
    # Extract all 'title = {...}' entries (case-insensitive)
    titles = re.findall(r"title\s*=\s*{{([^}]+)}}", bib_text, flags=re.IGNORECASE)
    
    # Normalize titles (strip, lowercase)
    normalized_titles = [title.strip().lower() for title in titles]
    
    # Count occurrences
    title_counts = Counter(normalized_titles)
    
    # Filter duplicates
    duplicates = {title: count for title, count in title_counts.items() if count > 1}
    
    return duplicates

# %%
# Example usage
file_path = r"C:\Users\ricewater\Documents\CTIDownloads\20241204_malpedia_downloads\malpedia-db_2024-11-12.bib"
bib_content = read_bib_file(file_path)
duplicate_titles = find_duplicate_titles(bib_content)

print("Duplicate titles and their counts:")
# Out:
# Duplicate titles and their counts:

# %%
len(duplicate_titles)
# Out:
# 463

# %%
for title, count in duplicate_titles.items():
   print(f"{title} - {count}")
# Out:
# apt-k-47 organization launches espionage attacks using a new trojan tool - 2
# tracking subaat: targeted phishing attack leads to threat actor’s repository - 2
# clean ursa - 2
# granite taurus - 2
# trident ursa - 2
# diplomats beware: cloaked ursa phishing with a twist - 2
# fin7 power hour: adversary archaeology and the evolution of fin7 - 2
# feodo tracker - 2
# biotech research firm miltenyi biotec hit by ransomware, data leaked - 2
# privileges and credentials: phished at the request of counsel - 2
# kimsuky - 2
# lookout uncovers android spyware deployed in kazakhstan - 2
# threat actor targeting hong kong pro-democracy figures - 2
# deep analysis agent tesla malware - 2
# an analysis of infrastructure linked to the hagga threat actor - 3
# cyber deterrence in action? a story of one long hurricane panda campaign - 2
# ani-shell - 2
# icedid analysis - 2
# operation bitter biscuit - 2
# rancor: targeted attacks in south east asia using plaintee and ddkong malware families - 2
# axiom - 3
# lazarus group - 2
# putter panda - 2
# thrip - 2
# apt38 - 3
# machete - 2
# inception - 2
# prince of persia: infy malware active in decade of targeted attacks - 3
# targeted attacks in the middle east using kasperagent and micropsia - 2
# prince of persia – ride the lightning: infy returns as “foudre” - 2
# tweet on unlock92 ransomware - 2
# on the strongpity waterhole attacks targeting italian and belgian encryption users - 2
# a simple example of a complex cyberattack - 2
# following the trail of blacktech’s cyber espionage campaigns - 2
# bad magic: new apt found in the area of russo-ukrainian conflict - 2
# revisting blister: new development of the blister loader - 2
# pacifier apt - 3
# unveiling socks5systemz: the rise of a new proxy service via privateloader and amadey - 2
# the eye of the tiger - 4
# gamaredon group grows its game - 2
# email-delivered modi rat attack pastes powershell commands - 2
# windows services lay the groundwork for a midas ransomware attack - 2
# dridex bots deliver entropy ransomware in recent attacks - 2
# light in the dark: hunting for sunburst - 2
# gootkit banking trojan | deep dive into anti-analysis features - 2
# vietnam national background apt organization "sea lotus" used the topic of the epidemic to attack our government agencies - 2
# inside trickbot, russia’s notorious ransomware gang - 2
# breaking the weakest link of the strongest chain - 2
# spoofing in the reeds with rietspoof - 3
# apt group planted backdoors targeting high profile networks in central asia - 2
# apt group targeting governmental agencies in east asia - 3
# backdoored client from mongolian ca monpass - 2
# bkdr_rarstone: new rat to watch out for - 2
# an investigation of chrysaor malware on android - 2
# tweet on malware sample - 4
# darkside raas in linux version - 2
# investigating fortimanager zero-day exploitation (cve-2024-47575) - 2
# yanbian gang malware continues with wide-scale distribution and c2 - 2
# analysis of targeted attack against pakistan by exploiting inpage vulnerability and related apt groups - 2
# masters of mimicry: new apt group chamelgang and its arsenal - 3
# ransomware-as-a-service: understanding the cybercrime gig economy and how to protect yourself - 2
# flying in the clouds: apt31 renews its attacks on russian companies through cloud storage - 2
# sasfis malware uses a new trick - 2
# pseudomanuscrypt: a mass-scale spyware attack campaign - 3
# phishing campaigns by the nobelium intrusion set - 2
# redbaldknight/bronze butler’s daserf backdoor now using steganography - 2
# china hacked south korea over missile defense, u.s. firm says - 3
# the rise of telebots: analyzing disruptive killdisk attacks - 2
# xdata ransomware making rounds amid global wannacryptor scare - 2
# industroyer: biggest threat to industrial control systems since stuxnet - 2
# telebots are back: supply‑chain attacks against ukraine - 2
# chinese cyberespionage originating from tsinghua university infrastructure - 2
# fbi says an iranian hacking group is attacking f5 networking devices - 2
# hidden cobra - north korean malicious cyber activity - 2
# #stopransomware: ransomware attacks on critical infrastructure fund dprk malicious cyber activities - 2
# scattered spider - 2
# black basta ransomware | attacks deploy custom edr evasion tools tied to fin7 threat actor - 2
# domain blooms: identifying domain name themes targeted by threat actors - 2
# freemilk: a highly targeted spear phishing campaign - 2
# sofacy’s ‘komplex’ os x trojan - 2
# 2019 crowdstrike global threat report - 3
# hacker group creates network of fake linkedin profiles - 2
# ready for (nearly) anything:  five things to prepare for a  cyber security incident - 2
# how to expose a potential cybercriminal due to misconfigurations - 2
# operation dustysky part 2 - 2
# operation cleaver - 4
# mars-deimos: from jupiter to mars and back again (part two) - 2
# from the front lines | unsigned macos orat malware gambles for the win - 2
# the black vine cyberespionage group - 2
# suckfly: revealing the secret life of your code signing certificates - 2
# indian organizations targeted in suckfly attacks - 2
# cridex analysis using volatility - 2
# domain borrowing: catch my c2 traffic if you can - 3
# midas ransomware : tracing the evolution of thanos ransomware variants - 2
# hidden lynx – professional hackers for hire - 4
# babuk ransomware - 3
# darkside ransomware - 3
# atomsilo ransomware - 2
# diavol ransomware - 2
# rook ransomware analysis - 2
# study of targeted attacks on russian research institutes - 2
# qakbot infection with cobalt strike and vnc activity - 2
# arkei variants: from vidar to mars stealer - 2
# windows metastealer malware - 2
# ta578 using thread-hijacked emails to push iso files for bumblebee malware - 2
# bumblebee malware from transferxl urls - 2
# recent icedid (bokbot) activity - 2
# gelsemium: when threat actors go gardening - 2
# sykipot now targeting us civil aviation sector information - 2
# thwarting loaders: from socgholish to blister’s lockbit payload - 2
# russian hackers suspected in cyberattack on german parliament - 2
# new wannacryptor‑like ransomware attack hits globally: all you need to know - 2
# the mystery of metador | an unattributed threat hiding in telcos, isps, and universities - 3
# threat assessment: black basta ransomware - 2
# the kitten that charmed me: the 9 lives of a nation state attacker - 2
# emotet is back - 2
# chinese actors use ‘3102’ malware in attacks on us government and eu media - 2
# emissary trojan changelog: did operation lotus blossom cause it to evolve? - 2
# the oilrig campaign: attacks on saudi arabian organizations deliver helminth backdoor - 2
# new sofacy attacks against us government agency - 3
# striking oil: a closer look at adversary infrastructure - 2
# oilrig uses rgdoor iis backdoor on targets in the middle east - 2
# the gorgon group: slithering between nation state and cybercrime - 2
# sofacy continues global attacks and wheels out new ‘cannon’ trojan - 2
# xdspy: stealing government secrets since 2011 - 2
# deep analysis of vidar stealer - 2
# threat bulletin: cutting-off the command-and-control infrastructure of collectorgoomba - 2
# solarwinds | understanding & detecting the supernova webshell trojan - 2
# operation saffron rose - 2
# operation quantum entanglement - 2
# hammertoss: stealthy tactics define a russian cyber threat group - 2
# apt41: double dragon apt41, a dual espionage and cyber crime operation - 2
# who’s who in the zoo - 2
# teamtnt upgrades arsenal, refines focus on kubernetes and gpu environments - 2
# elastic charms spectralviper - 2
# achievement unlocked: chinese cyber espionage evolves to support higher level missions - 2
# latrodectus rapid evolution continues with latest new payload features - 2
# roboski and global recovery: automation to combat evolving obfuscation - 2
# rm3 – curiosities of the wildest banking malware - 2
# suspected iran-nexus tag-56 uses uae forum lure for credential theft against us think tank - 2
# exposing tag-53’s credential harvesting infrastructure used for russia-aligned espionage operations - 3
# unveiling the depths of residential proxies providers - 2
# meta: ukrainian officials, military targeted by ghostwriter hackers - 2
# cve-2024-38112: void banshee targets windows users through zombie internet explorer in zero-day attacks - 2
# removing coordinated inauthentic behavior - 2
# taking action against hackers in bangladesh and vietnam - 2
# the dukes: 7 years of russian cyber-espionage - 2
# iran and russia blamed for state-sponsored espionage - 2
# fakecalls: a talking trojan - 2
# iranian fileless attack infiltrates israeli organizations - 2
# fin7 takes another bite at the restaurant industry - 2
# fin7 dissected: hackers accelerate pace of innovation - 2
# the epic turla operation - 2
# the darkhotel apt - 2
# cloud atlas: redoctober apt is back in style - 2
# equation: the death star of malware galaxy - 2
# the desert falcons targeted attacks - 2
# wild neutron – economic espionage threat actor returns with new tricks - 2
# sofacy apt hits high profile targets with updated toolset - 2
# lazarus under the hood - 4
# apt trends report q2 2019 - 2
# recent cloud atlas activity - 2
# apt trends report q2 2020 - 2
# apt trends report q3 2021 - 2
# a bad luck blackcat - 2
# windealer dealing on the side - 2
# the deception project: a new japanese-centric threat - 2
# swallowing the snake’s tail: tracking turla infrastructure - 2
# china-linked group redecho targets the indian power sector amid heightened border tensions - 2
# chinese state-sponsored activity group tag-22 targets nepal, the philippines, and taiwan using winnti and other tooling - 2
# china-linked group tag-28 targets india’s “the times group” and uidai (aadhaar) government agency with winnti malware - 2
# full spectrum detections for 5 popular web shells: alfa, sharpyshell, krypton, aspxspy, and twoface - 2
# isaacwiper continues trend of wiper attacks against ukraine - 2
# solardeflection c2 infrastructure used by nobelium in company brand misuse - 2
# fog of war: how the ukraine conflict transformed the cyber threat landscape - 2
# ukraine remains russia’s biggest cyber focus in 2023 - 2
# bluedelta exploits ukrainian government roundcube mail servers to support espionage activities - 2
# redcurl: the pentest you didn’t know about - 2
# the brothers grim - the reversing tale of grimagent malware used by ryuk - 2
# redcurl: the awakening - 2
# oilrig malware campaign updates toolset and expands targets - 2
# dragonok updates toolset and targets multiple geographic regions - 2
# threat actors target government of belarus using cmstar trojan - 2
# thundercats hack the fsb | your taxes didn’t pay for this op - 2
# netwire technical analysis report - 2
# unveiling the cryptomimic - 2
# sysrv-hello expands infrastructure - 2
# patchwork cyberespionage group expands targets from governments to wide range of industries - 2
# ex-conti and fin7 actors collaborate with new domino backdoor - 2
# when pentest tools go brutal: red-teaming tool being abused by malicious actors - 2
# operation ghoul: targeted attacks on industrial and engineering organizations - 2
# a coin miner with a “heaven’s gate” - 2
# lockbit ransomware side-loads cobalt strike beacon with legitimate vmware utility - 2
# bisonal malware used in attacks against russia and south korea - 2
# chinese threat actor scarab targeting ukraine - 2
# from the front lines | 8220 gang massively expands cloud botnet to 30,000 infected hosts - 2
# global dns hijacking campaign: dns record manipulation at scale - 2
# tweet on ransomware - 3
# new fileless botnet novter distributed by kovcoreg malvertising campaign - 2
# apt-c-36 updates its spam campaign against south american entities with commodity rats - 2
# ten process injection techniques: a technical survey of common and trending process injection techniques - 3
# eset discovers attor, a spy platform with curious gsm fingerprinting - 2
# digging up invisimole’s hidden arsenal - 2
# turla png dropper is back - 2
# analysis run - 4
# trojan.koredos comes with an unwelcomed surprise - 2
# higaisa or winnti? apt41 backdoors, old and new - 2
# analysis of a series of attacks by the suspected lazarus organization using daewoo shipyard as relevant bait - 2
# protecting customers from a private-sector offensive actor using 0-day exploits and devilstongue malware - 2
# bazacall: phony call centers lead to exfiltration and ransomware - 2
# evolving trends in iranian threat actor activity – mstic presentation at cyberwarcon 2021 - 2
# the many lives of blackcat ransomware - 2
# raspberry robin worm part of larger ecosystem facilitating pre-ransomware activity - 2
# tweet on linux version of revil ransomware - 2
# alphv ransomware gang analysis - 2
# an apt with no name - 2
# hackers lurking, parliamentarians told - 2
# industroyer2: industroyer reloaded - 2
# new activity of the blue termite apt - 2
# mofang: a politically motivated information stealing adversary - 2
# ta505 exploits solarwinds serv-u vulnerability (cve-2021-35211) for initial access - 2
# the story of jian – how apt31 stole and used an unknown equation group 0-day - 2
# netwalker ransomware - 2
# antefrigus ransomware - 2
# nefilim ransomware - 2
# gocryptolocker - 2
# lv ransomware - 2
# gist with xz backdoor analysis - 2
# chinese apt group targets india and hong kong using new variant of mgbot malware - 2
# evasive panda - 2
# lazarus apt conceals malicious code within bmp image to drop its rat - 2
# the elderwood project - 3
# apt1: q&a on attacks by the comment crew - 2
# duuzer back door trojan targets south korea to take over computers - 2
# russian bank employees received fake job offers in targeted email attack - 2
# strider: cyberespionage group turns eye of sauron on targets - 2
# shamoon: back from the dead and destructive as ever - 2
# attackers target dozens of global banks with new malware - 2
# shamoon: multi-staged destructive attacks limited to specific targets - 2
# longhorn: tools used by cyberespionage group linked to vault 7 - 2
# nine iranians charged with conducting massive cyber theft campaign on behalf of the islamic revolutionary guard corps - 2
# the state of stalkerware in 2021 - 2
# houdini’s magic reappearance - 2
# the gamaredon group toolset evolution - 4
# habitsrat used to target linux and windows servers - 2
# threat hunting in active directory environment - 2
# operation pawn storm: using decoys to evade detection - 2
# operation muzabi - 2
# new linux/rakos threat: devices and servers under ssh scan (again) - 2
# mikroceen: spying backdoor leveraged in high‑profile networks in central asia - 2
# overview of the cyber weapons used in the ukraine - russia war - 2
# microsoft security—detecting empires in the cloud - 2
# newest addition to a happy family: kbot - 2
# bringing a cannon to a knife fight - 2
# gacrux – a basic c malware with a custom pe loader - 2
# how winnti apt grouping works - 2
# convuster: macos adware now in rust - 2
# lofylife: malicious npm packages steal discord tokens and bank card data - 2
# callisto group - 2
# ta505 targets the americas in a new campaign - 2
# operation exchange marauder - 2
# the pumpkin eclipse - 2
# derailing the raptor train - 2
# iranian hackers targeting turkey and arabian peninsula in new malware campaign - 2
# crackedcantil: a malware symphony breakdown - 2
# inception attackers target europe with year-old office vulnerability - 2
# malicious document targets vietnamese officials - 2
# remcos rat - 2
# mosaicregressor: lurking in the shadows of uefi - 2
# caught in the wild - past, present and future - 2
# a look into fysbis: sofacy’s linux backdoor - 2
# magic hound campaign attacks saudi targets - 2
# oopsie! oilrig uses threedollars to deliver new trojan - 2
# tracking cyber activity in eastern europe - 2
# update on cyber activity in eastern europe - 2
# continued cyber activity in eastern europe observed by tag - 2
# kazuar: multiplatform espionage backdoor with api access - 2
# a detailed analysis of an advanced persistent threat malware - 2
# scarab attackers took aim at select russian targets since 2012 - 2
# new adobe flash zero-day used in pawn storm campaign targeting foreign affairs ministries - 2
# quarterly report: incident response trends in summer 2020 - 2
# operation potao express: analysis of a cyber‑espionage toolkit - 2
# killdisk now targeting linux: demands $250k ransom, but can’t decrypt - 2
# black kingdom ransomware begins appearing on exchange servers - 2
# hypervisor jackpotting: carbon spider and sprite spider target esxi servers with ransomware to maximize impact - 2
# trickbot variant “anchor_dns” communicating over dns - 2
# unpacking an emotet trojan - 2
# purple fox uses new arrival vector and improves malware arsenal - 2
# recent litehttp activities and iocs - 2
# insidecopy: how this apt continues to evolve its arsenal - 3
# advanced persistent threats (apts) - 2
# the "wayback” campaign: a large scale operation hiding in plain sight - 2
# on the footsteps of hive ransomware - 2
# russian hackers 'fancy bear' likely breached olympic drug-testing agency and dnc, experts say - 2
# catching the “inception framework” phishing attack - 2
# yours truly, signed av driver: weaponizing an antivirus driver - 2
# targeted attacks on french company exploit multiple word vulnerabilities - 2
# tracking ‘kimsuky’, the north korea-based cyber espionage group: part 1 - 2
# inside a back door attack - 2
# smoking out a darkside affiliate’s supply chain software compromise - 2
# introducing rokrat - 2
# korea in the crosshairs - 2
# dns on fire - 2
# xloader android spyware and banking trojan distributed via dns spoofing - 2
# investigating apt36 or earth karkaddan’s attack chain and malware arsenal - 2
# microsoft digital defense report - 2
# iran responsible for charlie hebdo attacks - 2
# recent watering hole attacks attributed to apt group “th3bug” using poison ivy - 2
# unit 42 identifies new dragonok backdoor malware deployed against japanese targets - 2
# menupass returns with new malware and new attacks against japanese academics and organizations - 2
# trochilus and new moonwind rats used in attack against thai organizations - 2
# unboxing linux/mumblehard: muttering spam from your servers - 2
# bad rabbit: not‑petya is back with improved ransomware - 2
# ebury is alive but unseen: 400k linux servers compromised for cryptocurrency theft and financial gain - 2
# graftor - but i never asked for this… - 2
# threat alert: fileless malware executing in containers - 2
# kinsing malware exploits novel openfire vulnerability - 2
# operation deputydog: zero-day (cve-2013-3893) attack against japanese targets - 2
# conti ransomware - 2
# regeorg - 2
# hafnium targeting exchange servers with 0-day exploits - 2
# actinium targets ukrainian organizations - 2
# disrupting seaborgium’s ongoing phishing operations - 2
# akira ransomware - 2
# nspx30: a sophisticated aitm-enabled implant evolving since 2005 - 2
# goldmax, goldfinder, and sibot: analyzing nobelium’s layered persistence - 2
# operation bearded barbie: apt-c-23 campaign targeting israeli officials - 2
# winnti analysis - 2
# new apt group murenshark investigative report: torpedoes hit turkish navy - 2
# reverse-engineering dubnium - 2
# finding beacons in the dark - 2
# who is pioneer kitten? - 2
# chae$ chronicles: version 4.1 dedicated to morphisec researchers - 2
# operation lagtime it: colourful panda footprint - 3
# what is cyber threat intelligence? - 2
# the hidden c2: lampion trojan release 212 is on the rise and using a c2 server for two years - 2
# decoding network data from a gh0st rat variant - 2
# in-depth analysis of the new team9 malware family - 2
# hogfish redleaves campaign: hogfish (apt10) targets japan with redleaves implants in “new battle” - 2
# a detailed analysis of the redline stealer - 2
# a deep dive into black basta ransomware - 2
# south korean financial companies targeted by castov - 2
# operation woolen-goldfish: when kittens go phishing - 2
# winnti abuses github for c&c communications - 2
# sanctions be damned | from dridex to macaw, the evolution of evil corp - 2
# old gremlins, new methods - 2
# apt43: north korean group uses cybercrime to fund espionage operations - 2
# fin7 revisited: inside astra panel and sqlrat malware - 2
# vicious panda: the covid campaign - 2
# ta505 group’s teslagun in-depth analysis - 2
# the chronicles of the hellsing apt: the empire strikes back - 2
# drop it like it's qbot: separating malicious droppers, loaders, and crypters from their payloads - 2
# delphi used to score against palestine - 2
# tropic trooper targets taiwanese government and fossil fuel provider with poison ivy - 3
# leonardo s.p.a. data breach analysis - 2
# snatch ransomware - 2
# lojax: first uefi rootkit found in the wild, courtesy of the sednit group - 2
# mekotio: these aren’t the security updates you’re looking for… - 2
# bandook: signed & delivered - 2
# the madi attacks: series of social engineering campaigns - 2
# the shamoon attacks - 2
# four years of darkseoul cyberattacks against south korea continue on anniversary of korean war - 2
# dragonfly: cyberespionage attacks against energy suppliers - 2
# sandworm windows zero-day vulnerability being actively exploited in targeted attacks - 2
# security vendors take action against hidden lynx malware - 2
# iran-based attackers use back door threats to spy on middle eastern targets - 2
# the waterbug attack group - 2
# swift attackers’ malware linked to more financial attacks - 2
# buckeye cyberespionage group shifts gaze from us to hong kong - 4
# odinaff: new trojan used in high level financial attacks - 2
# greenbug cyberespionage group targeting middle east, possible links to shamoon - 2
# supernova solarwinds .net webshell analysis - 3
# monthly news - november 2023 - 2
# shamoon attackers employ new tool kit to wipe infected systems - 2
# shelltea + poslurp malware memory-resident point-of-sale malware attacks industry - 2
# joker - 2
# spynote - 2
# timeline of sandworm attacks - 2
# threat assessment: hangover threat group - 2
# downeks and quasar rat used in recent targeted attacks against governments - 2
# abadbabe 8badf00d: discovering badhatch and a detailed look at fin8’s tooling - 2
# donot team leverages new modular malware framework in south asia - 2
# cyber threat profile malteiro - 2
# bronze butler - 2
# gold kingswood - 2
# muddywater operations in lebanon and oman - 2
# rewterz threat alert – widely abused msix app installer disabled by microsoft – active iocs - 2
# sharkbot: a “new” generation android banking trojan being distributed on google play store - 2
# vice society: a discreet but steady double extortion ransomware group - 2
# dissecting operation troy: cyberespionage in south korea - 2
# mcafee uncovers operation honeybee, a malicious document campaign targeting humanitarian aid groups - 2
# analyzing operation ghostsecret: attack seeks to steal data worldwide - 2
# taiwan heist: lazarus tools and ransomware - 2
# unc1860 and the temple of oats: iran’s hidden hand in middle eastern networks - 2
# targeted attacks on indian government and financial institutions using the jsoutprox rat - 2
# a "naver"-ending game of lazarus apt - 2
# recent inpage exploits lead to multiple malware families - 2
# tracking bumblebee’s development - 2
# august in november: new information stealer hits the scene - 2
# operation bleeding bear - 2
# a guide to macos threat hunting and incident response - 2
# apt41 has arisen from the dust - 2
# exposing initial access broker with ties to conti - 2
# chessmaster makes its move: a look into the campaign’s cyberespionage arsenal - 2
# the luckycat hackers - 2
# satellite turla: apt command and control in the sky - 2
# operation stealthytrident: corporate software under attack - 2
# the new maxtrilha trojan is being disseminated and targeting several banks - 2
# deep panda - 2
# the anthem hack: all roads lead to china - 2
# thamar reservoir – an iranian cyber-attack campaign against targets in the middle east - 2
# threat group 3390 cyberespionage - 2
# fastpos: quick and easy credit card theft - 2
# digitally signed malware targeting gaming companies - 2
# twin zero-day attacks: promethium and neodymium target individuals in europe - 2
# iranian threat agent oilrig delivers digitally signed malware, impersonates university of oxford - 2
# operation electric powder – who is targeting israel electric company? - 2
# el machete's malware attacks cut through latam - 2
# dragonfly: western energy sector targeted by sophisticated attack group - 3
# iranian threat agent greenbug impersonates israeli high-tech and cyber security companies - 2
# mitigating and eliminating info-stealing qakbot and emotet in corporate networks - 2
# cyberespionage campaign sphinx goes mobile with anubisspy - 2
# chafer: latest attacks reveal heightened ambitions - 2
# leafminer: new espionage campaigns targeting middle eastern regions - 2
# double the infection, double the fun - 2
# apt28: new espionage operations target military and government organizations - 2
# fastcash: how the lazarus group is emptying millions from atms - 2
# stolen pencil campaign targets academia - 2
# shamoon: destructive threat re-emerges with new sting in its tail - 2
# elfin: relentless espionage group targets multiple organizations in saudi arabia and u.s. - 2
# double trouble: ransomware with data leak extortion, part 1 - 2
# analyzing attacks that exploit the cve-2021-40444 mshtml vulnerability - 2
# threat advisory: strt-ta02 - destructive software - 2
# cyber threat activity in ukraine: analysis and resources - 2
# cicada: chinese apt group widens targeting in recent espionage activity - 2
# outbreak of follina in australia - 2
# volt typhoon compromises 30% of cisco rv320/325 devices in 37 days - 2
# operation “space race”: reaching the stars through professional social networks - 2
# revix linux ransomware - 2
# brata - a tale of three families - 2
# malware “wellmess” targeting linux and windows - 2
# pla unit 61398 - 2
# red october - 2
# rocket kitten - 2
# winnti umbrella - 2
# mem2img: memory-resident malware detection via convolution neural network - 2
# indicators of compromise for malware used by apt28 - 2
# china: declaration by the high representative on behalf of the european union urging chinese authorities to take action against malicious cyber activities undertaken from its territory - 2
# macos malware is more reality than myth: popular threats and challenges in analysis - 2
# fancy bear - 2
# bfv cyber-brief: hinweis auf aktuelle angriffskampagne - 2
# virustotal page for the sample - 2
# pixstealer: a new wave of android banking trojans abusing accessibility services - 2
# detecting and responding: pandas and bears - 2
# vault 7: cia hacking tools revealed - 2
# overwatch exposes aquatic panda in possession of log4shell exploit tools during hands-on intrusion attempt - 2
# oilrig uses updated bondupdater to target middle eastern government - 2
# trello from the other side: tracking apt29 phishing campaigns - 2
# dualtoy: new windows trojan sideloads risky apps to android and ios devices - 2
# operation ke3chang resurfaces with new tidepool malware - 2
# raspberry robin: anti-evasion how-to & exploit analysis - 2
# tough times for ukrainian honeypot? - 2
# clop ransomware notes - 2
