# %%
import pandas as pd
from statistics import mode

def apt_group_software_mapping(file_path: str):
    """
    Reads the relevant columns from the Excel file and maps each APT group to the software they use.
    Additionally, provides the mean, median, mode, and the max/min software counts with the respective APT group.

    Args:
        file_path (str): Path to the Excel file.

    Returns:
        dict: Mapping of APT groups to the software they use.
        int: Count of unique APT groups.
        int: Count of unique software.
        dict: Statistics including mean, median, mode, max, and min with respective APT groups.
    """
    # Load the sheet 'associated groups'
    xls = pd.ExcelFile(file_path)
    df = pd.read_excel(xls, sheet_name='associated groups')

    # Ensure the relevant columns exist
    if 'source name' in df.columns and 'target ID' in df.columns:
        # Create a mapping of APT groups to software
        apt_to_software = df.groupby('source name')['target ID'].apply(list).to_dict()

        # Get the count of software used by each APT group
        software_counts = df.groupby('source name')['target ID'].nunique()

        # Calculate statistics
        mean_count = software_counts.mean()
        median_count = software_counts.median()
        try:
            mode_count = mode(software_counts)
        except:
            mode_count = 'No unique mode'

        max_count = software_counts.max()
        min_count = software_counts.min()

        # Find the APT groups corresponding to the max and min counts
        max_apt_group = software_counts.idxmax()
        min_apt_group = software_counts.idxmin()

        stats = {
            'mean_count': mean_count,
            'median_count': median_count,
            'mode_count': mode_count,
            'max_count': max_count,
            'max_apt_group': max_apt_group,
            'min_count': min_count,
            'min_apt_group': min_apt_group
        }

        # Get unique counts
        unique_apt_groups = df['source name'].nunique()
        unique_software = df['target ID'].nunique()

        return apt_to_software, unique_apt_groups, unique_software, stats
    else:
        raise ValueError("The required columns 'source name' and 'target ID' are not found in the sheet.")

# %%
file_path = r"C:\Users\Aakanksha Saha\Documents\CTITTP\enterprise-attack-v16.1-software.xlsx"  # Replace with your Excel file path
try:
    apt_mapping, unique_apt_groups, unique_software, stats = apt_group_software_mapping(file_path)
    #print(f"APT Group to Software Mapping:\n{apt_mapping}")
    print(f"\nUnique APT Groups Count: {unique_apt_groups}")
    print(f"Unique Software Count: {unique_software}")
    print(f"\nStatistics:\n{stats}")
except ValueError as e:
    print(e)
# Out:
# Unique APT Groups Count: 145
# Unique Software Count: 523
#
# Statistics:
# {'mean_count': np.float64(6.889655172413793), 'median_count': np.float64(4.0), 'mode_count': 2, 'max_count': np.int64(48), 'max_apt_group': 'APT29', 'min_count': np.int64(1), 'min_apt_group': 'APT-C-23'}

# %%
import pandas as pd
from collections import Counter

def get_top_software(file_path: str, top_n: int = 10):
    """
    Identifies the top N software used by count and includes the software name for readability.

    Args:
        file_path (str): Path to the Excel file.
        top_n (int): Number of top software to identify.

    Returns:
        pd.DataFrame: A DataFrame containing the top N software with their counts and corresponding names.
    """
    # Load the sheet 'associated groups'
    xls = pd.ExcelFile(file_path)
    df = pd.read_excel(xls, sheet_name='associated groups')

    # Ensure the relevant columns exist
    if 'source name' in df.columns and 'target ID' in df.columns and 'target name' in df.columns:
        # Count occurrences of each target ID
        software_counts = df['target ID'].value_counts().head(top_n).reset_index()
        software_counts.columns = ['target ID', 'count']

        # Merge with 'target name' for readability
        software_details = software_counts.merge(df[['target ID', 'target name']].drop_duplicates(), on='target ID')

        # Ensure no duplicates from merging and return
        return software_details
    else:
        raise ValueError("Required columns ('source name', 'target ID', 'target name') are not found in the sheet.")

# %%
# Ensure all rows are shown
pd.set_option('display.max_rows', None)  # Disable row truncation

# Example Usage
file_path = r"C:\Users\Aakanksha Saha\Documents\CTITTP\enterprise-attack-v16.1-software.xlsx" 
try:
    top_software = get_top_software(file_path, top_n=523)
    print("Top Software:")
    print(top_software)
except ValueError as e:
    print(e)
# Out:
# Top Software:
#     target ID  count                target name
# 0       S0002     48                   Mimikatz
# 1       S0029     35                     PsExec
# 2       S0039     31                        Net
# 3       S0154     26              Cobalt Strike
# 4       S0363     17                     Empire
# 5       S0013     14                      PlugX
# 6       S0012     14                  PoisonIvy
# 7       S0100     13                   ipconfig
# 8       S0357     13                   Impacket
# 9       S0097     13                       Ping
# 10      S0349     12                    LaZagne
# 11      S0104     11                    netstat
# 12      S0160     11                   certutil
# 13      S0032     11                  gh0st RAT
# 14      S0057     11                   Tasklist
# 15      S0096     10                 Systeminfo
# 16      S0552      9                     AdFind
# 17      S0590      9                    NBTscan
# 18      S0194      9                PowerSploit
# 19      S0075      8                        Reg
# 20      S0020      8              China Chopper
# 21      S0190      7                  BITSAdmin
# 22      S0005      7  Windows Credential Editor
# 23      S0385      7                      njRAT
# 24      S0108      7                      netsh
# 25      S0521      6                 BloodHound
# 26      S0262      6                  QuasarRAT
# 27      S0596      6                  ShadowPad
# 28      S0106      6                        cmd
# 29      S0359      6                     Nltest
# 30      S0006      6                     pwdump
# 31      S0008      5                   gsecdump
# 32      S0195      5                    SDelete
# 33      S0488      5               CrackMapExec
# 34      S0095      5                        ftp
# 35      S0073      5                    ASPXSpy
# 36      S0645      4                   Wevtutil
# 37      S0021      4                    Derusbi
# 38      S1040      4                     Rclone
# 39      S0250      4                     Koadic
# 40      S0183      4                        Tor
# 41      S0336      4                   NanoCore
# 42      S0198      4                    NETWIRE
# 43      S0508      4                      ngrok
# 44      S0284      3                  More_eggs
# 45      S1144      3                        FRP
# 46      S0111      3                   schtasks
# 47      S0174      3                  Responder
# 48      S0110      3                         at
# 49      S0670      3                 WarzoneRAT
# 50      S0191      3                     Winexe
# 51      S0069      3                BLACKCOFFEE
# 52      S0334      3                  DarkComet
# 53      S0378      3                     PoshC2
# 54      S0099      3                        Arp
# 55      S0412      3                    ZxShell
# 56      S0430      3           Winnti for Linux
# 57      S0404      3                   esentutl
# 58      S1160      2                Latrodectus
# 59      S0434      2           Imminent Monitor
# 60      S0331      2                Agent Tesla
# 61      S0662      2                  RCSession
# 62      S0103      2                      route
# 63      S1025      2                     Amadey
# 64      S0496      2                      REvil
# 65      S0384      2                     Dridex
# 66      S0332      2                     Remcos
# 67      S0591      2                ConnectWise
# 68      S0381      2                FlawedAmmyy
# 69      S0632      2                  GrimAgent
# 70      S0449      2                       Maze
# 71      S0446      2                       Ryuk
# 72      S0379      2                Revenge RAT
# 73      S0266      2                   TrickBot
# 74      S0483      2                     IcedID
# 75      S0650      2                     QakBot
# 76      S1018      2                  Saint Bot
# 77      S0598      2            P.A.S. Webshell
# 78      S1039      2                  Bumblebee
# 79      S0664      2                    Pandora
# 80      S0105      2                    dsquery
# 81      S0633      2                     Sliver
# 82      S0203      2                     Hydraq
# 83      S0141      2         Winnti for Windows
# 84      S0030      2                   Carbanak
# 85      S0534      2                      Bazar
# 86      S1097      2                 HUI Loader
# 87      S0593      2         ECCENTRICBANDWAGON
# 88      S0192      2                       Pupy
# 89      S0225      2                     sqlmap
# 90      S0607      2                   KillDisk
# 91      S0376      2                   HOPLIGHT
# 92      S0129      2            AutoIt backdoor
# 93      S1134      2                   DEADWOOD
# 94      S0040      2                      HTRAN
# 95      S0070      2                HTTPBrowser
# 96      S0275      1                   UPPERCUT
# 97      S0119      1                  Cachedump
# 98      S0026      1                  GLOOXMAIL
# 99      S0121      1                    Lslsass
# 100     S0122      1      Pass-The-Hash Toolkit
# 101     S0504      1                     Anchor
# 102     S0501      1                    PipeMon
# 103     S0466      1                   WindTail
# 104     S0377      1                      Ebury
# 105     S0680      1                  LitePower
# 106     S0679      1                  Ferocious
# 107     S0387      1                     KeyBoy
# 108     S0452      1                   USBferry
# 109     S0388      1                    YAHOYAH
# 110     S0335      1                     Carbon
# 111     S0126      1                     ComRAT
# 112     S0137      1                  CORESHELL
# 113     S0351      1                     Cannon
# 114     S0243      1              DealersChoice
# 115     S0134      1                  Downdelph
# 116     S0502      1                   Drovorub
# 117     S0193      1                   Forfiles
# 118     S0410      1                     Fysbis
# 119     S0135      1                    HIDEDRV
# 120     S0044      1                   JHUHUGIT
# 121     S1141      1                   LunarWeb
# 122     S0256      1                   Mosquito
# 123     S0247      1                     NavRAT
# 124     S0216      1                    POORAIM
# 125     S0240      1                     ROKRAT
# 126     S0354      1                      Denis
# 127     S0477      1                      Goopy
# 128     S0156      1                   KOMPROGO
# 129     S0585      1                   Kerrdown
# 130     S0352      1           OSX_OCEANLOTUS.D
# 131     S0158      1                    PHOREAL
# 132     S1078      1                 RotaJakiro
# 133     S0157      1                  SOUNDBITE
# 134     S0155      1                 WINDSHIELD
# 135     S0371      1                   POWERTON
# 136     S0682      1                TrailBlazer
# 137     S0636      1                  VaporRage
# 138     S0515      1                   WellMail
# 139     S0036      1                 FLASHFLOOD
# 140     S0034      1                   NETEAGLE
# 141     S0028      1                  SHIPSHAPE
# 142     S0035      1                  SPACESHIP
# 143     S0048      1                  PinchDuke
# 144     S0518      1               PolyglotDuke
# 145     S0139      1                  PowerDuke
# 146     S1084      1                  QUIETEXIT
# 147     S0684      1                  ROADTools
# 148     S0565      1                   Raindrop
# 149     S0657      1                  BLUELIGHT
# 150     S0212      1                  CORALDECK
# 151     S0213      1                    DOGCALL
# 152     S0355      1                Final1stspy
# 153     S0214      1                  HAPPYWORK
# 154     S0215      1                      KARAE
# 155     S0112      1                   ROCKBOOT
# 156     S1109      1                  PACEMAKER
# 157     S1108      1                 PULSECHECK
# 158     S0217      1               SHUTTERSPEED
# 159     S0218      1                  SLOWDRIFT
# 160     S0219      1                   WINERACK
# 161     S0454      1                   Cadelspy
# 162     S0459      1              MechaFlounder
# 163     S0375      1                     Remexi
# 164     S0358      1                      Ruler
# 165     S0380      1                 StoneDrill
# 166     S0199      1                   TURNEDUP
# 167     S0165      1                     OSInfo
# 168     S0166      1                  RemoteCMD
# 169     S0063      1                    SHOTPUT
# 170     S0031      1                  BACKSPACE
# 171     S1159      1                   DUSTTRAP
# 172     S1051      1                    KEYPLUG
# 173     S0443      1                 MESSAGETAP
# 174     S0511      1                    RegDuke
# 175     S0559      1                   SUNBURST
# 176     S0562      1                    SUNSPOT
# 177     S0053      1                    SeaDuke
# 178     S0589      1                      Sibot
# 179     S0516      1                   SoreFang
# 180     S0560      1                   TEARDROP
# 181     S0054      1                  CloudDuke
# 182     S0050      1                 CosmicDuke
# 183     S0046      1                    CozyCar
# 184     S0634      1                  EnvyScout
# 185     S0512      1                    FatDuke
# 186     S0661      1                   FoggyWeb
# 187     S1050      1                    PcShare
# 188     S1113      1                 RAPIDPULSE
# 189     S1110      1                SLIGHTPULSE
# 190     S1104      1                  SLOWPULSE
# 191     S0007      1               Skeleton Key
# 192     S1133      1                    Apostle
# 193     S1136      1               BFG Agonizer
# 194     S1132      1               IPsec Helper
# 195     S1137      1                  Moneybird
# 196     S1135      1           MultiLayer Wiper
# 197     S0224      1                      Havij
# 198     S1129      1                      Akira
# 199     S0433      1                    Rifdoor
# 200     S1027      1            Heyoka Backdoor
# 201     S1026      1                    Mongall
# 202     S1158      1                    DUSTPAN
# 203     S0056      1                Net Crawler
# 204     S0004      1                   TinyZBot
# 205     S0646      1              SpicyOmelette
# 206     S0167      1                 Matryoshka
# 207     S0009      1                      Hikit
# 208     S0672      1                        Zox
# 209     S1013      1                       ZxxZ
# 210     S0469      1                        ABK
# 211     S0473      1                    Avenger
# 212     S0470      1                        BBK
# 213     S0187      1                     Daserf
# 214     S0471      1               build_downer
# 215     S0472      1                   down_new
# 216     S0647      1                     Turian
# 217     S0696      1                    Flagpro
# 218     S0437      1                     Kivars
# 219     S0138      1                    OLDBAIT
# 220     S0136      1                 USBStealer
# 221     S0235      1                   CrossRAT
# 222     S0182      1                  FinFisher
# 223     S0270      1                 RogueRobin
# 224     S0080      1                     Mivast
# 225     S0074      1                     Sakula
# 226     S0142      1                   StreamEx
# 227     S0093      1            Backdoor.Oldrea
# 228     S0500      1                       MCMD
# 229     S0094      1            Trojan.Karagany
# 230     S0435      1                      PLEAD
# 231     S0436      1                   TSCookie
# 232     S0579      1                  Waterbear
# 233     S1152      1                 IMAPLoader
# 234     S1096      1                Cheerscrypt
# 235     S0164      1                     TDTESS
# 236     S1016      1                      MacMa
# 237     S1146      1                      MgBot
# 238     S1147      1                  Nightdoor
# 239     S0234      1                    Bandook
# 240     S0049      1                 GeminiDuke
# 241     S0597      1                 GoldFinder
# 242     S0588      1                    GoldMax
# 243     S0037      1                 HAMMERTOSS
# 244     S0513      1                   LiteDuke
# 245     S0051      1                   MiniDuke
# 246     S0637      1                 NativeZone
# 247     S0052      1                  OnionDuke
# 248     S0150      1                    POSHSPY
# 249     S0162      1                    Komplex
# 250     S0397      1                      LoJax
# 251     S0681      1                      Lizar
# 252     S0145      1                POWERSOURCE
# 253     S0517      1                 Pillowmint
# 254     S0416      1                 RDFSNIFFER
# 255     S0390      1                     SQLRat
# 256     S0204      1                      Briba
# 257     S0211      1                      Linfo
# 258     S0205      1                       Naid
# 259     S0210      1                      Nerex
# 260     S0208      1                      Pasam
# 261     S0207      1                    Vasport
# 262     S0206      1                      Wiarp
# 263     S0689      1                WhisperGate
# 264     S0568      1                    EVILNUM
# 265     S0173      1                   FLIPSIDE
# 266     S0169      1                     RawPOS
# 267     S0686      1                 QuietSieve
# 268     S1155      1                   Covenant
# 269     S0503      1               FrameworkPOS
# 270     S0372      1                 LockerGoga
# 271     S0161      1                  XAgentOSX
# 272     S0117      1                    XTunnel
# 273     S0251      1                    Zebrocy
# 274     S0677      1               AADInternals
# 275     S0635      1                    BoomBox
# 276     S0071      1                  hcdLoader
# 277     S0045      1              ADVSTORESHELL
# 278     S0023      1                  CHOPSTICK
# 279     S0415      1                 BOOSTWRITE
# 280     S0417      1                    GRIFFON
# 281     S0151      1                  HALFBAKED
# 282     S0648      1                 JSS Loader
# 283     S0570      1                  BitPaymer
# 284     S0695      1                      Donut
# 285     S0612      1               WastedLocker
# 286     S0280      1                  MirageFox
# 287     S0146      1                   TEXTMATE
# 288     S1081      1                   BADHATCH
# 289     S0196      1                 PUNCHBUGGY
# 290     S0197      1                 PUNCHTRACK
# 291     S0481      1              Ragnar Locker
# 292     S1085      1                   Sardonic
# 293     S0652      1                   MarkiRAT
# 294     S0556      1                    Pay2Key
# 295     S0564      1                 BlackMould
# 296     S1031      1                   PingPull
# 297     S0685      1                 PowerPunch
# 298     S0147      1                 Pteranodon
# 299     S0584      1                  AppleJeus
# 300     S0347      1                  AuditCred
# 301     S0245      1                    BADCALL
# 302     S0520      1                BLINDINGCAN
# 303     S0239      1                   Bankshot
# 304     S1011      1                    Tarrask
# 305     S1014      1                     DanBot
# 306     S1021      1                  DnsSystem
# 307     S1020      1                      Kevin
# 308     S1015      1                      Milan
# 309     S1019      1                      Shark
# 310     S1139      1             INC Ransomware
# 311     S0441      1                PowerShower
# 312     S0442      1                   VBShower
# 313     S0651      1                    BoxCaon
# 314     S0653      1                      xCaon
# 315     S0364      1                    RawDisk
# 316     S0586      1              TAINTEDSCRIBE
# 317     S0263      1                  TYPEFRAME
# 318     S0665      1               ThreatNeedle
# 319     S0180      1                    Volgmer
# 320     S0366      1                   WannaCry
# 321     S0691      1                   Neoichor
# 322     S0439      1                      Okrum
# 323     S0227      1                spwebmember
# 324     S0622      1                  AppleSeed
# 325     S0414      1                  BabyShark
# 326     S0252      1               Brave Prince
# 327     S0527      1            CSPY Downloader
# 328     S0249      1                Gold Dragon
# 329     S0526      1                    KGH_SPY
# 330     S0353      1                      NOKKI
# 331     S0409      1                    Machete
# 332     S0674      1                 CharmPower
# 333     S0186      1                  DownPaper
# 334     S1012      1                  PowerLess
# 335     S1122      1                    Mispadu
# 336     S1060      1                    Mafalda
# 337     S1059      1                   metaMain
# 338     S0498      1                Cryptoistic
# 339     S0497      1                      Dacls
# 340     S0567      1                     Dtrack
# 341     S0181      1                  FALLCHILL
# 342     S0246      1                   HARDRAIN
# 343     S0431      1               HotCroissant
# 344     S0271      1                  KEYMARBLE
# 345     S0238      1                   Proxysvc
# 346     S0241      1                   RATANKBA
# 347     S1034      1                StrifeWater
# 348     S1088      1                      Disco
# 349     S1090      1                  NightClub
# 350     S1089      1                 SharpDisco
# 351     S1047      1                       Mori
# 352     S0594      1                       Out1
# 353     S0223      1                 POWERSTATS
# 354     S0669      1                   KOCTOPUS
# 355     S0413      1                 MailSniper
# 356     S0642      1                   BADFLICK
# 357     S0232      1                    HOMEFRY
# 358     S0233      1                   MURKYTOP
# 359     S0228      1                  NanHaiShu
# 360     S0229      1                        Orz
# 361     S0081      1                      Elise
# 362     S0082      1                   Emissary
# 363     S0061      1                      HDoor
# 364     S0630      1                    Nebulae
# 365     S0055      1                   RARSTONE
# 366     S0629      1                   RainyDay
# 367     S0058      1                      SslMM
# 368     S0060      1                      Sys10
# 369     S0059      1                      WinMM
# 370     S0444      1                    ShimRat
# 371     S0445      1            ShimRatReporter
# 372     S0547      1                   DropBook
# 373     S0062      1                   DustySky
# 374     S0553      1                    MoleNet
# 375     S0546      1                 SharpStage
# 376     S0543      1                      Spark
# 377     S1033      1                      DCSrv
# 378     S1032      1                   PyDCrypt
# 379     S0258      1                     RGDoor
# 380     S0185      1                 SEASHARPEE
# 381     S0610      1                  SideTwist
# 382     S1151      1                 ZeroCleare
# 383     S0236      1                   Kwampirs
# 384     S0200      1                    Dipsind
# 385     S0201      1                       JPIN
# 386     S0202      1                     adbupd
# 387     S1046      1                    PowGoop
# 388     S0592      1            RemoteUtilities
# 389     S0450      1                 SHARPSTATS
# 390     S1037      1                  STARWHALE
# 391     S1035      1                Small Sieve
# 392     S1124      1                 SocGholish
# 393     S0176      1                   Wingbird
# 394     S0456      1                  Aria-body
# 395     S0130      1             Unknown Logger
# 396     S0010      1                      Lurid
# 397     S1162      1                  Playcrypt
# 398     S0066      1                  3PARA RAT
# 399     S0065      1                     4H RAT
# 400     S0068      1                 httpclient
# 401     S0067      1                  pngdowner
# 402     S0148      1                        RTM
# 403     S0340      1                    Octopus
# 404     S0360      1                BONDUPDATER
# 405     S0170      1                   Helminth
# 406     S0189      1                ISMInjector
# 407     S0264      1                     OopsIE
# 408     S0184      1                   POWRUNER
# 409     S0269      1                  QUADAGENT
# 410     S0495      1                       RDAT
# 411     S0343      1       Exaramel for Windows
# 412     S0342      1                 GreyEnergy
# 413     S0604      1                Industroyer
# 414     S1072      1               Industroyer2
# 415     S0231      1             Invoke-PSImage
# 416     S0368      1                   NotPetya
# 417     S0365      1          Olympic Destroyer
# 418     S1058      1                   Prestige
# 419     S1023      1                CreepyDrive
# 420     S1024      1                CreepySnail
# 421     S0491      1                 StrongPity
# 422     S0178      1                   Truvasys
# 423     S0128      1                    BADNEWS
# 424     S0475      1                 BackConfig
# 425     S0272      1               NDiskMonitor
# 426     S0131      1                 TINYTYPHON
# 427     S1029      1               AuTo Stealer
# 428     S0447      1                    Lokibot
# 429     S0171      1                   Felismus
# 430     S0188      1                 Starloader
# 431     S1140      1                      Spica
# 432     S0125      1                     Remsec
# 433     S0118      1                    Nidiran
# 434     S1087      1                   AsyncRAT
# 435     S0255      1                     DDKONG
# 436     S0254      1                   PLAINTEE
# 437     S1017      1                   OutSteel
# 438     S1125      1                   AcidRain
# 439     S0606      1                 Bad Rabbit
# 440     S0089      1                BlackEnergy
# 441     S0687      1              Cyclops Blink
# 442     S0401      1         Exaramel for Linux
# 443     S0230      1                      ZeroT
# 444     S0344      1                    Azorult
# 445     S0611      1                       Clop
# 446     S0383      1                FlawedGrace
# 447     S0460      1                       Get2
# 448     S0461      1                     SDBbot
# 449     S0382      1                 ServHelper
# 450     S0386      1                     Ursnif
# 451     S0476      1                      Valak
# 452     S1010      1                  VPNFilter
# 453     S0077      1                     CallMe
# 454     S0076      1                      FakeM
# 455     S0079      1                MobileOrder
# 456     S0078      1                      Psylo
# 457     S1068      1                   BlackCat
# 458     S1028      1                 Action RAT
# 459     S0179      1                MimiPenguin
# 460     S0683      1                   Peirates
# 461     S0660      1                  Clambling
# 462     S0398      1                   HyperBro
# 463     S0663      1                  SysUpdate
# 464     S0261      1                  Catchamas
# 465     S1101      1                     LoFiSe
# 466     S1100      1                      Ninja
# 467     S1102      1                    Pcexter
# 468     S1099      1                    Samurai
# 469     S0268      1                    Bisonal
# 470     S0115      1                    Crimson
# 471     S0644      1                 ObliqueRAT
# 472     S1086      1                      Snip3
# 473     S0283      1                       jRAT
# 474     S0033      1                NetTraveler
# 475     S0587      1                    Penquin
# 476     S0393      1              PowerStallion
# 477     S0668      1                  TinyTurla
# 478     S0022      1                   Uroburos
# 479     S0538      1                     Crutch
# 480     S0091      1                       Epic
# 481     S0168      1                      Gazer
# 482     S0537      1                 HyperStack
# 483     S0581      1            IronNetInjector
# 484     S1075      1                  KOPILUWAK
# 485     S0265      1                     Kazuar
# 486     S0395      1                LightNeuron
# 487     S1143      1                LunarLoader
# 488     S1142      1                  LunarMail
# 489     S1145      1                    Pikabot
# 490     S0601      1                  Hildegard
# 491     S1154      1                   VersaMem
# 492     S0345      1                    Seasalt
# 493     S0339      1                  Micropsia
# 494     S0109      1                      WEBC2
# 495     S0017      1                    BISCUIT
# 496     S0025      1                   CALENDAR
# 497     S0042      1                    LOWBALL
# 498     S0144      1                     ChChes
# 499     S0624      1                   Ecipekac
# 500     S0152      1                   EvilGrab
# 501     S0628      1                     FYAnti
# 502     S0626      1                      P8RAT
# 503     S0153      1                  RedLeaves
# 504     S0159      1                   SNUGRIDE
# 505     S0627      1                 SodaMaster
# 506     S0643      1                      Peppy
# 507     S0514      1                   WellMess
# 508     S0175      1                       meek
# 509     S0123      1                       xCmd
# 510     S0015      1                     Ixeshe
# 511     S0003      1                    RIPTIDE
# 512     S0064      1                      ELMER
# 513     S0124      1                  Pisloader
# 514     S0575      1                      Conti
# 515     S0659      1                     Diavol
# 516     S0024      1                       Dyre
# 517     S0367      1                     Emotet
# 518     S1071      1                     Rubeus
# 519     S0043      1                 BUBBLEWRAP
# 520     S0102      1                    nbtstat
# 521     S0572      1       Caterpillar WebShell
# 522     S0569      1                  Explosive

# %%
import pandas as pd
from collections import Counter

def filter_single_use_software(file_path: str):
    """
    Filters the software used by only one APT group, includes the APT group (source name) in the output,
    and checks the 'target ref' column to categorize the software as malware or tool type.

    Args:
        file_path (str): Path to the Excel file.

    Returns:
        pd.DataFrame: A DataFrame containing software used by only one APT group along with the APT group name
                      and categorized by malware or tool type.
    """
    # Load the sheet 'associated groups'
    xls = pd.ExcelFile(file_path)
    df = pd.read_excel(xls, sheet_name='associated groups')

    # Ensure the relevant columns exist
    if 'source name' in df.columns and 'target ID' in df.columns and 'target name' in df.columns and 'target ref' in df.columns:
        # Count occurrences of each target ID and filter for count = 1
        software_counts = df['target ID'].value_counts()
        single_use_software = software_counts[software_counts == 1].index

        # Filter the original DataFrame for software used only once
        filtered_df = df[df['target ID'].isin(single_use_software)][['target ID', 'target name', 'source name', 'target ref']].drop_duplicates()

        # Add a new column categorizing as 'malware' or 'tool'
        filtered_df['category'] = filtered_df['target ref'].apply(lambda x: 'malware' if 'malware' in x.lower() else 'tool')

        return filtered_df
    else:
        raise ValueError("Required columns ('source name', 'target ID', 'target name', 'target ref') are not found in the sheet.")

# %%
file_path = r"C:\Users\Aakanksha Saha\Documents\CTITTP\enterprise-attack-v16.1-software.xlsx" 

# Ensure all rows are shown
pd.set_option('display.max_rows', None)  # Disable row truncation

try:
    # Get and print software used by only one APT group
    single_use_software = filter_single_use_software(file_path)
    print("Software Used by Only One APT Group:")
    print(single_use_software)
except ValueError as e:
    print(e)
# Out:
# Software Used by Only One APT Group:
#     target ID            target name         source name  \
# 0       S0339              Micropsia            APT-C-23
# 2       S0017                BISCUIT                APT1
# 3       S0025               CALENDAR                APT1
# 4       S0119              Cachedump                APT1
# 5       S0026              GLOOXMAIL                APT1
# 6       S0121                Lslsass                APT1
# 9       S0122  Pass-The-Hash Toolkit                APT1
# 12      S0345                Seasalt                APT1
# 14      S0109                  WEBC2                APT1
# 18      S0123                   xCmd                APT1
# 20      S0015                 Ixeshe               APT12
# 21      S0003                RIPTIDE               APT12
# 22      S0064                  ELMER               APT16
# 25      S0124              Pisloader               APT18
# 28      S0071              hcdLoader               APT18
# 31      S0045          ADVSTORESHELL               APT28
# 32      S0023              CHOPSTICK               APT28
# 33      S0137              CORESHELL               APT28
# 34      S0351                 Cannon               APT28
# 35      S0243          DealersChoice               APT28
# 36      S0134              Downdelph               APT28
# 37      S0502               Drovorub               APT28
# 38      S0193               Forfiles               APT28
# 39      S0410                 Fysbis               APT28
# 40      S0135                HIDEDRV               APT28
# 41      S0044               JHUHUGIT               APT28
# 43      S0162                Komplex               APT28
# 44      S0397                  LoJax               APT28
# 47      S0138                OLDBAIT               APT28
# 50      S0136             USBStealer               APT28
# 53      S0161              XAgentOSX               APT28
# 54      S0117                XTunnel               APT28
# 55      S0251                Zebrocy               APT28
# 57      S0677           AADInternals               APT29
# 60      S0635                BoomBox               APT29
# 61      S0054              CloudDuke               APT29
# 63      S0050             CosmicDuke               APT29
# 64      S0046                CozyCar               APT29
# 65      S0634              EnvyScout               APT29
# 66      S0512                FatDuke               APT29
# 67      S0661               FoggyWeb               APT29
# 68      S0049             GeminiDuke               APT29
# 69      S0597             GoldFinder               APT29
# 70      S0588                GoldMax               APT29
# 71      S0037             HAMMERTOSS               APT29
# 73      S0513               LiteDuke               APT29
# 75      S0051               MiniDuke               APT29
# 76      S0637             NativeZone               APT29
# 78      S0052              OnionDuke               APT29
# 79      S0150                POSHSPY               APT29
# 80      S0048              PinchDuke               APT29
# 81      S0518           PolyglotDuke               APT29
# 82      S0139              PowerDuke               APT29
# 84      S1084              QUIETEXIT               APT29
# 85      S0684              ROADTools               APT29
# 86      S0565               Raindrop               APT29
# 87      S0511                RegDuke               APT29
# 89      S0559               SUNBURST               APT29
# 90      S0562                SUNSPOT               APT29
# 91      S0053                SeaDuke               APT29
# 92      S0589                  Sibot               APT29
# 94      S0516               SoreFang               APT29
# 96      S0560               TEARDROP               APT29
# 99      S0682            TrailBlazer               APT29
# 100     S0636              VaporRage               APT29
# 101     S0515               WellMail               APT29
# 102     S0514               WellMess               APT29
# 104     S0175                   meek               APT29
# 106     S0165                 OSInfo                APT3
# 108     S0166              RemoteCMD                APT3
# 109     S0063                SHOTPUT                APT3
# 111     S0031              BACKSPACE               APT30
# 112     S0036             FLASHFLOOD               APT30
# 113     S0034               NETEAGLE               APT30
# 114     S0028              SHIPSHAPE               APT30
# 115     S0035              SPACESHIP               APT30
# 118     S0354                  Denis               APT32
# 119     S0477                  Goopy               APT32
# 120     S0156               KOMPROGO               APT32
# 121     S0585               Kerrdown               APT32
# 124     S0352       OSX_OCEANLOTUS.D               APT32
# 125     S0158                PHOREAL               APT32
# 126     S1078             RotaJakiro               APT32
# 127     S0157              SOUNDBITE               APT32
# 128     S0155             WINDSHIELD               APT32
# 139     S0371               POWERTON               APT33
# 143     S0358                  Ruler               APT33
# 144     S0380             StoneDrill               APT33
# 145     S0199               TURNEDUP               APT33
# 147     S0657              BLUELIGHT               APT37
# 148     S0212              CORALDECK               APT37
# 150     S0213                DOGCALL               APT37
# 151     S0355            Final1stspy               APT37
# 152     S0214              HAPPYWORK               APT37
# 153     S0215                  KARAE               APT37
# 154     S0247                 NavRAT               APT37
# 155     S0216                POORAIM               APT37
# 156     S0240                 ROKRAT               APT37
# 157     S0217           SHUTTERSPEED               APT37
# 158     S0218              SLOWDRIFT               APT37
# 159     S0219               WINERACK               APT37
# 167     S0454               Cadelspy               APT39
# 169     S0459          MechaFlounder               APT39
# 173     S0375                 Remexi               APT39
# 182     S1158                DUSTPAN               APT41
# 183     S1159               DUSTTRAP               APT41
# 187     S1051                KEYPLUG               APT41
# 188     S0443             MESSAGETAP               APT41
# 194     S0112               ROCKBOOT               APT41
# 209     S1109              PACEMAKER                APT5
# 210     S1108             PULSECHECK                APT5
# 211     S1050                PcShare                APT5
# 213     S1113             RAPIDPULSE                APT5
# 214     S1110            SLIGHTPULSE                APT5
# 215     S1104              SLOWPULSE                APT5
# 216     S0007           Skeleton Key                APT5
# 221     S1133                Apostle              Agrius
# 222     S1136           BFG Agonizer              Agrius
# 224     S1132           IPsec Helper              Agrius
# 226     S1137              Moneybird              Agrius
# 227     S1135       MultiLayer Wiper              Agrius
# 229     S0224                  Havij  Ajax Security Team
# 232     S1129                  Akira               Akira
# 237     S0433                Rifdoor            Andariel
# 239     S1027        Heyoka Backdoor        Aoqin Dragon
# 240     S1026                Mongall        Aoqin Dragon
# 248     S0009                  Hikit               Axiom
# 252     S0672                    Zox               Axiom
# 255     S1013                   ZxxZ              BITTER
# 256     S0469                    ABK       BRONZE BUTLER
# 257     S0473                Avenger       BRONZE BUTLER
# 258     S0470                    BBK       BRONZE BUTLER
# 259     S0187                 Daserf       BRONZE BUTLER
# 265     S0471           build_downer       BRONZE BUTLER
# 267     S0472               down_new       BRONZE BUTLER
# 274     S0647                 Turian   BackdoorDiplomacy
# 275     S0696                Flagpro           BlackTech
# 276     S0437                 Kivars           BlackTech
# 277     S0435                  PLEAD           BlackTech
# 279     S0436               TSCookie           BlackTech
# 280     S0579              Waterbear           BlackTech
# 283     S1152             IMAPLoader              CURIUM
# 294     S1096            Cheerscrypt    Cinnamon Tempest
# 303     S0056            Net Crawler             Cleaver
# 305     S0004               TinyZBot             Cleaver
# 311     S0646          SpicyOmelette        Cobalt Group
# 315     S0167             Matryoshka         CopyKittens
# 316     S0164                 TDTESS         CopyKittens
# 318     S1016                  MacMa           Daggerfly
# 319     S1146                  MgBot           Daggerfly
# 320     S1147              Nightdoor           Daggerfly
# 323     S0234                Bandook        Dark Caracal
# 324     S0235               CrossRAT        Dark Caracal
# 325     S0182              FinFisher        Dark Caracal
# 328     S0270             RogueRobin          DarkHydrus
# 332     S0080                 Mivast          Deep Panda
# 335     S0074                 Sakula          Deep Panda
# 336     S0142               StreamEx          Deep Panda
# 340     S0093        Backdoor.Oldrea           Dragonfly
# 343     S0500                   MCMD           Dragonfly
# 348     S0094        Trojan.Karagany           Dragonfly
# 361     S0204                  Briba           Elderwood
# 363     S0211                  Linfo           Elderwood
# 364     S0205                   Naid           Elderwood
# 365     S0210                  Nerex           Elderwood
# 366     S0208                  Pasam           Elderwood
# 368     S0207                Vasport           Elderwood
# 369     S0206                  Wiarp           Elderwood
# 378     S0689            WhisperGate          Ember Bear
# 380     S0568                EVILNUM             Evilnum
# 388     S0173               FLIPSIDE                FIN5
# 390     S0169                 RawPOS                FIN5
# 397     S0503           FrameworkPOS                FIN6
# 399     S0372             LockerGoga                FIN6
# 407     S0415             BOOSTWRITE                FIN7
# 411     S0417                GRIFFON                FIN7
# 412     S0151              HALFBAKED                FIN7
# 413     S0648             JSS Loader                FIN7
# 414     S0681                  Lizar                FIN7
# 417     S0145            POWERSOURCE                FIN7
# 418     S0517             Pillowmint                FIN7
# 420     S0416             RDFSNIFFER                FIN7
# 422     S0390                 SQLRat                FIN7
# 423     S0146               TEXTMATE                FIN7
# 424     S1081               BADHATCH                FIN8
# 428     S0196             PUNCHBUGGY                FIN8
# 429     S0197             PUNCHTRACK                FIN8
# 432     S0481          Ragnar Locker                FIN8
# 433     S1085               Sardonic                FIN8
# 436     S0652               MarkiRAT    Ferocious Kitten
# 438     S0556                Pay2Key          Fox Kitten
# 441     S0564             BlackMould             GALLIUM
# 448     S1031               PingPull             GALLIUM
# 460     S0685             PowerPunch     Gamaredon Group
# 461     S0147             Pteranodon     Gamaredon Group
# 462     S0686             QuietSieve     Gamaredon Group
# 472     S1155               Covenant             HAFNIUM
# 475     S1011                Tarrask             HAFNIUM
# 477     S1014                 DanBot              HEXANE
# 478     S1021              DnsSystem              HEXANE
# 480     S1020                  Kevin              HEXANE
# 481     S1015                  Milan              HEXANE
# 485     S1019                  Shark              HEXANE
# 492     S1139         INC Ransomware          INC Ransom
# 500     S0441            PowerShower           Inception
# 501     S0442               VBShower           Inception
# 502     S0651                BoxCaon         IndigoZebra
# 504     S0653                  xCaon         IndigoZebra
# 505     S0570              BitPaymer       Indrik Spider
# 507     S0695                  Donut       Indrik Spider
# 512     S0612           WastedLocker       Indrik Spider
# 514     S0280              MirageFox            Ke3chang
# 515     S0691               Neoichor            Ke3chang
# 517     S0439                  Okrum            Ke3chang
# 523     S0227            spwebmember            Ke3chang
# 525     S0622              AppleSeed             Kimsuky
# 526     S0414              BabyShark             Kimsuky
# 527     S0252           Brave Prince             Kimsuky
# 528     S0527        CSPY Downloader             Kimsuky
# 529     S0249            Gold Dragon             Kimsuky
# 530     S0526                KGH_SPY             Kimsuky
# 532     S0353                  NOKKI             Kimsuky
# 538     S0584              AppleJeus       Lazarus Group
# 539     S0347              AuditCred       Lazarus Group
# 540     S0245                BADCALL       Lazarus Group
# 541     S0520            BLINDINGCAN       Lazarus Group
# 542     S0239               Bankshot       Lazarus Group
# 543     S0498            Cryptoistic       Lazarus Group
# 544     S0497                  Dacls       Lazarus Group
# 545     S0567                 Dtrack       Lazarus Group
# 547     S0181              FALLCHILL       Lazarus Group
# 548     S0246               HARDRAIN       Lazarus Group
# 550     S0431           HotCroissant       Lazarus Group
# 551     S0271              KEYMARBLE       Lazarus Group
# 552     S0238               Proxysvc       Lazarus Group
# 553     S0241               RATANKBA       Lazarus Group
# 554     S0364                RawDisk       Lazarus Group
# 556     S0586          TAINTEDSCRIBE       Lazarus Group
# 557     S0263              TYPEFRAME       Lazarus Group
# 558     S0665           ThreatNeedle       Lazarus Group
# 559     S0180                Volgmer       Lazarus Group
# 560     S0366               WannaCry       Lazarus Group
# 564     S0669               KOCTOPUS        LazyScripter
# 571     S0413             MailSniper           Leafminer
# 574     S0642               BADFLICK           Leviathan
# 581     S0232                HOMEFRY           Leviathan
# 582     S0233               MURKYTOP           Leviathan
# 583     S0228              NanHaiShu           Leviathan
# 585     S0229                    Orz           Leviathan
# 591     S0081                  Elise       Lotus Blossom
# 592     S0082               Emissary       Lotus Blossom
# 595     S0409                Machete             Machete
# 596     S0674             CharmPower         Magic Hound
# 597     S0186              DownPaper         Magic Hound
# 603     S1012              PowerLess         Magic Hound
# 609     S1122                Mispadu            Malteiro
# 610     S1060                Mafalda             Metador
# 611     S1059               metaMain             Metador
# 613     S0444                ShimRat              Mofang
# 614     S0445        ShimRatReporter              Mofang
# 615     S0547               DropBook            Molerats
# 616     S0062               DustySky            Molerats
# 617     S0553                MoleNet            Molerats
# 619     S0546             SharpStage            Molerats
# 620     S0543                  Spark            Molerats
# 621     S1033                  DCSrv         Moses Staff
# 623     S1032               PyDCrypt         Moses Staff
# 624     S1034            StrifeWater         Moses Staff
# 625     S1088                  Disco   MoustachedBouncer
# 626     S1090              NightClub   MoustachedBouncer
# 627     S1089             SharpDisco   MoustachedBouncer
# 634     S1047                   Mori          MuddyWater
# 635     S0594                   Out1          MuddyWater
# 636     S0223             POWERSTATS          MuddyWater
# 637     S1046                PowGoop          MuddyWater
# 639     S0592        RemoteUtilities          MuddyWater
# 640     S0450             SHARPSTATS          MuddyWater
# 641     S1037              STARWHALE          MuddyWater
# 642     S1035            Small Sieve          MuddyWater
# 649     S1124             SocGholish     Mustard Tempest
# 650     S0176               Wingbird           NEODYMIUM
# 651     S0456              Aria-body              Naikon
# 652     S0061                  HDoor              Naikon
# 653     S0630                Nebulae              Naikon
# 657     S0055               RARSTONE              Naikon
# 658     S0629               RainyDay              Naikon
# 659     S0058                  SslMM              Naikon
# 660     S0060                  Sys10              Naikon
# 663     S0059                  WinMM              Naikon
# 666     S0340                Octopus     Nomadic Octopus
# 667     S0360            BONDUPDATER              OilRig
# 668     S0170               Helminth              OilRig
# 669     S0189            ISMInjector              OilRig
# 673     S0264                 OopsIE              OilRig
# 674     S0184               POWRUNER              OilRig
# 676     S0269              QUADAGENT              OilRig
# 677     S0495                   RDAT              OilRig
# 678     S0258                 RGDoor              OilRig
# 680     S0185             SEASHARPEE              OilRig
# 681     S0610              SideTwist              OilRig
# 684     S1151             ZeroCleare              OilRig
# 690     S0236               Kwampirs          Orangeworm
# 697     S0200                Dipsind            PLATINUM
# 698     S0201                   JPIN            PLATINUM
# 699     S0202                 adbupd            PLATINUM
# 700     S1023            CreepyDrive            POLONIUM
# 701     S1024            CreepySnail            POLONIUM
# 702     S0491             StrongPity          PROMETHIUM
# 703     S0178               Truvasys          PROMETHIUM
# 705     S0128                BADNEWS           Patchwork
# 706     S0475             BackConfig           Patchwork
# 707     S0272           NDiskMonitor           Patchwork
# 710     S0131             TINYTYPHON           Patchwork
# 711     S0130         Unknown Logger           Patchwork
# 712     S0010                  Lurid          PittyTiger
# 723     S1162              Playcrypt                Play
# 726     S0066              3PARA RAT        Putter Panda
# 727     S0065                 4H RAT        Putter Panda
# 728     S0068             httpclient        Putter Panda
# 729     S0067              pngdowner        Putter Panda
# 730     S0148                    RTM                 RTM
# 731     S0255                 DDKONG              Rancor
# 732     S0254               PLAINTEE              Rancor
# 735     S1017               OutSteel          Saint Bear
# 737     S1125               AcidRain       Sandworm Team
# 738     S0606             Bad Rabbit       Sandworm Team
# 739     S0089            BlackEnergy       Sandworm Team
# 741     S0687          Cyclops Blink       Sandworm Team
# 743     S0401     Exaramel for Linux       Sandworm Team
# 744     S0343   Exaramel for Windows       Sandworm Team
# 745     S0342             GreyEnergy       Sandworm Team
# 747     S0604            Industroyer       Sandworm Team
# 748     S1072           Industroyer2       Sandworm Team
# 749     S0231         Invoke-PSImage       Sandworm Team
# 753     S0368               NotPetya       Sandworm Team
# 754     S0365      Olympic Destroyer       Sandworm Team
# 757     S1058               Prestige       Sandworm Team
# 760     S1010              VPNFilter       Sandworm Team
# 761     S0077                 CallMe       Scarlet Mimic
# 762     S0076                  FakeM       Scarlet Mimic
# 763     S0079            MobileOrder       Scarlet Mimic
# 764     S0078                  Psylo       Scarlet Mimic
# 765     S1068               BlackCat    Scattered Spider
# 770     S1028             Action RAT            SideCopy
# 771     S1029           AuTo Stealer            SideCopy
# 778     S0447                Lokibot       SilverTerrier
# 781     S0171               Felismus              Sowbug
# 782     S0188             Starloader              Sowbug
# 783     S1140                  Spica       Star Blizzard
# 784     S0125                 Remsec             Strider
# 785     S0118                Nidiran             Suckfly
# 787     S1087               AsyncRAT              TA2541
# 791     S1086                  Snip3              TA2541
# 793     S0283                   jRAT              TA2541
# 795     S0033            NetTraveler               TA459
# 797     S0230                  ZeroT               TA459
# 801     S0344                Azorult               TA505
# 803     S0611                   Clop               TA505
# 807     S0383            FlawedGrace               TA505
# 808     S0460                   Get2               TA505
# 812     S0461                 SDBbot               TA505
# 813     S0382             ServHelper               TA505
# 817     S0386                 Ursnif               TA551
# 818     S0476                  Valak               TA551
# 820     S1145                Pikabot               TA577
# 827     S0601              Hildegard             TeamTNT
# 829     S0179            MimiPenguin             TeamTNT
# 830     S0683               Peirates             TeamTNT
# 837     S0660              Clambling   Threat Group-3390
# 840     S0398               HyperBro   Threat Group-3390
# 848     S0663              SysUpdate   Threat Group-3390
# 859     S0261              Catchamas               Thrip
# 864     S1101                 LoFiSe            ToddyCat
# 866     S1100                  Ninja            ToddyCat
# 867     S1102                Pcexter            ToddyCat
# 869     S1099                Samurai            ToddyCat
# 871     S0268                Bisonal          Tonto Team
# 877     S0115                Crimson   Transparent Tribe
# 879     S0644             ObliqueRAT   Transparent Tribe
# 880     S0643                  Peppy   Transparent Tribe
# 883     S0387                 KeyBoy      Tropic Trooper
# 886     S0452               USBferry      Tropic Trooper
# 887     S0388                YAHOYAH      Tropic Trooper
# 889     S0335                 Carbon               Turla
# 890     S0126                 ComRAT               Turla
# 891     S0538                 Crutch               Turla
# 893     S0091                   Epic               Turla
# 894     S0168                  Gazer               Turla
# 895     S0537             HyperStack               Turla
# 896     S0581        IronNetInjector               Turla
# 897     S1075              KOPILUWAK               Turla
# 898     S0265                 Kazuar               Turla
# 899     S0395            LightNeuron               Turla
# 900     S1143            LunarLoader               Turla
# 901     S1142              LunarMail               Turla
# 902     S1141               LunarWeb               Turla
# 904     S0256               Mosquito               Turla
# 907     S0587                Penquin               Turla
# 908     S0393          PowerStallion               Turla
# 913     S0668              TinyTurla               Turla
# 914     S0022               Uroburos               Turla
# 916     S0102                nbtstat               Turla
# 918     S0572   Caterpillar WebShell      Volatile Cedar
# 919     S0569              Explosive      Volatile Cedar
# 930     S1154               VersaMem        Volt Typhoon
# 938     S0679              Ferocious               WIRTE
# 939     S0680              LitePower               WIRTE
# 941     S0377                  Ebury             Windigo
# 942     S0466               WindTail           Windshift
# 943     S0501                PipeMon        Winnti Group
# 947     S0504                 Anchor       Wizard Spider
# 952     S0575                  Conti       Wizard Spider
# 953     S0659                 Diavol       Wizard Spider
# 954     S0024                   Dyre       Wizard Spider
# 955     S0367                 Emotet       Wizard Spider
# 964     S1071                 Rubeus       Wizard Spider
# 967     S0043             BUBBLEWRAP           admin@338
# 968     S0042                LOWBALL           admin@338
# 975     S0144                 ChChes            menuPass
# 977     S0624               Ecipekac            menuPass
# 978     S0152               EvilGrab            menuPass
# 979     S0628                 FYAnti            menuPass
# 984     S0626                  P8RAT            menuPass
# 991     S0153              RedLeaves            menuPass
# 992     S0159               SNUGRIDE            menuPass
# 993     S0627             SodaMaster            menuPass
# 994     S0275               UPPERCUT            menuPass
#
#                                         target ref category
# 0    malware--8c050cea-86e1-4b63-bf21-7af4fa483349  malware
# 2    malware--b8eb28e4-48a6-40ae-951a-328714f75eda  malware
# 3    malware--5a84dc36-df0d-4053-9b7c-f0c388a57283  malware
# 4       tool--c9cd7ec9-40b7-49db-80be-1399eddd9c52     tool
# 5    malware--f2e8c7a1-cae1-45c4-baf0-6f21bdcbb2c2  malware
# 6       tool--2fab555f-7664-4623-b4e0-1675ae38190b     tool
# 9       tool--a52edc76-328d-4596-85e7-d56ef5a9eb69     tool
# 12   malware--b45747dc-87ca-4597-a245-7e16a61bc491  malware
# 14   malware--1d808f62-cf63-4063-9727-ff6132514c22  malware
# 18      tool--4fa49fc0-9162-4bdb-a37e-7aa3dcb6d38b     tool
# 20   malware--8beac7c2-48d2-4cd9-9b15-6c452f38ac06  malware
# 21   malware--ad4f146f-e3ec-444a-ba71-24bffd7f0f8e  malware
# 22   malware--3cab1b76-2f40-4cd0-8d2c-7ed16eeb909c  malware
# 25   malware--b96680d1-5eb3-4f07-b95c-00ab904ac236  malware
# 28   malware--9e2bba94-950b-4fcf-8070-cb3f816c5f4e  malware
# 31   malware--fb575479-14ef-41e9-bfab-0b7cf10bec73  malware
# 32   malware--ccd61dfc-b03f-4689-8c18-7c97eab08472  malware
# 33   malware--60c18d06-7b91-4742-bae3-647845cd9d81  malware
# 34   malware--d20b397a-ea47-48a9-b503-2e2a3551e11d  malware
# 35   malware--8f460983-1bbb-4e7e-8094-f0b5e720f658  malware
# 36   malware--08d20cd2-f084-45ee-8558-fa6ef5a18519  malware
# 37   malware--99164b38-1775-40bc-b77b-a2373b14540a  malware
# 38      tool--90ec2b22-7061-4469-b539-0989ec4f96c2     tool
# 39   malware--50d6688b-0985-4f3d-8cbe-0c796b30703b  malware
# 40   malware--e669bb87-f773-4c7b-bfcc-a9ffebfdd8d4  malware
# 41   malware--8ae43c46-57ef-47d5-a77a-eebb35628db2  malware
# 43   malware--f108215f-3487-489d-be8b-80e346d32518  malware
# 44   malware--b865dded-0553-4962-a44b-6fe7863effed  malware
# 47   malware--2dd34b01-6110-4aac-835d-b5e7b936b0be  malware
# 50   malware--af2ad3b7-ab6a-4807-91fd-51bcaff9acbb  malware
# 930  malware--0a6ec267-83a9-41a5-98c7-57c3ff81e11f  malware
# 938  malware--73d08401-005f-4e1f-90b9-8f45d120879f  malware
# 939  malware--9020f5c7-efde-4125-a4f1-1b70f1274ddd  malware
# 941  malware--d6b3fcd0-1c86-4350-96f0-965ed02fcc51  malware
# 942  malware--0d1f9f5b-11ea-42c3-b5f4-63cce0122541  malware
# 943  malware--8393dac0-0583-456a-9372-fd81691bca20  malware
# 947  malware--5f1d4579-4e8f-48e7-860e-2da773ae432e  malware
# 952  malware--4dea7d8e-af94-4bfb-afe4-7ff54f59308b  malware
# 953  malware--4e9bdf9a-4957-47f6-87b3-c76898d3f623  malware
# 954  malware--63c2a130-8a5b-452f-ad96-07cf0af12ffe  malware
# 955  malware--32066e94-3112-48ca-b9eb-ba2b59d2f023  malware
# 964     tool--e33267fe-099f-4af2-8730-63d49f8813b2     tool
# 967  malware--123bd7b3-675c-4b1a-8482-c55782b20e2b  malware
# 968  malware--2a6f4c7b-e690-4cc7-ab6b-1f821fb6b80b  malware
# 975  malware--dc5d1a33-62aa-4a0c-aa8c-589b87beb11e  malware
# 977  malware--292eb0c5-b8e8-4af6-9e8f-0fda6b4528d3  malware
# 978  malware--2f1a9fd0-3b7c-4d77-a358-78db13adbe78  malware
# 979  malware--434ba392-ebdc-488b-b1ef-518deea65774  malware
# 984  malware--7c58fff0-d206-4db1-96b1-e3a9e0e320b9  malware
# 991  malware--17b40f60-729f-4fe8-8aea-cc9ee44a95d5  malware
# 992  malware--3240cbe4-c550-443b-aa76-cc2a7058b870  malware
# 993  malware--94d6d788-07bb-4dcc-b62f-e02626b00108  malware
# 994  malware--fb4e3792-e915-4fdd-a9cd-92dfa2ace7aa  malware

# %%
import pandas as pd

def filter_unique_software_for_groups(file_path: str):
    """
    Finds the software used by only one APT group, which is not shared with any other group.
    
    Args:
        file_path (str): Path to the Excel file.

    Returns:
        pd.DataFrame: A DataFrame containing groups with their unique software.
    """
    # Load the sheet 'associated groups'
    xls = pd.ExcelFile(file_path)
    df = pd.read_excel(xls, sheet_name='associated groups')

    # Ensure the relevant columns exist
    if 'source name' in df.columns and 'target ID' in df.columns and 'target name' in df.columns and 'target ref' in df.columns:
        
        # Count occurrences of each target ID (software) across all groups
        software_counts = df['target ID'].value_counts()

        # Filter the software that is used only once
        unique_software_ids = software_counts[software_counts == 1].index

        # Filter the original DataFrame for software used only once
        filtered_df = df[df['target ID'].isin(unique_software_ids)][['target ID', 'target name', 'source name', 'target ref']].drop_duplicates()

        # Find the APT group names for the unique software
        unique_software_groups = filtered_df.groupby('source name').agg({'target ID': 'count'}).reset_index()
        unique_software_groups = unique_software_groups.rename(columns={'target ID': 'unique_software_count'})

        return unique_software_groups
    else:
        raise ValueError("Required columns ('source name', 'target ID', 'target name', 'target ref') are not found in the sheet.")

# %%
# Example usage:
file_path = r"C:\Users\ricewater\Documents\CTITTP\ATTACK Excel sheets\enterprise-attack-v16.1-software.xlsx"
unique_software_groups = filter_unique_software_for_groups(file_path)

# Print the result
print(len(unique_software_groups))
# Out:
# 115
