# %%
import pandas as pd
import json
import math
import os
import csv

# Step 1: Load configuration from a JSON file
with open("config.json", "r") as config_file:
    config = json.load(config_file)


# Step 2: Extract the data directory and file paths from the configuration
data_directory = config["data_directory"]
file_paths = {key: os.path.join(data_directory, value) for key, value in config["file_paths_software_v16"].items()}

# %%
# Function to load software from an Excel file and create a dictionary
def load_software_from_excel(file_path, sheet_name):
    # Read the Excel file
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    # Extract the relevant columns: 'ID', 'name', 'aliases', 'type'
    df_subset = df[['ID', 'name', 'aliases', 'type']]
    # Create a dictionary for the software
    software_dict = {}
    for _, row in df_subset.iterrows():
        software_id = row['ID']
        software_name = row['name']
        aliases = row['aliases']
        type_software = row['type']

        # Check if aliases is NaN (or empty) and replace it with an empty list
        if isinstance(aliases, float) and math.isnan(aliases):
            aliases = []  # Replace NaN with an empty list
        # If aliases is a string, convert it to a list
        elif isinstance(aliases, str):
            aliases = [aliases]  # Convert single string to list
        
        # Add the software information to the dictionary
        software_dict[software_id] = {
            'name': software_name,
            'aliases': aliases, 
            'type': type_software
        }
    return software_dict

# %%
# Step 3: Define a function to load the software mappings for the given attack type
def load_attack_software(attack_type, sheet_name="software"):
    file_path = file_paths.get(attack_type)
    if file_path:
        return load_software_from_excel(file_path, sheet_name=sheet_name)
    else:
        raise ValueError(f"Invalid attack type: {attack_type}")

# Step 4: Load the software mappings by specifying the attack type
enterprise_software = load_attack_software("enterprise")
ics_software = load_attack_software("ics")
mobile_software = load_attack_software("mobile")


# Step 4: Identify and add unique ICS and Mobile software IDs not in Enterprise
for software_id, software_info in ics_software.items():
    if software_id not in enterprise_software:
        # Add the unique ICS software to the enterprise software mapping
        enterprise_software[software_id] = software_info

for software_id, software_info in mobile_software.items():
    if software_id not in enterprise_software:
        # Add the unique Mobile software to the enterprise software mapping
        enterprise_software[software_id] = software_info

# %%
# Step 6: Display the counts and first few entries
print(f"\nTotal software in updated mapping: {len(enterprise_software)}")
print("\nSome example software mappings:")
for software_id, software_info in list(enterprise_software.items())[:5]:  # Display first 5 for example
    print(f"ID: {software_id}, Name: {software_info['name']}, Type: {software_info['type']}, Aliases: {software_info['aliases']}")
# Out:
# Total software in updated mapping: 826
#
# Some example software mappings:
# ID: S0066, Name: 3PARA RAT, Type: malware, Aliases: []
# ID: S0065, Name: 4H RAT, Type: malware, Aliases: []
# ID: S0677, Name: AADInternals, Type: tool, Aliases: []
# ID: S0469, Name: ABK, Type: malware, Aliases: []
# ID: S0045, Name: ADVSTORESHELL, Type: malware, Aliases: ['AZZY, EVILTOSS, NETUI, Sedreco']

# %%
# # Step 5: Optionally, export the updated software mapping to a new JSON file (relative path)
# output_directory = "data/output"
# os.makedirs(output_directory, exist_ok=True)  # Create the output directory if it doesn't exist
# output_file_path = os.path.join(output_directory, 'software_mapping_MITRE.json')
# with open(output_file_path, 'w') as f:
#     json.dump(enterprise_software, f, indent=4)

# %%
# Initialize counters for malware and tool
malware_count = 0
tool_count = 0

# Loop through the enterprise_software to count malware and tool types
for software_info in enterprise_software.values():
    if software_info['type'] == 'malware':
        malware_count += 1
    elif software_info['type'] == 'tool':
        tool_count += 1

# Step 6: Display the counts and first few entries
print(f"\nTotal software in updated mapping: {len(enterprise_software)}")
print(f"Total malware count: {malware_count}")
print(f"Total tool count: {tool_count}")
# Out:
# Total software in updated mapping: 826
# Total malware count: 736
# Total tool count: 90

# %%
# Function to read malware families from the JSON file
def read_malware_families_from_file():
    try:
        with open('malware_families.json', 'r') as json_file:
            families_data = json.load(json_file)
            return families_data
    except FileNotFoundError:
        print("Malware families JSON file not found.")
        return None

# %%
# Load the MITRE software mappings (from the generated JSON file)
def read_mitre_software_file():
    software_mappings_file_path = 'data/output/software_mapping_MITRE.json'  # Replace with actual path to MITRE software mappings
    try:
        with open(software_mappings_file_path, 'r') as f:
            mitre_software_mappings = json.load(f)
            return mitre_software_mappings
    except FileNotFoundError:
        print("MITRE Software Mapping JSON file not found.")
        return None

# %%
import re

# Helper function to normalize names for better matching
def normalize_name(name):
    # Convert to lowercase
    name = name.lower()
    
    # Replace underscores followed by 'rat' with ' rat'
    name = re.sub(r'_rat$', ' rat', name)
    
    # Replace underscores in general with spaces
    name = name.replace('_', ' ')
    
    # Remove common malware prefixes like 'trojan.' or 'win.'
    name = re.sub(r'^(trojan\.|win\.)', '', name)
    
    return name

# %%
def find_software_intersection_with_malpedia(malpedia_families_data, mitre_software_mappings):
    intersection = []  # Store MITRE software that intersect with Malpedia actors
    unique_group_ids = set()  # To store unique group IDs for intersection
    mitre_software_not_in_malpedia = []  # Store MITRE software not found in Malpedia

    # Loop through each MITRE software in mitre_software_mappings
    for software_id, software_info in mitre_software_mappings.items():
        software_name = normalize_name(software_info['name'])# Normalize to lowercase for comparison

        # Handle cases where 'aliases' might be NaN or other non-list types
        aliases = software_info.get('aliases', [])
        if isinstance(aliases, float) or aliases is None:  # Check if it's NaN or None
            aliases = []  # Set to empty list
        else:
            aliases = [normalize_name(alias) for alias in aliases]   # Normalize aliases to lowercase

        found_match = False

        # Loop through each Malpedia family in malpedia_families_data
        for family_id, family_info in malpedia_families_data.items():
            family_name = normalize_name(family_id)  # Normalize Malpedia family name
            common_name = normalize_name(family_info.get('common_name', ''))  # Normalize common name
            alt_names = [normalize_name(alt_name) for alt_name in family_info.get('alt_names', [])]  # Normalize alt_names

            # Check if software_name or aliases match with Malpedia family_name, common_name, or alt_names
            if software_name == family_name or software_name == common_name or software_name in alt_names:
                intersection.append((software_name, family_name, software_id))  # Found intersection with software_name
                unique_group_ids.add(software_id)
                found_match = True
                break  # No need to check further if match is found
            elif any(alias == family_name or alias == common_name or alias in alt_names for alias in aliases):
                intersection.append((software_name, family_name, software_id))  # Found intersection with alias
                unique_group_ids.add(software_id)
                found_match = True
                break

        # If no match was found for this MITRE software, add it to the "not in Malpedia" list
        if not found_match:
            mitre_software_not_in_malpedia.append((software_name, software_id))

    return intersection, unique_group_ids, mitre_software_not_in_malpedia

# %%
malpedia_families_data = read_malware_families_from_file()
mitre_software_mappings = read_mitre_software_file()
# Find the intersection
intersection, unique_group_ids, mitre_software_not_in_malpedia = find_software_intersection_with_malpedia(malpedia_families_data, mitre_software_mappings)

# %%
# # Print the intersection results
print(f"Total intersection based on unique software IDs: {len(unique_group_ids)}")
if intersection:
    print("\nIntersection found between MITRE software and Malpedia families:")
    for software_name, family_name, software_id in intersection:
        print(f"MITRE Software: {software_name} | Malpedia Family: {family_name} | Software ID: {software_id}")
else:
    print("No intersection found between MITRE software and Malpedia families.")

# Initialize counters for malware and tool
malware_count = 0
tool_count = 0

# Print the MITRE software not present in Malpedia
if mitre_software_not_in_malpedia:
    print(f"\nTotal MITRE software not present in Malpedia: {len(mitre_software_not_in_malpedia)}")

    for software_name, software_id in mitre_software_not_in_malpedia:
        # Get the type of software from mitre_software_mappings using the software_id
        software_type = mitre_software_mappings.get(software_id, {}).get('type', 'Unknown').strip().lower()

        # Increment the malware/tool counters based on the type
        if software_type == 'malware':
            malware_count += 1
        elif software_type == 'tool':
            tool_count += 1

        print(f"MITRE Software: {software_name.strip()} | Software ID: {software_id} | Type: {software_type.capitalize()}")

    # Print the summary of malware and tools count
    print(f"\nTotal Malwares: {malware_count}")
    print(f"Total Tools: {tool_count}")
# Out:
# Total intersection based on unique software IDs: 511
#
# Intersection found between MITRE software and Malpedia families:
# MITRE Software: 4h rat | Malpedia Family: 4h rat | Software ID: S0065
# MITRE Software: andromeda | Malpedia Family: andromeda | Software ID: S1074
# MITRE Software: aspxspy | Malpedia Family: php.aspxspy | Software ID: S0073
# MITRE Software: acidrain | Malpedia Family: elf.acidrain | Software ID: S1125
# MITRE Software: action rat | Malpedia Family: action rat | Software ID: S1028
# MITRE Software: agent tesla | Malpedia Family: agent tesla | Software ID: S0331
# MITRE Software: agent.btz | Malpedia Family: agent btz | Software ID: S0092
# MITRE Software: akira | Malpedia Family: elf.akira | Software ID: S1129
# MITRE Software: amadey | Malpedia Family: amadey | Software ID: S1025
# MITRE Software: anchor | Malpedia Family: anchor | Software ID: S0504
# MITRE Software: apostle | Malpedia Family: apostle | Software ID: S1133
# MITRE Software: applejeus | Malpedia Family: osx.applejeus | Software ID: S0584
# MITRE Software: appleseed | Malpedia Family: appleseed | Software ID: S0622
# MITRE Software: aria-body | Malpedia Family: ariabody | Software ID: S0456
# MITRE Software: astaroth | Malpedia Family: astaroth | Software ID: S0373
# MITRE Software: asyncrat | Malpedia Family: asyncrat | Software ID: S1087
# MITRE Software: attor | Malpedia Family: attor | Software ID: S0438
# MITRE Software: avaddon | Malpedia Family: avaddon | Software ID: S0640
# MITRE Software: avoslocker | Malpedia Family: elf.avoslocker | Software ID: S1053
# MITRE Software: azorult | Malpedia Family: azorult | Software ID: S0344
# MITRE Software: backspace | Malpedia Family: backspace | Software ID: S0031
# MITRE Software: badcall | Malpedia Family: apk.badcall | Software ID: S0245
# MITRE Software: badflick | Malpedia Family: badflick | Software ID: S0642
# MITRE Software: badhatch | Malpedia Family: badhatch | Software ID: S1081
# MITRE Software: badnews | Malpedia Family: badnews | Software ID: S0128
# MITRE Software: bbsrat | Malpedia Family: bbsrat | Software ID: S0127
# MITRE Software: biscuit | Malpedia Family: biscuit | Software ID: S0017
# MITRE Software: blackcoffee | Malpedia Family: blackcoffee | Software ID: S0069
# MITRE Software: blindingcan | Malpedia Family: blindingcan | Software ID: S0520
# MITRE Software: bluelight | Malpedia Family: bluelight | Software ID: S0657
# MITRE Software: bondupdater | Malpedia Family: ps1.bondupdater | Software ID: S0360
# MITRE Software: boostwrite | Malpedia Family: boostwrite | Software ID: S0415
# MITRE Software: bpfdoor | Malpedia Family: elf.bpfdoor | Software ID: S1161
# MITRE Software: bs2005 | Malpedia Family: bs2005 | Software ID: S0014
# MITRE Software: bubblewrap | Malpedia Family: bubblewrap | Software ID: S0043
# MITRE Software: babuk | Malpedia Family: elf.babuk | Software ID: S0638
# MITRE Software: babyshark | Malpedia Family: babyshark | Software ID: S0414
# MITRE Software: backconfig | Malpedia Family: backconfig | Software ID: S0475
# MITRE Software: badpatch | Malpedia Family: apk.badpatch | Software ID: S0337
# MITRE Software: bandook | Malpedia Family: bandook | Software ID: S0234
# MITRE Software: bankshot | Malpedia Family: bankshot | Software ID: S0239
# MITRE Software: bisonal | Malpedia Family: korlia | Software ID: S0268
# MITRE Software: bitpaymer | Malpedia Family: friedex | Software ID: S0570
# MITRE Software: black basta | Malpedia Family: elf.blackbasta | Software ID: S1070
# MITRE Software: blackcat | Malpedia Family: elf.blackcat | Software ID: S1068
# MITRE Software: blackenergy | Malpedia Family: blackenergy | Software ID: S0089
# MITRE Software: boombox | Malpedia Family: boombox | Software ID: S0635
# MITRE Software: boxcaon | Malpedia Family: boxcaon | Software ID: S0651
# MITRE Software: brute ratel c4 | Malpedia Family: brute ratel c4 | Software ID: S1063
# MITRE Software: bumblebee | Malpedia Family: bumblebee | Software ID: S1039
# MITRE Software: bundlore | Malpedia Family: osx.bundlore | Software ID: S0482
# MITRE Software: carrotball | Malpedia Family: carrotball | Software ID: S0465
# MITRE Software: carrotbat | Malpedia Family: carrotbat | Software ID: S0462
# MITRE Software: chopstick | Malpedia Family: elf.xagent | Software ID: S0023
# MITRE Software: coreshell | Malpedia Family: coreshell | Software ID: S0137
# MITRE Software: caddywiper | Malpedia Family: caddywiper | Software ID: S0693
# MITRE Software: cadelspy | Malpedia Family: cadelspy | Software ID: S0454
# MITRE Software: calisto | Malpedia Family: osx.proton rat | Software ID: S0274
# MITRE Software: cannon | Malpedia Family: cannon | Software ID: S0351
# MITRE Software: carbanak | Malpedia Family: carbanak | Software ID: S0030
# MITRE Software: carberp | Malpedia Family: carberp | Software ID: S0484
# MITRE Software: carbon | Malpedia Family: cobra | Software ID: S0335
# MITRE Software: cardinal rat | Malpedia Family: cardinal rat | Software ID: S0348
# MITRE Software: catchamas | Malpedia Family: catchamas | Software ID: S0261
# MITRE Software: chches | Malpedia Family: chches | Software ID: S0144
# MITRE Software: chaes | Malpedia Family: chaes | Software ID: S0631
# MITRE Software: chaos | Malpedia Family: elf.chaos | Software ID: S0220
# MITRE Software: cherry picker | Malpedia Family: cherry picker | Software ID: S0107
# MITRE Software: chinoxy | Malpedia Family: chinoxy | Software ID: S1041
# MITRE Software: clambling | Malpedia Family: clambling | Software ID: S0660
# MITRE Software: clop | Malpedia Family: elf.clop | Software ID: S0611
# MITRE Software: cloudduke | Malpedia Family: cloud duke | Software ID: S0054
# MITRE Software: cobalt strike | Malpedia Family: cobalt strike | Software ID: S0154
# MITRE Software: cobian rat | Malpedia Family: cobian rat | Software ID: S0338
# MITRE Software: comrat | Malpedia Family: agent btz | Software ID: S0126
# MITRE Software: conficker | Malpedia Family: conficker | Software ID: S0608
# MITRE Software: conti | Malpedia Family: elf.conti | Software ID: S0575
# MITRE Software: cosmicduke | Malpedia Family: cosmicduke | Software ID: S0050
# MITRE Software: cozycar | Malpedia Family: cozyduke | Software ID: S0046
# MITRE Software: creepysnail | Malpedia Family: creepysnail | Software ID: S1024
# MITRE Software: crimson | Malpedia Family: crimson | Software ID: S0115
# MITRE Software: crossrat | Malpedia Family: jar.crossrat | Software ID: S0235
# MITRE Software: crutch | Malpedia Family: crutch | Software ID: S0538
# MITRE Software: cuba | Malpedia Family: cuba | Software ID: S0625
# MITRE Software: dcsrv | Malpedia Family: dcsrv | Software ID: S1033
# MITRE Software: ddkong | Malpedia Family: ddkong | Software ID: S0255
# MITRE Software: deadwood | Malpedia Family: deadwood | Software ID: S1134
# MITRE Software: deathransom | Malpedia Family: deathransom | Software ID: S0616
# MITRE Software: dogcall | Malpedia Family: rokrat | Software ID: S0213
# MITRE Software: dratzarus | Malpedia Family: dratzarus | Software ID: S0694
# MITRE Software: dustpan | Malpedia Family: dustpan | Software ID: S1158
# MITRE Software: dusttrap | Malpedia Family: dusttrap | Software ID: S1159
# MITRE Software: dacls | Malpedia Family: elf.dacls | Software ID: S0497
# MITRE Software: danbot | Malpedia Family: danbot | Software ID: S1014
# MITRE Software: darkcomet | Malpedia Family: darkcomet | Software ID: S0334
# MITRE Software: darkgate | Malpedia Family: darkgate | Software ID: S1111
# MITRE Software: darktortilla | Malpedia Family: darktortilla | Software ID: S1066
# MITRE Software: darkwatchman | Malpedia Family: js.darkwatchman | Software ID: S0673
# MITRE Software: daserf | Malpedia Family: daserf | Software ID: S0187
# MITRE Software: denis | Malpedia Family: soundbite | Software ID: S0354
# MITRE Software: derusbi | Malpedia Family: elf.derusbi | Software ID: S0021
# MITRE Software: diavol | Malpedia Family: diavol | Software ID: S0659
# MITRE Software: dipsind | Malpedia Family: redsalt | Software ID: S0200
# MITRE Software: dok | Malpedia Family: apk.retefe | Software ID: S0281
# MITRE Software: doki | Malpedia Family: elf.doki | Software ID: S0600
# MITRE Software: donut | Malpedia Family: donut injector | Software ID: S0695
# MITRE Software: downpaper | Malpedia Family: downpaper | Software ID: S0186
# MITRE Software: downdelph | Malpedia Family: downdelph | Software ID: S0134
# MITRE Software: dridex | Malpedia Family: dridex | Software ID: S0384
# MITRE Software: dropbook | Malpedia Family: dropbook | Software ID: S0547
# MITRE Software: dtrack | Malpedia Family: dtrack | Software ID: S0567
# MITRE Software: duqu | Malpedia Family: duqu | Software ID: S0038
# MITRE Software: dyre | Malpedia Family: dyre | Software ID: S0024
# MITRE Software: eccentricbandwagon | Malpedia Family: pslogger | Software ID: S0593
# MITRE Software: ekans | Malpedia Family: snake | Software ID: S0605
# MITRE Software: elmer | Malpedia Family: elmer | Software ID: S0064
# MITRE Software: evilnum | Malpedia Family: js.evilnum | Software ID: S0568
# MITRE Software: ebury | Malpedia Family: elf.ebury | Software ID: S0377
# MITRE Software: egregor | Malpedia Family: egregor | Software ID: S0554
# MITRE Software: elise | Malpedia Family: elise | Software ID: S0081
# MITRE Software: emissary | Malpedia Family: emissary | Software ID: S0082
# MITRE Software: emotet | Malpedia Family: emotet | Software ID: S0367
# MITRE Software: envyscout | Malpedia Family: envyscout | Software ID: S0634
# MITRE Software: epic | Malpedia Family: wipbot | Software ID: S0091
# MITRE Software: evilbunny | Malpedia Family: evilbunny | Software ID: S0396
# MITRE Software: evilgrab | Malpedia Family: evilgrab | Software ID: S0152
# MITRE Software: fallchill | Malpedia Family: volgmer | Software ID: S0181
# MITRE Software: felixroot | Malpedia Family: felixroot | Software ID: S0267
# MITRE Software: fivehands | Malpedia Family: fivehands | Software ID: S0618
# MITRE Software: flashflood | Malpedia Family: flashflood | Software ID: S0036
# MITRE Software: fatduke | Malpedia Family: fatduke | Software ID: S0512
# MITRE Software: felismus | Malpedia Family: felismus | Software ID: S0171
# MITRE Software: finfisher | Malpedia Family: apk.finfisher | Software ID: S0182
# MITRE Software: final1stspy | Malpedia Family: final1stspy | Software ID: S0355
# MITRE Software: flagpro | Malpedia Family: flagpro | Software ID: S0696
# MITRE Software: flame | Malpedia Family: flame | Software ID: S0143
# MITRE Software: flawedammyy | Malpedia Family: flawedammyy | Software ID: S0381
# MITRE Software: flawedgrace | Malpedia Family: flawedgrace | Software ID: S0383
# MITRE Software: frameworkpos | Malpedia Family: grateful pos | Software ID: S0503
# MITRE Software: fruitfly | Malpedia Family: osx.fruitfly | Software ID: S0277
# MITRE Software: funnydream | Malpedia Family: funny dream | Software ID: S1044
# MITRE Software: fysbis | Malpedia Family: elf.xagent | Software ID: S0410
# MITRE Software: glooxmail | Malpedia Family: glooxmail | Software ID: S0026
# MITRE Software: griffon | Malpedia Family: js.griffon | Software ID: S0417
# MITRE Software: gazer | Malpedia Family: gazer | Software ID: S0168
# MITRE Software: geminiduke | Malpedia Family: geminiduke | Software ID: S0049
# MITRE Software: get2 | Malpedia Family: get2 | Software ID: S0460
# MITRE Software: gold dragon | Malpedia Family: gold dragon | Software ID: S0249
# MITRE Software: goldmax | Malpedia Family: goldmax | Software ID: S0588
# MITRE Software: goldenspy | Malpedia Family: goldenspy | Software ID: S0493
# MITRE Software: gootloader | Malpedia Family: js.gootloader | Software ID: S1138
# MITRE Software: grandoreiro | Malpedia Family: grandoreiro | Software ID: S0531
# MITRE Software: greyenergy | Malpedia Family: grey energy | Software ID: S0342
# MITRE Software: grimagent | Malpedia Family: grimagent | Software ID: S0632
# MITRE Software: guloader | Malpedia Family: cloudeye | Software ID: S0561
# MITRE Software: h1n1 | Malpedia Family: h1n1 | Software ID: S0132
# MITRE Software: halfbaked | Malpedia Family: vbs.halfbaked | Software ID: S0151
# MITRE Software: hammertoss | Malpedia Family: tdiscoverer | Software ID: S0037
# MITRE Software: hardrain | Malpedia Family: apk.hardrain | Software ID: S0246
# MITRE Software: hawkball | Malpedia Family: hawkball | Software ID: S0391
# MITRE Software: hellokitty | Malpedia Family: elf.hellokitty | Software ID: S0617
# MITRE Software: hidedrv | Malpedia Family: hidedrv | Software ID: S0135
# MITRE Software: homefry | Malpedia Family: homefry | Software ID: S0232
# MITRE Software: hoplight | Malpedia Family: hoplight | Software ID: S0376
# MITRE Software: htran | Malpedia Family: htran | Software ID: S0040
# MITRE Software: httpbrowser | Malpedia Family: httpbrowser | Software ID: S0070
# MITRE Software: hui loader | Malpedia Family: hui loader | Software ID: S1097
# MITRE Software: hancitor | Malpedia Family: hancitor | Software ID: S0499
# MITRE Software: helminth | Malpedia Family: helminth | Software ID: S0170
# MITRE Software: hermeticwiper | Malpedia Family: hermeticwiper | Software ID: S0697
# MITRE Software: hermeticwizard | Malpedia Family: hermeticwizard | Software ID: S0698
# MITRE Software: hiddenwasp | Malpedia Family: elf.hiddenwasp | Software ID: S0394
# MITRE Software: hikit | Malpedia Family: hikit | Software ID: S0009
# MITRE Software: hotcroissant | Malpedia Family: hotcroissant | Software ID: S0431
# MITRE Software: hydraq | Malpedia Family: 9002 | Software ID: S0203
# MITRE Software: hyperbro | Malpedia Family: hyperbro | Software ID: S0398
# MITRE Software: hyperstack | Malpedia Family: turla silentmoon | Software ID: S0537
# MITRE Software: imaploader | Malpedia Family: imap loader | Software ID: S1152
# MITRE Software: icedid | Malpedia Family: icedid | Software ID: S0483
# MITRE Software: industroyer | Malpedia Family: industroyer | Software ID: S0604
# MITRE Software: industroyer2 | Malpedia Family: industroyer2 | Software ID: S1072
# MITRE Software: innaputrat | Malpedia Family: innaput rat | Software ID: S0259
# MITRE Software: invisimole | Malpedia Family: invisimole | Software ID: S0260
# MITRE Software: ironnetinjector | Malpedia Family: ironnetinjector | Software ID: S0581
# MITRE Software: jcry | Malpedia Family: jcry | Software ID: S0389
# MITRE Software: jhuhugit | Malpedia Family: osx.komplex | Software ID: S0044
# MITRE Software: janicab | Malpedia Family: osx.janicab | Software ID: S0163
# MITRE Software: keymarble | Malpedia Family: keymarble | Software ID: S0271
# MITRE Software: keyplug | Malpedia Family: elf.keyplug | Software ID: S1051
# MITRE Software: kgh spy | Malpedia Family: kgh spy | Software ID: S0526
# MITRE Software: komprogo | Malpedia Family: komprogo | Software ID: S0156
# MITRE Software: konni | Malpedia Family: apk.konni | Software ID: S0356
# MITRE Software: kopiluwak | Malpedia Family: js.kopiluwak | Software ID: S1075
# MITRE Software: kasidet | Malpedia Family: neutrino | Software ID: S0088
# MITRE Software: kazuar | Malpedia Family: kazuar | Software ID: S0265
# MITRE Software: kerrdown | Malpedia Family: kerrdown | Software ID: S0585
# MITRE Software: keyboy | Malpedia Family: keyboy | Software ID: S0387
# MITRE Software: keydnap | Malpedia Family: osx.keydnap | Software ID: S0276
# MITRE Software: killdisk | Malpedia Family: killdisk | Software ID: S0607
# MITRE Software: kinsing | Malpedia Family: elf.kinsing | Software ID: S0599
# MITRE Software: kivars | Malpedia Family: elf.kivars | Software ID: S0437
# MITRE Software: koadic | Malpedia Family: koadic | Software ID: S0250
# MITRE Software: kobalos | Malpedia Family: elf.kobalos | Software ID: S0641
# MITRE Software: komplex | Malpedia Family: osx.komplex | Software ID: S0162
# MITRE Software: kwampirs | Malpedia Family: kwampirs | Software ID: S0236
# MITRE Software: lowball | Malpedia Family: lowball | Software ID: S0042
# MITRE Software: lazagne | Malpedia Family: py.lazagne | Software ID: S0349
# MITRE Software: latrodectus | Malpedia Family: latrodectus | Software ID: S1160
# MITRE Software: lightneuron | Malpedia Family: lightneuron | Software ID: S0395
# MITRE Software: liteduke | Malpedia Family: liteduke | Software ID: S0513
# MITRE Software: lizar | Malpedia Family: diceloader | Software ID: S0681
# MITRE Software: lojax | Malpedia Family: lojax | Software ID: S0397
# MITRE Software: lockergoga | Malpedia Family: lockergoga | Software ID: S0372
# MITRE Software: lokibot | Malpedia Family: apk.lokibot | Software ID: S0447
# MITRE Software: lookback | Malpedia Family: lookback | Software ID: S0582
# MITRE Software: lucifer | Malpedia Family: lucifer | Software ID: S0532
# MITRE Software: lunarmail | Malpedia Family: lunarmail | Software ID: S1142
# MITRE Software: lurid | Malpedia Family: enfal | Software ID: S0010
# MITRE Software: messagetap | Malpedia Family: elf.messagetap | Software ID: S0443
# MITRE Software: murkytop | Malpedia Family: murkytop | Software ID: S0233
# MITRE Software: macma | Malpedia Family: osx.cdds | Software ID: S1016
# MITRE Software: macspy | Malpedia Family: osx.macspy | Software ID: S0282
# MITRE Software: machete | Malpedia Family: py.pyark | Software ID: S0409
# MITRE Software: manjusaka | Malpedia Family: elf.manjusaka | Software ID: S1156
# MITRE Software: markirat | Malpedia Family: markirat | Software ID: S0652
# MITRE Software: maze | Malpedia Family: maze | Software ID: S0449
# MITRE Software: megacortex | Malpedia Family: megacortex | Software ID: S0576
# MITRE Software: melcoz | Malpedia Family: melcoz | Software ID: S0530
# MITRE Software: metamorfo | Malpedia Family: metamorfo | Software ID: S0455
# MITRE Software: meteor | Malpedia Family: meteor | Software ID: S0688
# MITRE Software: mgbot | Malpedia Family: mgbot | Software ID: S1146
# MITRE Software: micropsia | Malpedia Family: micropsia | Software ID: S0339
# MITRE Software: milan | Malpedia Family: milan | Software ID: S1015
# MITRE Software: mimikatz | Malpedia Family: mimikatz | Software ID: S0002
# MITRE Software: miniduke | Malpedia Family: miniduke | Software ID: S0051
# MITRE Software: miragefox | Malpedia Family: miragefox | Software ID: S0280
# MITRE Software: misdat | Malpedia Family: misdat | Software ID: S0083
# MITRE Software: mispadu | Malpedia Family: mispadu | Software ID: S1122
# MITRE Software: mobileorder | Malpedia Family: apk.mobile order | Software ID: S0079
# MITRE Software: molenet | Malpedia Family: molenet | Software ID: S0553
# MITRE Software: mongall | Malpedia Family: mongall | Software ID: S1026
# MITRE Software: moonwind | Malpedia Family: moonwind | Software ID: S0149
# MITRE Software: more eggs | Malpedia Family: js.more eggs | Software ID: S0284
# MITRE Software: mosquito | Malpedia Family: mosquito | Software ID: S0256
# MITRE Software: neteagle | Malpedia Family: neteagle | Software ID: S0034
# MITRE Software: netwire | Malpedia Family: osx.netwire | Software ID: S0198
# MITRE Software: nglite | Malpedia Family: nglite | Software ID: S1106
# MITRE Software: nokki | Malpedia Family: nokki | Software ID: S0353
# MITRE Software: nanhaishu | Malpedia Family: js.nanhaishu | Software ID: S0228
# MITRE Software: nanocore | Malpedia Family: nanocore | Software ID: S0336
# MITRE Software: navrat | Malpedia Family: navrat | Software ID: S0247
# MITRE Software: nebulae | Malpedia Family: nebulae | Software ID: S0630
# MITRE Software: net crawler | Malpedia Family: netc | Software ID: S0056
# MITRE Software: nettraveler | Malpedia Family: nettraveler | Software ID: S0033
# MITRE Software: netwalker | Malpedia Family: mailto | Software ID: S0457
# MITRE Software: nightclub | Malpedia Family: nightclub | Software ID: S1090
# MITRE Software: nightdoor | Malpedia Family: nightdoor | Software ID: S1147
# MITRE Software: notpetya | Malpedia Family: eternal petya | Software ID: S0368
# MITRE Software: oldbait | Malpedia Family: oldbait | Software ID: S0138
# MITRE Software: oceansalt | Malpedia Family: oceansalt | Software ID: S0346
# MITRE Software: octopus | Malpedia Family: ps1.octopus | Software ID: S0340
# MITRE Software: okrum | Malpedia Family: okrum | Software ID: S0439
# MITRE Software: olympic destroyer | Malpedia Family: olympic destroyer | Software ID: S0365
# MITRE Software: onionduke | Malpedia Family: onionduke | Software ID: S0052
# MITRE Software: oopsie | Malpedia Family: oopsie | Software ID: S0264
# MITRE Software: orz | Malpedia Family: js.airbreak | Software ID: S0229
# MITRE Software: outsteel | Malpedia Family: outsteel | Software ID: S1017
# MITRE Software: owaauth | Malpedia Family: owaauth | Software ID: S0072
# MITRE Software: phoreal | Malpedia Family: phoreal | Software ID: S0158
# MITRE Software: plaintee | Malpedia Family: plaintee | Software ID: S0254
# MITRE Software: plead | Malpedia Family: elf.plead | Software ID: S0435
# MITRE Software: poshspy | Malpedia Family: ps1.poshspy | Software ID: S0150
# MITRE Software: powersource | Malpedia Family: ps1.powersource | Software ID: S0145
# MITRE Software: powerstats | Malpedia Family: ps1.powerstats | Software ID: S0223
# MITRE Software: powerton | Malpedia Family: ps1.powerton | Software ID: S0371
# MITRE Software: powruner | Malpedia Family: ps1.powruner | Software ID: S0184
# MITRE Software: punchbuggy | Malpedia Family: powersniff | Software ID: S0196
# MITRE Software: punchtrack | Malpedia Family: poslurp | Software ID: S0197
# MITRE Software: pandora | Malpedia Family: pandora | Software ID: S0664
# MITRE Software: pay2key | Malpedia Family: pay2key | Software ID: S0556
# MITRE Software: pcshare | Malpedia Family: pcshare | Software ID: S1050
# MITRE Software: pikabot | Malpedia Family: pikabot | Software ID: S1145
# MITRE Software: pillowmint | Malpedia Family: pillowmint | Software ID: S0517
# MITRE Software: pinchduke | Malpedia Family: pinchduke | Software ID: S0048
# MITRE Software: pingpull | Malpedia Family: elf.pingpull | Software ID: S1031
# MITRE Software: pipemon | Malpedia Family: pipemon | Software ID: S0501
# MITRE Software: pisloader | Malpedia Family: roseam | Software ID: S0124
# MITRE Software: playcrypt | Malpedia Family: play | Software ID: S1162
# MITRE Software: plugx | Malpedia Family: plugx | Software ID: S0013
# MITRE Software: poisonivy | Malpedia Family: poison ivy | Software ID: S0012
# MITRE Software: polyglotduke | Malpedia Family: polyglotduke | Software ID: S0518
# MITRE Software: pony | Malpedia Family: pony | Software ID: S0453
# MITRE Software: poshc2 | Malpedia Family: poshc2 | Software ID: S0378
# MITRE Software: powgoop | Malpedia Family: ps1.powgoop | Software ID: S1046
# MITRE Software: powerduke | Malpedia Family: powerduke | Software ID: S0139
# MITRE Software: powershower | Malpedia Family: ps1.powershower | Software ID: S0441
# MITRE Software: prestige | Malpedia Family: prestige | Software ID: S1058
# MITRE Software: prikormka | Malpedia Family: prikormka | Software ID: S0113
# MITRE Software: prolock | Malpedia Family: pwndlocker | Software ID: S0654
# MITRE Software: pteranodon | Malpedia Family: pteranodon | Software ID: S0147
# MITRE Software: pupy | Malpedia Family: elf.pupy | Software ID: S0192
# MITRE Software: pysa | Malpedia Family: mespinoza | Software ID: S0583
# MITRE Software: quadagent | Malpedia Family: ps1.quadagent | Software ID: S0269
# MITRE Software: quietcanary | Malpedia Family: quietcanary | Software ID: S1076
# MITRE Software: quietexit | Malpedia Family: elf.quietexit | Software ID: S1084
# MITRE Software: qakbot | Malpedia Family: qakbot | Software ID: S0650
# MITRE Software: quasarrat | Malpedia Family: apk.xrat | Software ID: S0262
# MITRE Software: quietsieve | Malpedia Family: quietsieve | Software ID: S0686
# MITRE Software: ratankba | Malpedia Family: ratankba | Software ID: S0241
# MITRE Software: rdat | Malpedia Family: rdat | Software ID: S0495
# MITRE Software: revil | Malpedia Family: elf.revil | Software ID: S0496
# MITRE Software: rgdoor | Malpedia Family: rgdoor | Software ID: S0258
# MITRE Software: roadsweep | Malpedia Family: roadsweep | Software ID: S1150
# MITRE Software: rokrat | Malpedia Family: rokrat | Software ID: S0240
# MITRE Software: rtm | Malpedia Family: rtm | Software ID: S0148
# MITRE Software: raindrop | Malpedia Family: raindrop | Software ID: S0565
# MITRE Software: ramsay | Malpedia Family: ramsay | Software ID: S0458
# MITRE Software: raspberry robin | Malpedia Family: raspberry robin | Software ID: S1130
# MITRE Software: rawpos | Malpedia Family: rawpos | Software ID: S0169
# MITRE Software: reaver | Malpedia Family: reaver | Software ID: S0172
# MITRE Software: redleaves | Malpedia Family: redleaves | Software ID: S0153
# MITRE Software: regin | Malpedia Family: regin | Software ID: S0019
# MITRE Software: remcos | Malpedia Family: remcos | Software ID: S0332
# MITRE Software: remexi | Malpedia Family: remexi | Software ID: S0375
# MITRE Software: remotecmd | Malpedia Family: shareip | Software ID: S0166
# MITRE Software: remsec | Malpedia Family: remsec strider | Software ID: S0125
# MITRE Software: responder | Malpedia Family: py.responder | Software ID: S0174
# MITRE Software: revenge rat | Malpedia Family: revenge rat | Software ID: S0379
# MITRE Software: rifdoor | Malpedia Family: rifdoor | Software ID: S0433
# MITRE Software: rising sun | Malpedia Family: rising sun | Software ID: S0448
# MITRE Software: robbinhood | Malpedia Family: robinhood | Software ID: S0400
# MITRE Software: roguerobin | Malpedia Family: ps1.roguerobin | Software ID: S0270
# MITRE Software: rotajakiro | Malpedia Family: elf.rotajakiro | Software ID: S1078
# MITRE Software: rover | Malpedia Family: rover | Software ID: S0090
# MITRE Software: royal | Malpedia Family: elf.royal ransom | Software ID: S1073
# MITRE Software: rubeus | Malpedia Family: rubeus | Software ID: S1071
# MITRE Software: runningrat | Malpedia Family: runningrat | Software ID: S0253
# MITRE Software: ryuk | Malpedia Family: ryuk | Software ID: S0446
# MITRE Software: sdbbot | Malpedia Family: sdbbot | Software ID: S0461
# MITRE Software: seasharpee | Malpedia Family: asp.twoface | Software ID: S0185
# MITRE Software: sharpstats | Malpedia Family: sharpstats | Software ID: S0450
# MITRE Software: shipshape | Malpedia Family: shipshape | Software ID: S0028
# MITRE Software: shotput | Malpedia Family: pirpi | Software ID: S0063
# MITRE Software: shutterspeed | Malpedia Family: freenki | Software ID: S0217
# MITRE Software: slothfulmedia | Malpedia Family: slothfulmedia | Software ID: S0533
# MITRE Software: smokedham | Malpedia Family: smokedham | Software ID: S0649
# MITRE Software: soundbite | Malpedia Family: soundbite | Software ID: S0157
# MITRE Software: spaceship | Malpedia Family: spaceship | Software ID: S0035
# MITRE Software: sqlrat | Malpedia Family: js.sqlrat | Software ID: S0390
# MITRE Software: starwhale | Malpedia Family: vbs.starwhale | Software ID: S1037
# MITRE Software: sugardump | Malpedia Family: sugardump | Software ID: S1042
# MITRE Software: sugarush | Malpedia Family: sugarush | Software ID: S1049
# MITRE Software: sunburst | Malpedia Family: sunburst | Software ID: S0559
# MITRE Software: supernova | Malpedia Family: supernova | Software ID: S0578
# MITRE Software: svcready | Malpedia Family: svcready | Software ID: S1064
# MITRE Software: syscon | Malpedia Family: syscon | Software ID: S0464
# MITRE Software: saint bot | Malpedia Family: saint bot | Software ID: S1018
# MITRE Software: samsam | Malpedia Family: samsam | Software ID: S0370
# MITRE Software: sardonic | Malpedia Family: unidentified 103 | Software ID: S1085
# MITRE Software: seaduke | Malpedia Family: seadaddy | Software ID: S0053
# MITRE Software: seasalt | Malpedia Family: seasalt | Software ID: S0345
# MITRE Software: servhelper | Malpedia Family: servhelper | Software ID: S0382
# MITRE Software: shadowpad | Malpedia Family: shadowpad | Software ID: S0596
# MITRE Software: shamoon | Malpedia Family: disttrack | Software ID: S0140
# MITRE Software: shark | Malpedia Family: shark | Software ID: S1019
# MITRE Software: sharpstage | Malpedia Family: sharpstage | Software ID: S0546
# MITRE Software: shimrat | Malpedia Family: shimrat | Software ID: S0444
# MITRE Software: sidetwist | Malpedia Family: sidetwist | Software ID: S0610
# MITRE Software: sliver | Malpedia Family: sliver | Software ID: S0633
# MITRE Software: small sieve | Malpedia Family: gramdoor | Software ID: S1035
# MITRE Software: smoke loader | Malpedia Family: smokeloader | Software ID: S0226
# MITRE Software: socgholish | Malpedia Family: js.fakeupdates | Software ID: S1124
# MITRE Software: socksbot | Malpedia Family: socksbot | Software ID: S0273
# MITRE Software: sodamaster | Malpedia Family: sodamaster | Software ID: S0627
# MITRE Software: sombrat | Malpedia Family: sombrat | Software ID: S0615
# MITRE Software: sorefang | Malpedia Family: sorefang | Software ID: S0516
# MITRE Software: spark | Malpedia Family: spark | Software ID: S0543
# MITRE Software: speakup | Malpedia Family: elf.speakup | Software ID: S0374
# MITRE Software: spica | Malpedia Family: spica | Software ID: S1140
# MITRE Software: spicyomelette | Malpedia Family: js.more eggs | Software ID: S0646
# MITRE Software: squirrelwaffle | Malpedia Family: squirrelwaffle | Software ID: S1030
# MITRE Software: sslmm | Malpedia Family: sslmm | Software ID: S0058
# MITRE Software: starloader | Malpedia Family: starloader | Software ID: S0188
# MITRE Software: stonedrill | Malpedia Family: dropshot | Software ID: S0380
# MITRE Software: strongpity | Malpedia Family: strongpity | Software ID: S0491
# MITRE Software: stuxnet | Malpedia Family: stuxnet | Software ID: S0603
# MITRE Software: sykipot | Malpedia Family: sykipot | Software ID: S0018
# MITRE Software: synack | Malpedia Family: synack | Software ID: S0242
# MITRE Software: sys10 | Malpedia Family: sys10 | Software ID: S0060
# MITRE Software: sysupdate | Malpedia Family: elf.hyperssl | Software ID: S0663
# MITRE Software: taintedscribe | Malpedia Family: taintedscribe | Software ID: S0586
# MITRE Software: tdtess | Malpedia Family: tdtess | Software ID: S0164
# MITRE Software: teardrop | Malpedia Family: teardrop | Software ID: S0560
# MITRE Software: textmate | Malpedia Family: dnsmessenger | Software ID: S0146
# MITRE Software: tinytyphon | Malpedia Family: tinytyphon | Software ID: S0131
# MITRE Software: tscookie | Malpedia Family: elf.tscookie | Software ID: S0436
# MITRE Software: turnedup | Malpedia Family: turnedup | Software ID: S0199
# MITRE Software: typeframe | Malpedia Family: typeframe | Software ID: S0263
# MITRE Software: taidoor | Malpedia Family: taidoor | Software ID: S0011
# MITRE Software: thiefquest | Malpedia Family: osx.evilquest | Software ID: S0595
# MITRE Software: threatneedle | Malpedia Family: dratzarus | Software ID: S0665
# MITRE Software: tinyturla | Malpedia Family: tiny turla | Software ID: S0668
# MITRE Software: tinyzbot | Malpedia Family: tinyzbot | Software ID: S0004
# MITRE Software: tomiris | Malpedia Family: tomiris | Software ID: S0671
# MITRE Software: torisma | Malpedia Family: torisma | Software ID: S0678
# MITRE Software: trickbot | Malpedia Family: trickbot | Software ID: S0266
# MITRE Software: karagany | Malpedia Family: karagany | Software ID: S0094
# MITRE Software: mebromi | Malpedia Family: mebromi | Software ID: S0001
# MITRE Software: turian | Malpedia Family: turian | Software ID: S0647
# MITRE Software: uacme | Malpedia Family: uacme | Software ID: S0116
# MITRE Software: uppercut | Malpedia Family: anel | Software ID: S0275
# MITRE Software: usbferry | Malpedia Family: usbferry | Software ID: S0452
# MITRE Software: umbreon | Malpedia Family: elf.umbreon | Software ID: S0221
# MITRE Software: uroburos | Malpedia Family: osx.uroburos | Software ID: S0022
# MITRE Software: ursnif | Malpedia Family: gozi | Software ID: S0386
# MITRE Software: vermin | Malpedia Family: vermin | Software ID: S0257
# MITRE Software: vpnfilter | Malpedia Family: elf.vpnfilter | Software ID: S1010
# MITRE Software: valak | Malpedia Family: js.valak | Software ID: S0476
# MITRE Software: vaporrage | Malpedia Family: vapor rage | Software ID: S0636
# MITRE Software: versamem | Malpedia Family: jar.versamem | Software ID: S1154
# MITRE Software: volgmer | Malpedia Family: volgmer | Software ID: S0180
# MITRE Software: windshield | Malpedia Family: remy | Software ID: S0155
# MITRE Software: wirefire | Malpedia Family: py.wirefire | Software ID: S1115
# MITRE Software: wannacry | Malpedia Family: wannacryptor | Software ID: S0366
# MITRE Software: warzonerat | Malpedia Family: ave maria | Software ID: S0670
# MITRE Software: wastedlocker | Malpedia Family: wastedlocker | Software ID: S0612
# MITRE Software: waterbear | Malpedia Family: waterbear | Software ID: S0579
# MITRE Software: wellmail | Malpedia Family: elf.wellmail | Software ID: S0515
# MITRE Software: wellmess | Malpedia Family: wellmess | Software ID: S0514
# MITRE Software: whispergate | Malpedia Family: whispergate | Software ID: S0689
# MITRE Software: winmm | Malpedia Family: winmm | Software ID: S0059
# MITRE Software: windtail | Malpedia Family: osx.windtail | Software ID: S0466
# MITRE Software: woody rat | Malpedia Family: woodyrat | Software ID: S1065
# MITRE Software: xcsset | Malpedia Family: osx.xcsset | Software ID: S0658
# MITRE Software: xtunnel | Malpedia Family: xtunnel | Software ID: S0117
# MITRE Software: xbash | Malpedia Family: elf.xbash | Software ID: S0341
# MITRE Software: yahoyah | Malpedia Family: yahoyah | Software ID: S0388
# MITRE Software: zlib | Malpedia Family: poldat | Software ID: S0086
# MITRE Software: zebrocy | Malpedia Family: zebrocy | Software ID: S0251
# MITRE Software: zerocleare | Malpedia Family: zerocleare | Software ID: S1151
# MITRE Software: zerot | Malpedia Family: zerot | Software ID: S0230
# MITRE Software: zeroaccess | Malpedia Family: zeroaccess | Software ID: S0027
# MITRE Software: zxshell | Malpedia Family: zxshell | Software ID: S0412
# MITRE Software: zxxz | Malpedia Family: zxxz | Software ID: S1013
# MITRE Software: down new | Malpedia Family: broler | Software ID: S0472
# MITRE Software: gh0st rat | Malpedia Family: ghost rat | Software ID: S0032
# MITRE Software: gsecdump | Malpedia Family: gsecdump | Software ID: S0008
# MITRE Software: jrat | Malpedia Family: jar.jrat | Software ID: S0283
# MITRE Software: njrat | Malpedia Family: njrat | Software ID: S0385
# MITRE Software: pngdowner | Malpedia Family: pngdowner | Software ID: S0067
# MITRE Software: schtasks | Malpedia Family: ps1.schtasks | Software ID: S0111
# MITRE Software: xcaon | Malpedia Family: xcaon | Software ID: S0653
# MITRE Software: yty | Malpedia Family: yty | Software ID: S0248
# MITRE Software: incontroller | Malpedia Family: incontroller | Software ID: S1045
# MITRE Software: triton | Malpedia Family: triton | Software ID: S1009
# MITRE Software: abstractemu | Malpedia Family: apk.abstract emu | Software ID: S1061
# MITRE Software: agent smith | Malpedia Family: apk.agentsmith | Software ID: S0440
# MITRE Software: androrat | Malpedia Family: apk.androrat | Software ID: S0292
# MITRE Software: anubis | Malpedia Family: apk.anubis | Software ID: S0422
# MITRE Software: asacub | Malpedia Family: apk.asacub | Software ID: S0540
# MITRE Software: bouldspy | Malpedia Family: apk.daam | Software ID: S1079
# MITRE Software: brata | Malpedia Family: apk.brata | Software ID: S1094
# MITRE Software: bread | Malpedia Family: apk.joker | Software ID: S0432
# MITRE Software: busygasper | Malpedia Family: apk.busygasper | Software ID: S0655
# MITRE Software: carbonsteal | Malpedia Family: apk.carbonsteal | Software ID: S0529
# MITRE Software: cerberus | Malpedia Family: apk.cerberus | Software ID: S0480
# MITRE Software: chameleon | Malpedia Family: apk.chameleon | Software ID: S1083
# MITRE Software: charger | Malpedia Family: apk.charger | Software ID: S0323
# MITRE Software: defensor id | Malpedia Family: apk.defensor id | Software ID: S0479
# MITRE Software: dendroid | Malpedia Family: apk.dendroid | Software ID: S0301
# MITRE Software: doubleagent | Malpedia Family: apk.doubleagent | Software ID: S0550
# MITRE Software: drinik | Malpedia Family: apk.elibomi | Software ID: S1054
# MITRE Software: droidjack | Malpedia Family: apk.droidjack | Software ID: S0320
# MITRE Software: dualtoy | Malpedia Family: apk.dualtoy | Software ID: S0315
# MITRE Software: dvmap | Malpedia Family: apk.dvmap | Software ID: S0420
# MITRE Software: escobar | Malpedia Family: apk.aberebot | Software ID: S1092
# MITRE Software: eventbot | Malpedia Family: apk.eventbot | Software ID: S0478
# MITRE Software: exobot | Malpedia Family: apk.exobot | Software ID: S0522
# MITRE Software: exodus | Malpedia Family: apk.exodus | Software ID: S0405
# MITRE Software: fakespy | Malpedia Family: apk.fakespy | Software ID: S0509
# MITRE Software: fakecalls | Malpedia Family: apk.fakecalls | Software ID: S1080
# MITRE Software: flexispy | Malpedia Family: apk.flexispy | Software ID: S0408
# MITRE Software: flubot | Malpedia Family: apk.flubot | Software ID: S1067
# MITRE Software: flytrap | Malpedia Family: apk.flytrap | Software ID: S1093
# MITRE Software: gplayed | Malpedia Family: apk.gplayed | Software ID: S0536
# MITRE Software: ginp | Malpedia Family: apk.ginp | Software ID: S0423
# MITRE Software: goldeneagle | Malpedia Family: apk.goldeneagle | Software ID: S0551
# MITRE Software: gustuff | Malpedia Family: apk.gustuff | Software ID: S0406
# MITRE Software: henbox | Malpedia Family: apk.henbox | Software ID: S0544
# MITRE Software: hilalrat | Malpedia Family: apk.hilalrat | Software ID: S1128
# MITRE Software: insomnia | Malpedia Family: ios.poisoncarp | Software ID: S0463
# MITRE Software: mandrake | Malpedia Family: apk.mandrake | Software ID: S0485
# MITRE Software: mazarbot | Malpedia Family: apk.mazarbot | Software ID: S0303
# MITRE Software: monokle | Malpedia Family: apk.monokle | Software ID: S0407
# MITRE Software: pegasus for android | Malpedia Family: apk.chrysaor | Software ID: S0316
# MITRE Software: phenakite | Malpedia Family: ios.phenakite | Software ID: S1126
# MITRE Software: riltok | Malpedia Family: apk.riltok | Software ID: S0403
# MITRE Software: s.o.v.a. | Malpedia Family: apk.sova | Software ID: S1062
# MITRE Software: sharkbot | Malpedia Family: apk.sharkbot | Software ID: S1055
# MITRE Software: silkbean | Malpedia Family: apk.silkbean | Software ID: S0549
# MITRE Software: skygofree | Malpedia Family: apk.skygofree | Software ID: S0327
# MITRE Software: stealth mango | Malpedia Family: apk.stealthmango | Software ID: S0328
# MITRE Software: tanglebot | Malpedia Family: apk.tangle bot | Software ID: S1069
# MITRE Software: tianyspy | Malpedia Family: apk.tianyspy | Software ID: S1056
# MITRE Software: triada | Malpedia Family: apk.triada | Software ID: S0424
# MITRE Software: trickmo | Malpedia Family: apk.trickmo | Software ID: S0427
# MITRE Software: viceleaker | Malpedia Family: apk.triout | Software ID: S0418
# MITRE Software: wirelurker | Malpedia Family: ios.wirelurker | Software ID: S0312
# MITRE Software: wolfrat | Malpedia Family: apk.wolf rat | Software ID: S0489
# MITRE Software: xbot | Malpedia Family: apk.xbot | Software ID: S0298
# MITRE Software: zen | Malpedia Family: apk.zen | Software ID: S0494
#
# Total MITRE software not present in Malpedia: 315
# MITRE Software: 3para rat | Software ID: S0066 | Type: Malware
# MITRE Software: aadinternals | Software ID: S0677 | Type: Tool
# MITRE Software: abk | Software ID: S0469 | Type: Malware
# MITRE Software: advstoreshell | Software ID: S0045 | Type: Malware
# MITRE Software: adfind | Software ID: S0552 | Type: Tool
# MITRE Software: arp | Software ID: S0099 | Type: Tool
# MITRE Software: auto stealer | Software ID: S1029 | Type: Malware
# MITRE Software: auditcred | Software ID: S0347 | Type: Malware
# MITRE Software: autoit backdoor | Software ID: S0129 | Type: Malware
# MITRE Software: avenger | Software ID: S0473 | Type: Malware
# MITRE Software: bbk | Software ID: S0470 | Type: Malware
# MITRE Software: bfg agonizer | Software ID: S1136 | Type: Malware
# MITRE Software: bitsadmin | Software ID: S0190 | Type: Tool
# MITRE Software: bootrash | Software ID: S0114 | Type: Malware
# MITRE Software: bushwalk | Software ID: S1118 | Type: Malware
# MITRE Software: backdoor.oldrea | Software ID: S0093 | Type: Malware
# MITRE Software: bad rabbit | Software ID: S0606 | Type: Malware
# MITRE Software: bazar | Software ID: S0534 | Type: Malware
# MITRE Software: bendybear | Software ID: S0574 | Type: Malware
# MITRE Software: blackmould | Software ID: S0564 | Type: Malware
# MITRE Software: bloodhound | Software ID: S0521 | Type: Tool
# MITRE Software: bonadan | Software ID: S0486 | Type: Malware
# MITRE Software: brave prince | Software ID: S0252 | Type: Malware
# MITRE Software: briba | Software ID: S0204 | Type: Malware
# MITRE Software: calendar | Software ID: S0025 | Type: Malware
# MITRE Software: ccbkdr | Software ID: S0222 | Type: Malware
# MITRE Software: chimneysweep | Software ID: S1149 | Type: Malware
# MITRE Software: coathanger | Software ID: S1105 | Type: Malware
# MITRE Software: coraldeck | Software ID: S0212 | Type: Malware
# MITRE Software: cspy downloader | Software ID: S0527 | Type: Tool
# MITRE Software: cachedump | Software ID: S0119 | Type: Tool
# MITRE Software: callme | Software ID: S0077 | Type: Malware
# MITRE Software: caterpillar webshell | Software ID: S0572 | Type: Malware
# MITRE Software: charmpower | Software ID: S0674 | Type: Malware
# MITRE Software: cheerscrypt | Software ID: S1096 | Type: Malware
# MITRE Software: china chopper | Software ID: S0020 | Type: Malware
# MITRE Software: chrommme | Software ID: S0667 | Type: Malware
# MITRE Software: cointicker | Software ID: S0369 | Type: Malware
# MITRE Software: comnie | Software ID: S0244 | Type: Malware
# MITRE Software: connectwise | Software ID: S0591 | Type: Tool
# MITRE Software: cookieminer | Software ID: S0492 | Type: Malware
# MITRE Software: costabricks | Software ID: S0614 | Type: Malware
# MITRE Software: covenant | Software ID: S1155 | Type: Tool
# MITRE Software: crackmapexec | Software ID: S0488 | Type: Tool
# MITRE Software: creepydrive | Software ID: S1023 | Type: Malware
# MITRE Software: cryptoistic | Software ID: S0498 | Type: Malware
# MITRE Software: cuckoo stealer | Software ID: S1153 | Type: Malware
# MITRE Software: cyclops blink | Software ID: S0687 | Type: Malware
# MITRE Software: deadeye | Software ID: S1052 | Type: Malware
# MITRE Software: dealerschoice | Software ID: S0243 | Type: Malware
# MITRE Software: disco | Software ID: S1088 | Type: Malware
# MITRE Software: dnssystem | Software ID: S1021 | Type: Malware
# MITRE Software: drovorub | Software ID: S0502 | Type: Malware
# MITRE Software: dustysky | Software ID: S0062 | Type: Malware
# MITRE Software: ecipekac | Software ID: S0624 | Type: Malware
# MITRE Software: empire | Software ID: S0363 | Type: Tool
# MITRE Software: exaramel for linux | Software ID: S0401 | Type: Malware
# MITRE Software: exaramel for windows | Software ID: S0343 | Type: Malware
# MITRE Software: expand | Software ID: S0361 | Type: Tool
# MITRE Software: explosive | Software ID: S0569 | Type: Malware
# MITRE Software: flipside | Software ID: S0173 | Type: Malware
# MITRE Software: framesting | Software ID: S1120 | Type: Malware
# MITRE Software: frp | Software ID: S1144 | Type: Tool
# MITRE Software: fyanti | Software ID: S0628 | Type: Malware
# MITRE Software: fakem | Software ID: S0076 | Type: Malware
# MITRE Software: ferocious | Software ID: S0679 | Type: Malware
# MITRE Software: fgdump | Software ID: S0120 | Type: Tool
# MITRE Software: foggyweb | Software ID: S0661 | Type: Malware
# MITRE Software: forfiles | Software ID: S0193 | Type: Tool
# MITRE Software: glasstoken | Software ID: S1117 | Type: Malware
# MITRE Software: gelsemium | Software ID: S0666 | Type: Malware
# MITRE Software: goldfinder | Software ID: S0597 | Type: Malware
# MITRE Software: goopy | Software ID: S0477 | Type: Malware
# MITRE Software: gravityrat | Software ID: S0237 | Type: Malware
# MITRE Software: green lambert | Software ID: S0690 | Type: Malware
# MITRE Software: happywork | Software ID: S0214 | Type: Malware
# MITRE Software: hdoor | Software ID: S0061 | Type: Malware
# MITRE Software: hacking team uefi rootkit | Software ID: S0047 | Type: Malware
# MITRE Software: havij | Software ID: S0224 | Type: Tool
# MITRE Software: heyoka backdoor | Software ID: S1027 | Type: Malware
# MITRE Software: hi-zor | Software ID: S0087 | Type: Malware
# MITRE Software: hildegard | Software ID: S0601 | Type: Malware
# MITRE Software: inc ransomware | Software ID: S1139 | Type: Malware
# MITRE Software: ipsec helper | Software ID: S1132 | Type: Malware
# MITRE Software: isminjector | Software ID: S0189 | Type: Malware
# MITRE Software: iceapple | Software ID: S1022 | Type: Malware
# MITRE Software: imminent monitor | Software ID: S0434 | Type: Tool
# MITRE Software: impacket | Software ID: S0357 | Type: Tool
# MITRE Software: invoke-psimage | Software ID: S0231 | Type: Tool
# MITRE Software: ixeshe | Software ID: S0015 | Type: Malware
# MITRE Software: jpin | Software ID: S0201 | Type: Malware
# MITRE Software: jss loader | Software ID: S0648 | Type: Malware
# MITRE Software: javali | Software ID: S0528 | Type: Malware
# MITRE Software: karae | Software ID: S0215 | Type: Malware
# MITRE Software: koctopus | Software ID: S0669 | Type: Malware
# MITRE Software: kessel | Software ID: S0487 | Type: Malware
# MITRE Software: kevin | Software ID: S1020 | Type: Malware
# MITRE Software: lightwire | Software ID: S1119 | Type: Malware
# MITRE Software: littlelamb.wooltea | Software ID: S1121 | Type: Malware
# MITRE Software: linfo | Software ID: S0211 | Type: Malware
# MITRE Software: linux rabbit | Software ID: S0362 | Type: Malware
# MITRE Software: litepower | Software ID: S0680 | Type: Malware
# MITRE Software: lofise | Software ID: S1101 | Type: Malware
# MITRE Software: loudminer | Software ID: S0451 | Type: Malware
# MITRE Software: lslsass | Software ID: S0121 | Type: Tool
# MITRE Software: lunarloader | Software ID: S1143 | Type: Malware
# MITRE Software: lunarweb | Software ID: S1141 | Type: Malware
# MITRE Software: mcmd | Software ID: S0500 | Type: Tool
# MITRE Software: mafalda | Software ID: S1060 | Type: Malware
# MITRE Software: mailsniper | Software ID: S0413 | Type: Tool
# MITRE Software: matryoshka | Software ID: S0167 | Type: Malware
# MITRE Software: mechaflounder | Software ID: S0459 | Type: Malware
# MITRE Software: mimipenguin | Software ID: S0179 | Type: Tool
# MITRE Software: miner-c | Software ID: S0133 | Type: Malware
# MITRE Software: mis-type | Software ID: S0084 | Type: Malware
# MITRE Software: mivast | Software ID: S0080 | Type: Malware
# MITRE Software: moneybird | Software ID: S1137 | Type: Malware
# MITRE Software: mori | Software ID: S1047 | Type: Malware
# MITRE Software: multilayer wiper | Software ID: S1135 | Type: Malware
# MITRE Software: mythic | Software ID: S0699 | Type: Tool
# MITRE Software: nbtscan | Software ID: S0590 | Type: Tool
# MITRE Software: ndiskmonitor | Software ID: S0272 | Type: Malware
# MITRE Software: nkabuse | Software ID: S1107 | Type: Malware
# MITRE Software: nppspy | Software ID: S1131 | Type: Tool
# MITRE Software: naid | Software ID: S0205 | Type: Malware
# MITRE Software: nativezone | Software ID: S0637 | Type: Malware
# MITRE Software: neoichor | Software ID: S0691 | Type: Malware
# MITRE Software: nerex | Software ID: S0210 | Type: Malware
# MITRE Software: net | Software ID: S0039 | Type: Tool
# MITRE Software: nidiran | Software ID: S0118 | Type: Malware
# MITRE Software: ninja | Software ID: S1100 | Type: Malware
# MITRE Software: nltest | Software ID: S0359 | Type: Tool
# MITRE Software: osinfo | Software ID: S0165 | Type: Malware
# MITRE Software: osx/shlayer | Software ID: S0402 | Type: Malware
# MITRE Software: osx oceanlotus.d | Software ID: S0352 | Type: Malware
# MITRE Software: obliquerat | Software ID: S0644 | Type: Malware
# MITRE Software: out1 | Software ID: S0594 | Type: Tool
# MITRE Software: p.a.s. webshell | Software ID: S0598 | Type: Malware
# MITRE Software: p2p zeus | Software ID: S0016 | Type: Malware
# MITRE Software: p8rat | Software ID: S0626 | Type: Malware
# MITRE Software: pacemaker | Software ID: S1109 | Type: Malware
# MITRE Software: pitstop | Software ID: S1123 | Type: Malware
# MITRE Software: pooraim | Software ID: S0216 | Type: Malware
# MITRE Software: ps1 | Software ID: S0613 | Type: Malware
# MITRE Software: pulsecheck | Software ID: S1108 | Type: Malware
# MITRE Software: pacu | Software ID: S1091 | Type: Tool
# MITRE Software: pasam | Software ID: S0208 | Type: Malware
# MITRE Software: pass-the-hash toolkit | Software ID: S0122 | Type: Tool
# MITRE Software: pcexter | Software ID: S1102 | Type: Malware
# MITRE Software: peirates | Software ID: S0683 | Type: Tool
# MITRE Software: penquin | Software ID: S0587 | Type: Malware
# MITRE Software: peppy | Software ID: S0643 | Type: Malware
# MITRE Software: ping | Software ID: S0097 | Type: Tool
# MITRE Software: poetrat | Software ID: S0428 | Type: Malware
# MITRE Software: power loader | Software ID: S0177 | Type: Malware
# MITRE Software: powerless | Software ID: S1012 | Type: Malware
# MITRE Software: powerpunch | Software ID: S0685 | Type: Malware
# MITRE Software: powersploit | Software ID: S0194 | Type: Tool
# MITRE Software: powerstallion | Software ID: S0393 | Type: Malware
# MITRE Software: proton | Software ID: S0279 | Type: Malware
# MITRE Software: proxysvc | Software ID: S0238 | Type: Malware
# MITRE Software: psexec | Software ID: S0029 | Type: Tool
# MITRE Software: psylo | Software ID: S0078 | Type: Malware
# MITRE Software: pydcrypt | Software ID: S1032 | Type: Malware
# MITRE Software: rapidpulse | Software ID: S1113 | Type: Malware
# MITRE Software: rarstone | Software ID: S0055 | Type: Malware
# MITRE Software: rcsession | Software ID: S0662 | Type: Malware
# MITRE Software: rdfsniffer | Software ID: S0416 | Type: Malware
# MITRE Software: riptide | Software ID: S0003 | Type: Malware
# MITRE Software: roadtools | Software ID: S0684 | Type: Tool
# MITRE Software: rockboot | Software ID: S0112 | Type: Malware
# MITRE Software: raccoon stealer | Software ID: S1148 | Type: Malware
# MITRE Software: ragnar locker | Software ID: S0481 | Type: Malware
# MITRE Software: rainyday | Software ID: S0629 | Type: Malware
# MITRE Software: rawdisk | Software ID: S0364 | Type: Tool
# MITRE Software: rclone | Software ID: S1040 | Type: Tool
# MITRE Software: reg | Software ID: S0075 | Type: Tool
# MITRE Software: regduke | Software ID: S0511 | Type: Malware
# MITRE Software: remoteutilities | Software ID: S0592 | Type: Tool
# MITRE Software: ruler | Software ID: S0358 | Type: Tool
# MITRE Software: s-type | Software ID: S0085 | Type: Malware
# MITRE Software: sdelete | Software ID: S0195 | Type: Tool
# MITRE Software: silenttrinity | Software ID: S0692 | Type: Tool
# MITRE Software: slightpulse | Software ID: S1110 | Type: Malware
# MITRE Software: slowdrift | Software ID: S0218 | Type: Malware
# MITRE Software: slowpulse | Software ID: S1104 | Type: Malware
# MITRE Software: snugride | Software ID: S0159 | Type: Malware
# MITRE Software: steadypulse | Software ID: S1112 | Type: Malware
# MITRE Software: sunspot | Software ID: S0562 | Type: Malware
# MITRE Software: synful knock | Software ID: S0519 | Type: Malware
# MITRE Software: sakula | Software ID: S0074 | Type: Malware
# MITRE Software: samurai | Software ID: S1099 | Type: Malware
# MITRE Software: seth-locker | Software ID: S0639 | Type: Malware
# MITRE Software: sharpdisco | Software ID: S1089 | Type: Malware
# MITRE Software: shimratreporter | Software ID: S0445 | Type: Tool
# MITRE Software: sibot | Software ID: S0589 | Type: Malware
# MITRE Software: siloscape | Software ID: S0623 | Type: Malware
# MITRE Software: skeleton key | Software ID: S0007 | Type: Malware
# MITRE Software: skidmap | Software ID: S0468 | Type: Malware
# MITRE Software: snip3 | Software ID: S1086 | Type: Malware
# MITRE Software: streamex | Software ID: S0142 | Type: Malware
# MITRE Software: strifewater | Software ID: S1034 | Type: Malware
# MITRE Software: systeminfo | Software ID: S0096 | Type: Tool
# MITRE Software: t9000 | Software ID: S0098 | Type: Malware
# MITRE Software: tajmahal | Software ID: S0467 | Type: Malware
# MITRE Software: tarrask | Software ID: S1011 | Type: Malware
# MITRE Software: tasklist | Software ID: S0057 | Type: Tool
# MITRE Software: tor | Software ID: S0183 | Type: Tool
# MITRE Software: trailblazer | Software ID: S0682 | Type: Malware
# MITRE Software: truvasys | Software ID: S0178 | Type: Malware
# MITRE Software: uboatrat | Software ID: S0333 | Type: Malware
# MITRE Software: usbstealer | Software ID: S0136 | Type: Malware
# MITRE Software: unknown logger | Software ID: S0130 | Type: Malware
# MITRE Software: vbshower | Software ID: S0442 | Type: Malware
# MITRE Software: vasport | Software ID: S0207 | Type: Malware
# MITRE Software: warpwire | Software ID: S1116 | Type: Malware
# MITRE Software: webc2 | Software ID: S0109 | Type: Malware
# MITRE Software: winerack | Software ID: S0219 | Type: Malware
# MITRE Software: wevtutil | Software ID: S0645 | Type: Tool
# MITRE Software: wiarp | Software ID: S0206 | Type: Malware
# MITRE Software: windows credential editor | Software ID: S0005 | Type: Tool
# MITRE Software: winexe | Software ID: S0191 | Type: Tool
# MITRE Software: wingbird | Software ID: S0176 | Type: Malware
# MITRE Software: winnti for linux | Software ID: S0430 | Type: Malware
# MITRE Software: winnti for windows | Software ID: S0141 | Type: Malware
# MITRE Software: wiper | Software ID: S0041 | Type: Malware
# MITRE Software: xagentosx | Software ID: S0161 | Type: Malware
# MITRE Software: zipline | Software ID: S1114 | Type: Malware
# MITRE Software: zeus panda | Software ID: S0330 | Type: Malware
# MITRE Software: zox | Software ID: S0672 | Type: Malware
# MITRE Software: adbupd | Software ID: S0202 | Type: Malware
# MITRE Software: at | Software ID: S0110 | Type: Tool
# MITRE Software: build downer | Software ID: S0471 | Type: Malware
# MITRE Software: ccf32 | Software ID: S1043 | Type: Malware
# MITRE Software: certutil | Software ID: S0160 | Type: Tool
# MITRE Software: cmd | Software ID: S0106 | Type: Tool
# MITRE Software: dsquery | Software ID: S0105 | Type: Tool
# MITRE Software: esentutl | Software ID: S0404 | Type: Tool
# MITRE Software: ftp | Software ID: S0095 | Type: Tool
# MITRE Software: hcdloader | Software ID: S0071 | Type: Malware
# MITRE Software: httpclient | Software ID: S0068 | Type: Malware
# MITRE Software: ikitten | Software ID: S0278 | Type: Malware
# MITRE Software: ifconfig | Software ID: S0101 | Type: Tool
# MITRE Software: ipconfig | Software ID: S0100 | Type: Tool
# MITRE Software: macos.osaminer | Software ID: S1048 | Type: Malware
# MITRE Software: meek | Software ID: S0175 | Type: Tool
# MITRE Software: metamain | Software ID: S1059 | Type: Malware
# MITRE Software: nbtstat | Software ID: S0102 | Type: Tool
# MITRE Software: netsh | Software ID: S0108 | Type: Tool
# MITRE Software: netstat | Software ID: S0104 | Type: Tool
# MITRE Software: ngrok | Software ID: S0508 | Type: Tool
# MITRE Software: pwdump | Software ID: S0006 | Type: Tool
# MITRE Software: route | Software ID: S0103 | Type: Tool
# MITRE Software: spwebmember | Software ID: S0227 | Type: Tool
# MITRE Software: sqlmap | Software ID: S0225 | Type: Tool
# MITRE Software: xcmd | Software ID: S0123 | Type: Tool
# MITRE Software: zwshell | Software ID: S0350 | Type: Malware
# MITRE Software: acad/medre.a | Software ID: S1000 | Type: Malware
# MITRE Software: fuxnet | Software ID: S1157 | Type: Malware
# MITRE Software: plc-blaster | Software ID: S1006 | Type: Malware
# MITRE Software: androidos anserver.a | Software ID: S0310 | Type: Malware
# MITRE Software: adups | Software ID: S0309 | Type: Malware
# MITRE Software: ahrat | Software ID: S1095 | Type: Malware
# MITRE Software: allwinner | Software ID: S0319 | Type: Malware
# MITRE Software: android/addisplay.ashas | Software ID: S0525 | Type: Malware
# MITRE Software: android/chuli.a | Software ID: S0304 | Type: Malware
# MITRE Software: androidos/mallocker.b | Software ID: S0524 | Type: Malware
# MITRE Software: braintest | Software ID: S0293 | Type: Malware
# MITRE Software: chemistgames | Software ID: S0555 | Type: Malware
# MITRE Software: circles | Software ID: S0602 | Type: Malware
# MITRE Software: concipit1248 | Software ID: S0426 | Type: Malware
# MITRE Software: corona updates | Software ID: S0425 | Type: Malware
# MITRE Software: desert scorpion | Software ID: S0505 | Type: Malware
# MITRE Software: dresscode | Software ID: S0300 | Type: Malware
# MITRE Software: flixonline | Software ID: S1103 | Type: Malware
# MITRE Software: frozencell | Software ID: S0577 | Type: Malware
# MITRE Software: golden cup | Software ID: S0535 | Type: Malware
# MITRE Software: golfspy | Software ID: S0421 | Type: Malware
# MITRE Software: gooligan | Software ID: S0290 | Type: Malware
# MITRE Software: hornbill | Software ID: S1077 | Type: Malware
# MITRE Software: hummingbad | Software ID: S0322 | Type: Malware
# MITRE Software: hummingwhale | Software ID: S0321 | Type: Malware
# MITRE Software: judy | Software ID: S0325 | Type: Malware
# MITRE Software: keyraider | Software ID: S0288 | Type: Malware
# MITRE Software: notcompatible | Software ID: S0299 | Type: Malware
# MITRE Software: obad | Software ID: S0286 | Type: Malware
# MITRE Software: oldboot | Software ID: S0285 | Type: Malware
# MITRE Software: pjapps | Software ID: S0291 | Type: Malware
# MITRE Software: pallas | Software ID: S0399 | Type: Malware
# MITRE Software: pegasus for ios | Software ID: S0289 | Type: Malware
# MITRE Software: rcsandroid | Software ID: S0295 | Type: Malware
# MITRE Software: red alert 2.0 | Software ID: S0539 | Type: Malware
# MITRE Software: reddrop | Software ID: S0326 | Type: Malware
# MITRE Software: rotexy | Software ID: S0411 | Type: Malware
# MITRE Software: rumms | Software ID: S0313 | Type: Malware
# MITRE Software: shiftybug | Software ID: S0294 | Type: Malware
# MITRE Software: simbad | Software ID: S0419 | Type: Malware
# MITRE Software: spydealer | Software ID: S0324 | Type: Malware
# MITRE Software: spynote rat | Software ID: S0305 | Type: Malware
# MITRE Software: sunbird | Software ID: S1082 | Type: Malware
# MITRE Software: terracotta | Software ID: S0545 | Type: Malware
# MITRE Software: tangelo | Software ID: S0329 | Type: Malware
# MITRE Software: tiktok pro | Software ID: S0558 | Type: Malware
# MITRE Software: trojan-sms.androidos.agent.ao | Software ID: S0307 | Type: Malware
# MITRE Software: trojan-sms.androidos.fakeinst.a | Software ID: S0306 | Type: Malware
# MITRE Software: trojan-sms.androidos.opfake.a | Software ID: S0308 | Type: Malware
# MITRE Software: twitoor | Software ID: S0302 | Type: Malware
# MITRE Software: viperrat | Software ID: S0506 | Type: Malware
# MITRE Software: x-agent for android | Software ID: S0314 | Type: Malware
# MITRE Software: xloader for android | Software ID: S0318 | Type: Malware
# MITRE Software: xloader for ios | Software ID: S0490 | Type: Malware
# MITRE Software: xcodeghost | Software ID: S0297 | Type: Malware
# MITRE Software: yispecter | Software ID: S0311 | Type: Malware
# MITRE Software: zerghelper | Software ID: S0287 | Type: Malware
# MITRE Software: esurv | Software ID: S0507 | Type: Malware
#
# Total Malwares: 247
# Total Tools: 68

# %%
# Load the MITRE software mappings file (this should be the mappings created from the Excel files software ID: alias : Type)
mitre_software_mappings = read_mitre_software_file()
malpedia_families_data = read_malware_families_from_file()

# Open file in append mode (or write mode, if needed) with utf-8 encoding
with open('software_name_alias_normalization.csv', 'a', newline='', encoding='utf-8') as csvfile:
        csvwriter = csv.writer(csvfile)

        # Check if the file is empty and write the header if necessary
        try:
            # Try to move to the beginning of the file
            csvfile.seek(0, 2)  # Go to the end of the file
            if csvfile.tell() == 0:  # If file size is 0, write header
                csvwriter.writerow(['Software Name', 'Aliases', 'Normalized Name'])
        except Exception as e:
            print(f"Error checking file for header: {e}")

        # Loop through each MITRE software in mitre_software_mappings
        for software_id, software_info in mitre_software_mappings.items():
            original_software_name = software_info['name']
            normalized_software_name = normalize_name(software_info['name'])

                    # Handle cases where 'aliases' might be NaN or other non-list types
            aliases = software_info.get('aliases', [])
            if isinstance(aliases, float) or aliases is None:  # Check if it's NaN or None
               aliases = []  # Set to empty list
            else:
               aliases = [(alias) for alias in aliases]
            

             # Write MITRE group name, aliases (comma-separated), and normalized name to file
            csvwriter.writerow([f"mitre_{original_software_name}", ', '.join(aliases), normalized_software_name])


                # Loop through each Malpedia family in malpedia_families_data
        for family_id, family_info in malpedia_families_data.items():
            original_family_name = family_id 
            common_name = family_info.get('common_name', '')
            normalize_family_name = normalize_name(family_id)  # Normalize Malpedia family name
            alt_names = [(alt_name) for alt_name in family_info.get('alt_names', [])]  

            # Write Malpedia group name, aliases (comma-separated), and normalized name to file
            csvwriter.writerow([f"malpedia_{common_name}", ', '.join(alt_names), normalize_family_name])

# %%
## normalize aliases? 
## malpedia has a common name and another name with apk, win, elf prefix...
