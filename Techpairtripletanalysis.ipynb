# %%
import json
from itertools import combinations
from collections import defaultdict

# %%
def find_groups_with_unique_techniques(json_path):
    """
    Identifies groups that have techniques not used by any other group,
    and prints technique IDs along with their names.

    Parameters
    ----------
    json_path : str
        Path to the JSON file containing techniques_map.

    Returns
    -------
    dict
        Contains per-group unique techniques and total globally unique techniques.
    """
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Reverse map: technique_id → set of group_ids
    technique_to_groups = defaultdict(set)

    for group_id, info in data.items():
        for tech_id in info.get("items", []):
            technique_to_groups[tech_id].add(group_id)

    group_results = []
    globally_unique_techniques = set()

    for tech_id, groups in technique_to_groups.items():
        if len(groups) == 1:
            globally_unique_techniques.add(tech_id)

    for group_id, info in data.items():
        group_name = info.get("name", "")
        techniques = info.get("items", [])
        technique_names = info.get("technique name", [])
        tech_map = dict(zip(techniques, technique_names))

        unique_techniques = [
            (t, tech_map.get(t, "<unknown>")) for t in techniques if t in globally_unique_techniques
        ]

        if unique_techniques:
            group_results.append((group_id, group_name, unique_techniques))

    # Output summary
    print(f"Total groups with unique techniques: {len(group_results)}")
    print(f"Total unique techniques across all groups: {len(globally_unique_techniques)}\n")

    for group_id, group_name, techniques in group_results:
        print(f"Group: {group_id} ({group_name})")
        print(f"  Unique Techniques ({len(techniques)}):")
        for tid, tname in techniques:
            print(f"    - {tid}: {tname}")
        print()

    return {
        "groups_with_uniques": group_results,
        "total_unique_techniques": len(globally_unique_techniques),
        "globally_unique_techniques": globally_unique_techniques
    }

# %%
# Example usage
json_path = "mitre_techniques_map.json"  # Replace with actual path
groups_with_uniques = find_groups_with_unique_techniques(json_path)
# Out:
# Total groups with unique techniques: 52
# Total unique techniques across all groups: 147
#
# Group: G0001 (Axiom)
#   Unique Techniques (3):
#     - T1563.002: RDP Hijacking
#     - T1001.002: Steganography
#     - T1553: Subvert Trust Controls
#
# Group: G0004 (Ke3chang)
#   Unique Techniques (1):
#     - T1558.001: Golden Ticket
#
# Group: G0005 (APT12)
#   Unique Techniques (1):
#     - T1568.003: DNS Calculation
#
# Group: G0007 (APT28)
#   Unique Techniques (8):
#     - T1550.001: Application Access Token
#     - T1092: Communication Through Removable Media
#     - T1546.015: Component Object Model Hijacking
#     - T1048.002: Exfiltration Over Asymmetric Encrypted Non-C2 Protocol
#     - T1211: Exploitation for Defense Evasion
#     - T1001.001: Junk Data
#     - T1498: Network Denial of Service
#     - T1137.002: Office Test
#
# Group: G0010 (Turla)
#   Unique Techniques (3):
#     - T1615: Group Policy Discovery
#     - T1546.013: Process Discovery
#     - T1584.003: Visual Basic
#
# Group: G0012 (Darkhotel)
#   Unique Techniques (1):
#     - T1497: Virtualization/Sandbox Evasion
#
# Group: G0016 (APT29)
#   Unique Techniques (11):
#     - T1087.004: Cloud Account
#     - T1586.003: Cloud Administration Command
#     - T1651: Data from Local System
#     - T1098.005: Disable or Modify Cloud Logs
#     - T1562.008: Dynamic Resolution
#     - T1090.004: Email Accounts
#     - T1027.006: Hybrid Identity
#     - T1665: Ingress Tool Transfer
#     - T1556.007: Internet Connection Discovery
#     - T1037.004: Remote Email Collection
#     - T1649: Tool
#
# Group: G0019 (Naikon)
#   Unique Techniques (1):
#     - T1137.006: Add-ins
#
# Group: G0020 (Equation)
#   Unique Techniques (1):
#     - T1542.002: Component Firmware
#
# Group: G0027 (Threat Group-3390)
#   Unique Techniques (2):
#     - T1070.005: Network Share Connection Removal
#     - T1608.002: Upload Tool
#
# Group: G0032 (Lazarus Group)
#   Unique Techniques (6):
#     - T1561.001: Disk Content Wipe
#     - T1027.007: Dynamic API Resolution
#     - T1202: Indirect Command Execution
#     - T1574.013: KernelCallbackTable
#     - T1620: Reflective Code Loading
#     - T1218: System Binary Proxy Execution
#
# Group: G0034 (Sandworm Team)
#   Unique Techniques (9):
#     - T1583: Acquire Infrastructure
#     - T1590.001: Domain Properties
#     - T1499: Endpoint Denial of Service
#     - T1491.002: External Defacement
#     - T1593: Search Open Websites/Domains
#     - T1588.006: Web Shell
#     - T0807: <unknown>
#     - T0884: <unknown>
#     - T0819: <unknown>
#
# Group: G0041 (Strider)
#   Unique Techniques (1):
#     - T1556.002: Password Filter DLL
#
# Group: G0046 (FIN7)
#   Unique Techniques (1):
#     - T1546.011: Application Shimming
#
# Group: G0049 (OilRig)
#   Unique Techniques (2):
#     - T1137.004: Outlook Home Page
#     - T0869: <unknown>
#
# Group: G0050 (APT32)
#   Unique Techniques (3):
#     - T1552.002: Credentials in Registry
#     - T1564.004: NTFS File Attributes
#     - T1216.001: PubPrn
#
# Group: G0056 (PROMETHIUM)
#   Unique Techniques (1):
#     - T1205.001: Port Knocking
#
# Group: G0059 (Magic Hound)
#   Unique Techniques (3):
#     - T1591.001: Determine Physical Locations
#     - T1562: Internet Connection Discovery
#     - T1016.002: <unknown>
#
# Group: G0061 (FIN8)
#   Unique Techniques (1):
#     - T1055.004: Asynchronous Procedure Call
#
# Group: G0065 (Leviathan)
#   Unique Techniques (1):
#     - T1102.003: PowerShell
#
# Group: G0067 (APT37)
#   Unique Techniques (1):
#     - T1123: Audio Capture
#
# Group: G0068 (PLATINUM)
#   Unique Techniques (1):
#     - T1056.004: Credential API Hooking
#
# Group: G0069 (MuddyWater)
#   Unique Techniques (1):
#     - T1137.001: Office Template Macros
#
# Group: G0070 (Dark Caracal)
#   Unique Techniques (1):
#     - T1437.001: <unknown>
#
# Group: G0077 (Leafminer)
#   Unique Techniques (1):
#     - T1055.013: Process DoppelgÃ¤nging
#
# Group: G0080 (Cobalt Group)
#   Unique Techniques (1):
#     - T1218.008: Odbcconf
#
# Group: G0082 (APT38)
#   Unique Techniques (4):
#     - T1562.003: Impair Command History Logging
#     - T1565.003: Runtime Data Manipulation
#     - T1565.001: Stored Data Manipulation
#     - T1565.002: Transmitted Data Manipulation
#
# Group: G0085 (FIN4)
#   Unique Techniques (1):
#     - T1056.002: GUI Input Capture
#
# Group: G0087 (APT39)
#   Unique Techniques (3):
#     - T1546.010: AppInit DLLs
#     - T1059.010: AutoHotKey & AutoIT
#     - T1056: Input Capture
#
# Group: G0094 (Kimsuky)
#   Unique Techniques (6):
#     - T1557: Adversary-in-the-Middle
#     - T1176: Browser Extensions
#     - T1546.001: Change Default File Association
#     - T1587: Develop Capabilities
#     - T1588.005: File Deletion
#     - T1593.002: Security Software Discovery
#
# Group: G0096 (APT41)
#   Unique Techniques (1):
#     - T1596.005: Scheduled Task
#
# Group: G0102 (Wizard Spider)
#   Unique Techniques (3):
#     - T1490: Kerberoasting
#     - T1021: Remote System Discovery
#     - T1222.001: Windows Management Instrumentation
#
# Group: G0105 (DarkVishnya)
#   Unique Techniques (1):
#     - T1200: Hardware Additions
#
# Group: G0108 (Blue Mockingbird)
#   Unique Techniques (1):
#     - T1574.012: COR_PROFILER
#
# Group: G0112 (Windshift)
#   Unique Techniques (16):
#     - T1429: Audio Capture
#     - T1632.001: Code Signing Policy Modification
#     - T1628.003: Conceal Multimedia Files
#     - T1636.003: Contact List
#     - T1533: Data from Local System
#     - T1407: Download New Code at Runtime
#     - T1420: File and Directory Discovery
#     - T1627.001: Geofencing
#     - T1417.001: Keylogging
#     - T1430: Location Tracking
#     - T1406: SMS Messages
#     - T1636.004: Symmetric Cryptography
#     - T1521.001: System Checks
#     - T1633.001: Video Capture
#     - T1426: <unknown>
#     - T1512: <unknown>
#
# Group: G0114 (Chimera)
#   Unique Techniques (2):
#     - T1110.004: Credential Stuffing
#     - T1556.001: Domain Controller Authentication
#
# Group: G0125 (HAFNIUM)
#   Unique Techniques (2):
#     - T1592.004: Client Configurations
#     - T1590: Gather Victim Network Information
#
# Group: G0126 (Higaisa)
#   Unique Techniques (1):
#     - T1029: Scheduled Transfer
#
# Group: G0129 (Mustang Panda)
#   Unique Techniques (2):
#     - T1036.007: Double File Extension
#     - T1608: Symmetric Cryptography
#
# Group: G0139 (TeamTNT)
#   Unique Techniques (9):
#     - T1552.005: Cloud Instance Metadata API
#     - T1609: Container Administration Command
#     - T1613: Container and Resource Discovery
#     - T1610: Deploy Container
#     - T1611: Escape to Host
#     - T1048: Exfiltration Over Alternative Protocol
#     - T1204.003: Malicious Image
#     - T1595.001: Scanning IP Blocks
#     - T1569: System Services
#
# Group: G1003 (Ember Bear)
#   Unique Techniques (1):
#     - T1218.002: Control Panel
#
# Group: G1004 (LAPSUS$)
#   Unique Techniques (6):
#     - T1552.008: Chat Messages
#     - T1593.003: Code Repositories
#     - T1213.001: Create Cloud Instance
#     - T1584.002: Data Destruction
#     - T1578.003: Domain Account
#     - T1597.002: Service Stop
#
# Group: G1006 (Earth Lusca)
#   Unique Techniques (2):
#     - T1547.012: Print Processors
#     - T1053: Scheduled Task/Job
#
# Group: G1008 (SideCopy)
#   Unique Techniques (1):
#     - T1614: System Network Configuration Discovery
#
# Group: G1011 (EXOTIC LILY)
#   Unique Techniques (1):
#     - T1597: Search Closed Sources
#
# Group: G1015 (Scattered Spider)
#   Unique Techniques (6):
#     - T1580: Cloud Infrastructure Discovery
#     - T1538: Cloud Service Dashboard
#     - T1556.009: Conditional Access Policies
#     - T1006: Direct Volume Access
#     - T1556.006: Multi-Factor Authentication
#     - T1484.002: Trust Modification
#
# Group: G1016 (FIN13)
#   Unique Techniques (5):
#     - T1087: Account Discovery
#     - T1565: Data Manipulation
#     - T1134.003: Make and Impersonate Token
#     - T1556: Modify Authentication Process
#     - T1590.004: Network Topology
#
# Group: G1017 (Volt Typhoon)
#   Unique Techniques (2):
#     - T1070.007: Clear Network Connection History and Configurations
#     - T1036.008: Masquerade File Type
#
# Group: G1019 (MoustachedBouncer)
#   Unique Techniques (1):
#     - T1659: Content Injection
#
# Group: G1020 (Mustard Tempest)
#   Unique Techniques (2):
#     - T1583.008: Malvertising
#     - T1608.006: SEO Poisoning
#
# Group: G1023 (APT5)
#   Unique Techniques (1):
#     - T1554: Compromise Host Software Binary
#
# Group: G1028 (APT-C-23)
#   Unique Techniques (1):
#     - T1422: System Network Configuration Discovery

# %%
def find_unique_technique_pairs_with_names(json_path):
    """
    Analyze groups to find unique technique pairs (after removing globally unique techniques),
    and print both technique IDs and names.

    Parameters
    ----------
    json_path : str
        Path to JSON file containing techniques_map.

    Returns
    -------
    dict
        Summary of analysis, including groups with unique pairs and newly discovered unique pair groups.
    """
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Build technique-to-groups mapping
    technique_to_groups = defaultdict(set)
    for group_id, info in data.items():
        for tech in info.get("items", []):
            technique_to_groups[tech].add(group_id)

    # Identify globally unique techniques
    globally_unique_techniques = {tech for tech, groups in technique_to_groups.items() if len(groups) == 1}

    # Build pair-to-groups and group-to-pairs mappings
    pair_to_groups = defaultdict(set)
    group_to_pairs = dict()

    for group_id, info in data.items():
        techs = info.get("items", [])
        tech_names = info.get("technique name", [])
        tech_map = dict(zip(techs, tech_names))

        filtered_techs = [t for t in techs if t not in globally_unique_techniques]
        pairs = list(combinations(sorted(filtered_techs), 2))
        group_to_pairs[group_id] = {
            "pairs": pairs,
            "tech_map": tech_map,
            "name": info.get("name", "")
        }

        for pair in pairs:
            pair_to_groups[pair].add(group_id)

    # Identify unique pairs (appear in only one group)
    unique_pairs = {pair for pair, groups in pair_to_groups.items() if len(groups) == 1}

    # Find which groups contain at least one unique pair
    group_with_unique_pairs = defaultdict(list)
    for group_id, pair_info in group_to_pairs.items():
        for pair in pair_info["pairs"]:
            if pair in unique_pairs:
                group_with_unique_pairs[group_id].append(pair)

    # Compare to groups that already had globally unique techniques
    groups_with_unique_techs = {group_id for group_id, info in data.items()
                                 if any(t in globally_unique_techniques for t in info.get("items", []))}
    new_groups_with_unique_pairs = set(group_with_unique_pairs) - groups_with_unique_techs

    # Print Summary
    print(f"\nTotal groups with globally unique techniques: {len(groups_with_unique_techs)}")
    print(f"Total groups with unique technique pairs (excluding globals): {len(group_with_unique_pairs)}")
    print(f"New groups with unique technique pairs only: {len(new_groups_with_unique_pairs)}\n")

    for group_id in sorted(group_with_unique_pairs):
        info = group_to_pairs[group_id]
        tech_map = info["tech_map"]
        print(f"Group: {group_id} ({info['name']})")
        for t1, t2 in group_with_unique_pairs[group_id]:
            print(f"  - ({t1}, {t2}) → \"{tech_map.get(t1)}\" + \"{tech_map.get(t2)}\"")
        print()

    return {
        "groups_with_unique_pairs": group_with_unique_pairs,
        "new_unique_pair_groups": new_groups_with_unique_pairs,
        "all_unique_pairs": unique_pairs
    }

# %%
result = find_unique_technique_pairs_with_names(json_path)
# Out:
# Total groups with globally unique techniques: 52
# Total groups with unique technique pairs (excluding globals): 112
# New groups with unique technique pairs only: 63
#
# Group: G0001 (Axiom)
#   - (T1003, T1546.008) → "OS Credential Dumping" + "Accessibility Features"
#   - (T1003, T1566) → "OS Credential Dumping" + "Phishing"
#   - (T1003, T1583.002) → "OS Credential Dumping" + "DNS Server"
#   - (T1003, T1584.005) → "OS Credential Dumping" + "Botnet"
#   - (T1005, T1566) → "Data from Local System" + "Phishing"
#   - (T1005, T1583.002) → "Data from Local System" + "DNS Server"
#   - (T1021.001, T1566) → "Remote Desktop Protocol" + "Phishing"
#   - (T1021.001, T1584.005) → "Remote Desktop Protocol" + "Botnet"
#   - (T1078, T1566) → "Valid Accounts" + "Phishing"
#   - (T1078, T1583.002) → "Valid Accounts" + "DNS Server"
#   - (T1189, T1546.008) → "Drive-by Compromise" + "Accessibility Features"
#   - (T1189, T1566) → "Drive-by Compromise" + "Phishing"
#   - (T1189, T1583.002) → "Drive-by Compromise" + "DNS Server"
#   - (T1189, T1584.005) → "Drive-by Compromise" + "Botnet"
#   - (T1190, T1583.002) → "Exploit Public-Facing Application" + "DNS Server"
#   - (T1203, T1566) → "Exploitation for Client Execution" + "Phishing"
#   - (T1203, T1583.002) → "Exploitation for Client Execution" + "DNS Server"
#   - (T1546.008, T1560) → "Accessibility Features" + "Archive Collected Data"
#   - (T1546.008, T1566) → "Accessibility Features" + "Phishing"
#   - (T1546.008, T1583.002) → "Accessibility Features" + "DNS Server"
#   - (T1546.008, T1583.003) → "Accessibility Features" + "Virtual Private Server"
#   - (T1546.008, T1584.005) → "Accessibility Features" + "Botnet"
#   - (T1560, T1566) → "Archive Collected Data" + "Phishing"
#   - (T1560, T1583.002) → "Archive Collected Data" + "DNS Server"
#   - (T1560, T1584.005) → "Archive Collected Data" + "Botnet"
#   - (T1566, T1583.002) → "Phishing" + "DNS Server"
#   - (T1566, T1583.003) → "Phishing" + "Virtual Private Server"
#   - (T1566, T1584.005) → "Phishing" + "Botnet"
#   - (T1583.002, T1583.003) → "DNS Server" + "Virtual Private Server"
#   - (T1583.002, T1584.005) → "DNS Server" + "Botnet"
#   - (T1583.003, T1584.005) → "Virtual Private Server" + "Botnet"
#
# Group: G0003 (Cleaver)
#   - (T1003.001, T1557.002) → "LSASS Memory" + "ARP Cache Poisoning"
#   - (T1557.002, T1585.001) → "ARP Cache Poisoning" + "Social Media Accounts"
#
# Group: G0004 (Ke3chang)
#   - (T1003.001, T1020) → "LSASS Memory" + "Automated Exfiltration"
#   - (T1003.001, T1614.001) → "LSASS Memory" + "System Language Discovery"
#   - (T1003.002, T1007) → "Security Account Manager" + "System Service Discovery"
#   - (T1003.002, T1020) → "Security Account Manager" + "Automated Exfiltration"
#   - (T1003.002, T1036.002) → "Security Account Manager" + "Right-to-Left Override"
#   - (T1003.002, T1213.002) → "Security Account Manager" + "Sharepoint"
#   - (T1003.002, T1614.001) → "Security Account Manager" + "System Language Discovery"
#   - (T1003.003, T1020) → "NTDS" + "Automated Exfiltration"
#   - (T1003.003, T1036.002) → "NTDS" + "Right-to-Left Override"
#   - (T1003.003, T1614.001) → "NTDS" + "System Language Discovery"
#   - (T1003.004, T1020) → "LSA Secrets" + "Automated Exfiltration"
#   - (T1003.004, T1021.002) → "LSA Secrets" + "SMB/Windows Admin Shares"
#   - (T1003.004, T1027) → "LSA Secrets" + "Obfuscated Files or Information"
#   - (T1003.004, T1036.002) → "LSA Secrets" + "Right-to-Left Override"
#   - (T1003.004, T1213.002) → "LSA Secrets" + "Sharepoint"
#   - (T1003.004, T1569.002) → "LSA Secrets" + "Service Execution"
#   - (T1003.004, T1614.001) → "LSA Secrets" + "System Language Discovery"
#   - (T1005, T1614.001) → "Data from Local System" + "System Language Discovery"
#   - (T1007, T1020) → "System Service Discovery" + "Automated Exfiltration"
#   - (T1007, T1078.004) → "System Service Discovery" + "Cloud Accounts"
#   - (T1007, T1560) → "System Service Discovery" + "Archive Collected Data"
#   - (T1007, T1614.001) → "System Service Discovery" + "System Language Discovery"
#   - (T1016, T1036.002) → "System Network Configuration Discovery" + "Right-to-Left Override"
#   - (T1016, T1078.004) → "System Network Configuration Discovery" + "Cloud Accounts"
#   - (T1016, T1614.001) → "System Network Configuration Discovery" + "System Language Discovery"
#   - (T1018, T1020) → "Remote System Discovery" + "Automated Exfiltration"
#   - (T1018, T1078.004) → "Remote System Discovery" + "Cloud Accounts"
#   - (T1018, T1614.001) → "Remote System Discovery" + "System Language Discovery"
#   - (T1020, T1021.002) → "Automated Exfiltration" + "SMB/Windows Admin Shares"
#   - (T1020, T1036.002) → "Automated Exfiltration" + "Right-to-Left Override"
#   - (T1020, T1056.001) → "Automated Exfiltration" + "Keylogging"
#   - (T1020, T1059) → "Automated Exfiltration" + "Command and Scripting Interpreter"
#   - (T1020, T1069.002) → "Automated Exfiltration" + "Domain Groups"
#   - (T1020, T1078) → "Automated Exfiltration" + "Valid Accounts"
#   - (T1020, T1078.004) → "Automated Exfiltration" + "Cloud Accounts"
#   - (T1020, T1087.001) → "Automated Exfiltration" + "Local Account"
#   - (T1020, T1087.002) → "Automated Exfiltration" + "Domain Account"
#   - (T1020, T1114.002) → "Automated Exfiltration" + "Remote Email Collection"
#   - (T1020, T1133) → "Automated Exfiltration" + "External Remote Services"
#   - (T1020, T1190) → "Automated Exfiltration" + "Exploit Public-Facing Application"
#   - (T1020, T1213.002) → "Automated Exfiltration" + "Sharepoint"
#   - (T1020, T1560) → "Automated Exfiltration" + "Archive Collected Data"
#   - (T1020, T1560.001) → "Automated Exfiltration" + "Archive via Utility"
#   - (T1020, T1569.002) → "Automated Exfiltration" + "Service Execution"
#   - (T1020, T1587.001) → "Automated Exfiltration" + "Malware"
#   - (T1020, T1588.002) → "Automated Exfiltration" + "Tool"
#   - (T1020, T1614.001) → "Automated Exfiltration" + "System Language Discovery"
#   - (T1021.002, T1036.002) → "SMB/Windows Admin Shares" + "Right-to-Left Override"
#   - (T1021.002, T1614.001) → "SMB/Windows Admin Shares" + "System Language Discovery"
#   - (T1027, T1036.002) → "Obfuscated Files or Information" + "Right-to-Left Override"
#   - (T1027, T1069.002) → "Obfuscated Files or Information" + "Domain Groups"
#   - (T1027, T1078.004) → "Obfuscated Files or Information" + "Cloud Accounts"
#   - (T1027, T1213.002) → "Obfuscated Files or Information" + "Sharepoint"
#   - (T1027, T1560) → "Obfuscated Files or Information" + "Archive Collected Data"
#   - (T1027, T1614.001) → "Obfuscated Files or Information" + "System Language Discovery"
#   - (T1033, T1036.002) → "System Owner/User Discovery" + "Right-to-Left Override"
#   - (T1033, T1078.004) → "System Owner/User Discovery" + "Cloud Accounts"
#   - (T1033, T1614.001) → "System Owner/User Discovery" + "System Language Discovery"
#   - (T1036.002, T1041) → "Right-to-Left Override" + "Exfiltration Over C2 Channel"
#   - (T1036.002, T1049) → "Right-to-Left Override" + "System Network Connections Discovery"
#   - (T1036.002, T1056.001) → "Right-to-Left Override" + "Keylogging"
#   - (T1036.002, T1057) → "Right-to-Left Override" + "Process Discovery"
#   - (T1036.002, T1059) → "Right-to-Left Override" + "Command and Scripting Interpreter"
#   - (T1036.002, T1069.002) → "Right-to-Left Override" + "Domain Groups"
#   - (T1036.002, T1071.004) → "Right-to-Left Override" + "DNS"
#   - (T1036.002, T1078) → "Right-to-Left Override" + "Valid Accounts"
#   - (T1036.002, T1078.004) → "Right-to-Left Override" + "Cloud Accounts"
#   - (T1036.002, T1082) → "Right-to-Left Override" + "System Information Discovery"
#   - (T1036.002, T1087.001) → "Right-to-Left Override" + "Local Account"
#   - (T1036.002, T1114.002) → "Right-to-Left Override" + "Remote Email Collection"
#   - (T1036.002, T1119) → "Right-to-Left Override" + "Automated Collection"
#   - (T1036.002, T1133) → "Right-to-Left Override" + "External Remote Services"
#   - (T1036.002, T1213.002) → "Right-to-Left Override" + "Sharepoint"
#   - (T1036.002, T1543.003) → "Right-to-Left Override" + "Windows Service"
#   - (T1036.002, T1560) → "Right-to-Left Override" + "Archive Collected Data"
#   - (T1036.002, T1569.002) → "Right-to-Left Override" + "Service Execution"
#   - (T1036.002, T1587.001) → "Right-to-Left Override" + "Malware"
#   - (T1036.002, T1614.001) → "Right-to-Left Override" + "System Language Discovery"
#   - (T1036.005, T1614.001) → "Match Legitimate Name or Location" + "System Language Discovery"
#   - (T1041, T1069.002) → "Exfiltration Over C2 Channel" + "Domain Groups"
#   - (T1041, T1078.004) → "Exfiltration Over C2 Channel" + "Cloud Accounts"
#   - (T1041, T1614.001) → "Exfiltration Over C2 Channel" + "System Language Discovery"
#   - (T1049, T1614.001) → "System Network Connections Discovery" + "System Language Discovery"
#   - (T1056.001, T1614.001) → "Keylogging" + "System Language Discovery"
#   - (T1057, T1614.001) → "Process Discovery" + "System Language Discovery"
#   - (T1059, T1078.004) → "Command and Scripting Interpreter" + "Cloud Accounts"
#   - (T1059, T1213.002) → "Command and Scripting Interpreter" + "Sharepoint"
#   - (T1059, T1614.001) → "Command and Scripting Interpreter" + "System Language Discovery"
#   - (T1059.003, T1614.001) → "Windows Command Shell" + "System Language Discovery"
#   - (T1069.002, T1569.002) → "Domain Groups" + "Service Execution"
#   - (T1069.002, T1614.001) → "Domain Groups" + "System Language Discovery"
#   - (T1071.001, T1614.001) → "Web Protocols" + "System Language Discovery"
#   - (T1071.004, T1078.004) → "DNS" + "Cloud Accounts"
#   - (T1071.004, T1560) → "DNS" + "Archive Collected Data"
#   - (T1071.004, T1614.001) → "DNS" + "System Language Discovery"
#   - (T1078, T1614.001) → "Valid Accounts" + "System Language Discovery"
#   - (T1078.004, T1082) → "Cloud Accounts" + "System Information Discovery"
#   - (T1078.004, T1087.001) → "Cloud Accounts" + "Local Account"
#   - (T1078.004, T1543.003) → "Cloud Accounts" + "Windows Service"
#   - (T1078.004, T1569.002) → "Cloud Accounts" + "Service Execution"
#   - (T1078.004, T1614.001) → "Cloud Accounts" + "System Language Discovery"
#   - (T1083, T1614.001) → "File and Directory Discovery" + "System Language Discovery"
#   - (T1087.001, T1614.001) → "Local Account" + "System Language Discovery"
#   - (T1087.002, T1614.001) → "Domain Account" + "System Language Discovery"
#   - (T1105, T1614.001) → "Ingress Tool Transfer" + "System Language Discovery"
#   - (T1114.002, T1614.001) → "Remote Email Collection" + "System Language Discovery"
#   - (T1119, T1587.001) → "Automated Collection" + "Malware"
#   - (T1119, T1614.001) → "Automated Collection" + "System Language Discovery"
#   - (T1133, T1614.001) → "External Remote Services" + "System Language Discovery"
#   - (T1190, T1614.001) → "Exploit Public-Facing Application" + "System Language Discovery"
#   - (T1213.002, T1543.003) → "Sharepoint" + "Windows Service"
#   - (T1213.002, T1587.001) → "Sharepoint" + "Malware"
#   - (T1213.002, T1614.001) → "Sharepoint" + "System Language Discovery"
#   - (T1543.003, T1614.001) → "Windows Service" + "System Language Discovery"
#   - (T1547.001, T1614.001) → "Registry Run Keys / Startup Folder" + "System Language Discovery"
#   - (T1560, T1614.001) → "Archive Collected Data" + "System Language Discovery"
#   - (T1560.001, T1614.001) → "Archive via Utility" + "System Language Discovery"
#   - (T1569.002, T1587.001) → "Service Execution" + "Malware"
#   - (T1569.002, T1614.001) → "Service Execution" + "System Language Discovery"
#   - (T1587.001, T1614.001) → "Malware" + "System Language Discovery"
#   - (T1588.002, T1614.001) → "Tool" + "System Language Discovery"
#
# Group: G0006 (APT1)
#   - (T1021.001, T1588.001) → "Remote Email Collection" + "Match Legitimate Name or Location"
#   - (T1087.001, T1584.001) → "Local Email Collection" + "Email Accounts"
#   - (T1087.001, T1585.002) → "Local Email Collection" + "LSASS Memory"
#   - (T1114.001, T1566.001) → "Malware" + "Spearphishing Link"
#   - (T1114.001, T1588.001) → "Malware" + "Match Legitimate Name or Location"
#   - (T1114.002, T1588.001) → "Spearphishing Attachment" + "Match Legitimate Name or Location"
#   - (T1119, T1584.001) → "Automated Collection" + "Email Accounts"
#   - (T1119, T1588.001) → "Automated Collection" + "Match Legitimate Name or Location"
#   - (T1135, T1584.001) → "Pass the Hash" + "Email Accounts"
#   - (T1135, T1588.001) → "Pass the Hash" + "Match Legitimate Name or Location"
#   - (T1550.002, T1588.001) → "Process Discovery" + "Match Legitimate Name or Location"
#   - (T1584.001, T1588.001) → "Email Accounts" + "Match Legitimate Name or Location"
#   - (T1585.002, T1588.001) → "LSASS Memory" + "Match Legitimate Name or Location"
#
# Group: G0007 (APT28)
#   - (T1003, T1003.003) → "OS Credential Dumping" + "NTDS"
#   - (T1003, T1014) → "OS Credential Dumping" + "Rootkit"
#   - (T1003, T1025) → "OS Credential Dumping" + "Data from Removable Media"
#   - (T1003, T1030) → "OS Credential Dumping" + "Data Transfer Size Limits"
#   - (T1003, T1037.001) → "OS Credential Dumping" + "Logon Script (Windows)"
#   - (T1003, T1040) → "OS Credential Dumping" + "Network Sniffing"
#   - (T1003, T1078.004) → "OS Credential Dumping" + "Cloud Accounts"
#   - (T1003, T1091) → "OS Credential Dumping" + "Replication Through Removable Media"
#   - (T1003, T1098.002) → "OS Credential Dumping" + "Additional Email Delegate Permissions"
#   - (T1003, T1110.001) → "OS Credential Dumping" + "Password Guessing"
#   - (T1003, T1110.003) → "OS Credential Dumping" + "Password Spraying"
#   - (T1003, T1114.002) → "OS Credential Dumping" + "Remote Email Collection"
#   - (T1003, T1119) → "OS Credential Dumping" + "Automated Collection"
#   - (T1003, T1120) → "OS Credential Dumping" + "Peripheral Device Discovery"
#   - (T1003, T1134.001) → "OS Credential Dumping" + "Tool"
#   - (T1003, T1199) → "OS Credential Dumping" + "Valid Accounts"
#   - (T1003, T1213) → "OS Credential Dumping" + "Data from Information Repositories"
#   - (T1003, T1213.002) → "OS Credential Dumping" + "Sharepoint"
#   - (T1003, T1221) → "OS Credential Dumping" + "Timestomp"
#   - (T1003, T1528) → "OS Credential Dumping" + "Symmetric Cryptography"
#   - (T1003, T1542.003) → "OS Credential Dumping" + "Bootkit"
#   - (T1003, T1567) → "OS Credential Dumping" + "Exfiltration Over Web Service"
#   - (T1003, T1573.001) → "OS Credential Dumping" + "Template Injection"
#   - (T1003, T1584.008) → "OS Credential Dumping" + "Network Devices"
#   - (T1003, T1595.002) → "OS Credential Dumping" + "Web Protocols"
#   - (T1003, T1598) → "OS Credential Dumping" + "Phishing for Information"
#   - (T1003.001, T1025) → "LSASS Memory" + "Data from Removable Media"
#   - (T1003.001, T1037.001) → "LSASS Memory" + "Logon Script (Windows)"
#   - (T1003.001, T1091) → "LSASS Memory" + "Replication Through Removable Media"
#   - (T1003.001, T1110.001) → "LSASS Memory" + "Password Guessing"
#   - (T1003.001, T1221) → "LSASS Memory" + "Timestomp"
#   - (T1003.001, T1528) → "LSASS Memory" + "Symmetric Cryptography"
#   - (T1003.001, T1598) → "LSASS Memory" + "Phishing for Information"
#   - (T1003.003, T1025) → "NTDS" + "Data from Removable Media"
#   - (T1003.003, T1037.001) → "NTDS" + "Logon Script (Windows)"
#   - (T1003.003, T1071.003) → "NTDS" + "Mail Protocols"
#   - (T1003.003, T1090.003) → "NTDS" + "Multi-hop Proxy"
#   - (T1003.003, T1098.002) → "NTDS" + "Additional Email Delegate Permissions"
#   - (T1003.003, T1110.001) → "NTDS" + "Password Guessing"
#   - (T1003.003, T1120) → "NTDS" + "Peripheral Device Discovery"
#   - (T1003.003, T1134.001) → "NTDS" + "Tool"
#   - (T1003.003, T1528) → "NTDS" + "Symmetric Cryptography"
#   - (T1003.003, T1559.002) → "NTDS" + "Dynamic Data Exchange"
#   - (T1003.003, T1564.003) → "NTDS" + "Hidden Window"
#   - (T1003.003, T1567) → "NTDS" + "Exfiltration Over Web Service"
#   - (T1005, T1037.001) → "Data from Local System" + "Logon Script (Windows)"
#   - (T1005, T1134.001) → "Data from Local System" + "Tool"
#   - (T1005, T1598) → "Data from Local System" + "Phishing for Information"
#   - (T1014, T1025) → "Rootkit" + "Data from Removable Media"
#   - (T1014, T1037.001) → "Rootkit" + "Logon Script (Windows)"
#   - (T1014, T1039) → "Rootkit" + "Data from Network Shared Drive"
#   - (T1014, T1040) → "Rootkit" + "Network Sniffing"
#   - (T1014, T1068) → "Rootkit" + "Exploitation for Privilege Escalation"
#   - (T1014, T1071.003) → "Rootkit" + "Mail Protocols"
#   - (T1014, T1074.002) → "Rootkit" + "Remote Data Staging"
#   - (T1014, T1078.004) → "Rootkit" + "Cloud Accounts"
#   - (T1014, T1090.002) → "Rootkit" + "External Proxy"
#   - (T1014, T1090.003) → "Rootkit" + "Multi-hop Proxy"
#   - (T1014, T1091) → "Rootkit" + "Replication Through Removable Media"
#   - (T1014, T1098.002) → "Rootkit" + "Additional Email Delegate Permissions"
#   - (T1014, T1102.002) → "Rootkit" + "Bidirectional Communication"
#   - (T1014, T1110) → "Rootkit" + "Brute Force"
#   - (T1014, T1110.001) → "Rootkit" + "Password Guessing"
#   - (T1014, T1110.003) → "Rootkit" + "Password Spraying"
#   - (T1014, T1113) → "Rootkit" + "Screen Capture"
#   - (T1014, T1114.002) → "Rootkit" + "Remote Email Collection"
#   - (T1014, T1119) → "Rootkit" + "Automated Collection"
#   - (T1014, T1134.001) → "Rootkit" + "Tool"
#   - (T1014, T1189) → "Rootkit" + "Drive-by Compromise"
#   - (T1014, T1199) → "Rootkit" + "Valid Accounts"
#   - (T1014, T1204.001) → "Rootkit" + "Malicious Link"
#   - (T1014, T1204.002) → "Rootkit" + "Malicious File"
#   - (T1014, T1210) → "Rootkit" + "Exploitation of Remote Services"
#   - (T1014, T1213) → "Rootkit" + "Data from Information Repositories"
#   - (T1014, T1213.002) → "Rootkit" + "Sharepoint"
#   - (T1014, T1221) → "Rootkit" + "Timestomp"
#   - (T1014, T1505.003) → "Rootkit" + "Windows Command Shell"
#   - (T1014, T1528) → "Rootkit" + "Symmetric Cryptography"
#   - (T1014, T1559.002) → "Rootkit" + "Dynamic Data Exchange"
#   - (T1014, T1560) → "Rootkit" + "Archive Collected Data"
#   - (T1014, T1564.003) → "Rootkit" + "Hidden Window"
#   - (T1014, T1566.002) → "Rootkit" + "Spearphishing Link"
#   - (T1014, T1567) → "Rootkit" + "Exfiltration Over Web Service"
#   - (T1014, T1573.001) → "Rootkit" + "Template Injection"
#   - (T1014, T1583.003) → "Rootkit" + "Vulnerability Scanning"
#   - (T1014, T1583.006) → "Rootkit" + "Web Shell"
#   - (T1014, T1584.008) → "Rootkit" + "Network Devices"
#   - (T1014, T1586.002) → "Rootkit" + "Email Accounts"
#   - (T1014, T1598) → "Rootkit" + "Phishing for Information"
#   - (T1014, T1598.003) → "Rootkit" + "Steal Application Access Token"
#   - (T1021.002, T1037.001) → "SMB/Windows Admin Shares" + "Logon Script (Windows)"
#   - (T1021.002, T1090.003) → "SMB/Windows Admin Shares" + "Multi-hop Proxy"
#   - (T1021.002, T1091) → "SMB/Windows Admin Shares" + "Replication Through Removable Media"
#   - (T1021.002, T1098.002) → "SMB/Windows Admin Shares" + "Additional Email Delegate Permissions"
#   - (T1021.002, T1110.001) → "SMB/Windows Admin Shares" + "Password Guessing"
#   - (T1021.002, T1221) → "SMB/Windows Admin Shares" + "Timestomp"
#   - (T1021.002, T1528) → "SMB/Windows Admin Shares" + "Symmetric Cryptography"
#   - (T1021.002, T1559.002) → "SMB/Windows Admin Shares" + "Dynamic Data Exchange"
#   - (T1021.002, T1567) → "SMB/Windows Admin Shares" + "Exfiltration Over Web Service"
#   - (T1021.002, T1583.003) → "SMB/Windows Admin Shares" + "Vulnerability Scanning"
#   - (T1021.002, T1584.008) → "SMB/Windows Admin Shares" + "Network Devices"
#   - (T1021.002, T1586.002) → "SMB/Windows Admin Shares" + "Email Accounts"
#   - (T1021.002, T1598) → "SMB/Windows Admin Shares" + "Phishing for Information"
#   - (T1025, T1027.013) → "Data from Removable Media" + "Encrypted/Encoded File"
#   - (T1025, T1030) → "Data from Removable Media" + "Data Transfer Size Limits"
#   - (T1025, T1036) → "Data from Removable Media" + "Masquerading"
#   - (T1025, T1037.001) → "Data from Removable Media" + "Logon Script (Windows)"
#   - (T1025, T1040) → "Data from Removable Media" + "Network Sniffing"
#   - (T1025, T1056.001) → "Data from Removable Media" + "Keylogging"
#   - (T1025, T1070.001) → "Data from Removable Media" + "Clear Windows Event Logs"
#   - (T1025, T1070.006) → "Data from Removable Media" + "Token Impersonation/Theft"
#   - (T1025, T1074.001) → "Data from Removable Media" + "Local Data Staging"
#   - (T1025, T1074.002) → "Data from Removable Media" + "Remote Data Staging"
#   - (T1025, T1078) → "Data from Removable Media" + "Virtual Private Server"
#   - (T1025, T1078.004) → "Data from Removable Media" + "Cloud Accounts"
#   - (T1025, T1090.002) → "Data from Removable Media" + "External Proxy"
#   - (T1025, T1090.003) → "Data from Removable Media" + "Multi-hop Proxy"
#   - (T1025, T1091) → "Data from Removable Media" + "Replication Through Removable Media"
#   - (T1025, T1098.002) → "Data from Removable Media" + "Additional Email Delegate Permissions"
#   - (T1025, T1110.001) → "Data from Removable Media" + "Password Guessing"
#   - (T1025, T1110.003) → "Data from Removable Media" + "Password Spraying"
#   - (T1025, T1114.002) → "Data from Removable Media" + "Remote Email Collection"
#   - (T1025, T1133) → "Data from Removable Media" + "External Remote Services"
#   - (T1025, T1134.001) → "Data from Removable Media" + "Tool"
#   - (T1025, T1190) → "Data from Removable Media" + "Exploit Public-Facing Application"
#   - (T1025, T1199) → "Data from Removable Media" + "Valid Accounts"
#   - (T1025, T1203) → "Data from Removable Media" + "Exploitation for Client Execution"
#   - (T1025, T1210) → "Data from Removable Media" + "Exploitation of Remote Services"
#   - (T1025, T1213.002) → "Data from Removable Media" + "Sharepoint"
#   - (T1025, T1505.003) → "Data from Removable Media" + "Windows Command Shell"
#   - (T1025, T1528) → "Data from Removable Media" + "Symmetric Cryptography"
#   - (T1025, T1542.003) → "Data from Removable Media" + "Bootkit"
#   - (T1025, T1550.002) → "Data from Removable Media" + "Pass the Hash"
#   - (T1025, T1559.002) → "Data from Removable Media" + "Dynamic Data Exchange"
#   - (T1025, T1560) → "Data from Removable Media" + "Archive Collected Data"
#   - (T1025, T1564.001) → "Data from Removable Media" + "Hidden Files and Directories"
#   - (T1025, T1567) → "Data from Removable Media" + "Exfiltration Over Web Service"
#   - (T1025, T1573.001) → "Data from Removable Media" + "Template Injection"
#   - (T1025, T1583.003) → "Data from Removable Media" + "Vulnerability Scanning"
#   - (T1025, T1584.008) → "Data from Removable Media" + "Network Devices"
#   - (T1025, T1586.002) → "Data from Removable Media" + "Email Accounts"
#   - (T1025, T1589.001) → "Data from Removable Media" + "Credentials"
#   - (T1025, T1595.002) → "Data from Removable Media" + "Web Protocols"
#   - (T1025, T1598) → "Data from Removable Media" + "Phishing for Information"
#   - (T1025, T1598.003) → "Data from Removable Media" + "Steal Application Access Token"
#   - (T1027.013, T1037.001) → "Encrypted/Encoded File" + "Logon Script (Windows)"
#   - (T1027.013, T1110.001) → "Encrypted/Encoded File" + "Password Guessing"
#   - (T1027.013, T1134.001) → "Encrypted/Encoded File" + "Tool"
#   - (T1027.013, T1213.002) → "Encrypted/Encoded File" + "Sharepoint"
#   - (T1027.013, T1528) → "Encrypted/Encoded File" + "Symmetric Cryptography"
#   - (T1027.013, T1583.003) → "Encrypted/Encoded File" + "Vulnerability Scanning"
#   - (T1027.013, T1584.008) → "Encrypted/Encoded File" + "Network Devices"
#   - (T1027.013, T1598) → "Encrypted/Encoded File" + "Phishing for Information"
#   - (T1030, T1036) → "Data Transfer Size Limits" + "Masquerading"
#   - (T1030, T1037.001) → "Data Transfer Size Limits" + "Logon Script (Windows)"
#   - (T1030, T1039) → "Data Transfer Size Limits" + "Data from Network Shared Drive"
#   - (T1030, T1040) → "Data Transfer Size Limits" + "Network Sniffing"
#   - (T1030, T1057) → "Data Transfer Size Limits" + "Process Discovery"
#   - (T1030, T1070.006) → "Data Transfer Size Limits" + "Token Impersonation/Theft"
#   - (T1030, T1071.003) → "Data Transfer Size Limits" + "Mail Protocols"
#   - (T1030, T1078.004) → "Data Transfer Size Limits" + "Cloud Accounts"
#   - (T1030, T1090.002) → "Data Transfer Size Limits" + "External Proxy"
#   - (T1030, T1090.003) → "Data Transfer Size Limits" + "Multi-hop Proxy"
#   - (T1030, T1098.002) → "Data Transfer Size Limits" + "Additional Email Delegate Permissions"
#   - (T1030, T1102.002) → "Data Transfer Size Limits" + "Bidirectional Communication"
#   - (T1030, T1110) → "Data Transfer Size Limits" + "Brute Force"
#   - (T1030, T1110.001) → "Data Transfer Size Limits" + "Password Guessing"
#   - (T1030, T1110.003) → "Data Transfer Size Limits" + "Password Spraying"
#   - (T1030, T1113) → "Data Transfer Size Limits" + "Screen Capture"
#   - (T1030, T1114.002) → "Data Transfer Size Limits" + "Remote Email Collection"
#   - (T1030, T1120) → "Data Transfer Size Limits" + "Peripheral Device Discovery"
#   - (T1030, T1134.001) → "Data Transfer Size Limits" + "Tool"
#   - (T1030, T1213) → "Data Transfer Size Limits" + "Data from Information Repositories"
#   - (T1030, T1213.002) → "Data Transfer Size Limits" + "Sharepoint"
#   - (T1030, T1221) → "Data Transfer Size Limits" + "Timestomp"
#   - (T1030, T1528) → "Data Transfer Size Limits" + "Symmetric Cryptography"
#   - (T1030, T1559.002) → "Data Transfer Size Limits" + "Dynamic Data Exchange"
#   - (T1030, T1564.003) → "Data Transfer Size Limits" + "Hidden Window"
#   - (T1030, T1567) → "Data Transfer Size Limits" + "Exfiltration Over Web Service"
#   - (T1030, T1573.001) → "Data Transfer Size Limits" + "Template Injection"
#   - (T1030, T1583.003) → "Data Transfer Size Limits" + "Vulnerability Scanning"
#   - (T1030, T1583.006) → "Data Transfer Size Limits" + "Web Shell"
#   - (T1030, T1584.008) → "Data Transfer Size Limits" + "Network Devices"
#   - (T1030, T1586.002) → "Data Transfer Size Limits" + "Email Accounts"
#   - (T1030, T1598) → "Data Transfer Size Limits" + "Phishing for Information"
#   - (T1030, T1598.003) → "Data Transfer Size Limits" + "Steal Application Access Token"
#   - (T1036, T1037.001) → "Masquerading" + "Logon Script (Windows)"
#   - (T1036, T1078.004) → "Masquerading" + "Cloud Accounts"
#   - (T1036, T1090.003) → "Masquerading" + "Multi-hop Proxy"
#   - (T1036, T1091) → "Masquerading" + "Replication Through Removable Media"
#   - (T1036, T1098.002) → "Masquerading" + "Additional Email Delegate Permissions"
#   - (T1036, T1110.001) → "Masquerading" + "Password Guessing"
#   - (T1036, T1110.003) → "Masquerading" + "Password Spraying"
#   - (T1036, T1134.001) → "Masquerading" + "Tool"
#   - (T1036, T1213.002) → "Masquerading" + "Sharepoint"
#   - (T1036, T1528) → "Masquerading" + "Symmetric Cryptography"
#   - (T1036, T1542.003) → "Masquerading" + "Bootkit"
#   - (T1036, T1559.002) → "Masquerading" + "Dynamic Data Exchange"
#   - (T1036, T1567) → "Masquerading" + "Exfiltration Over Web Service"
#   - (T1036, T1584.008) → "Masquerading" + "Network Devices"
#   - (T1036, T1586.002) → "Masquerading" + "Email Accounts"
#   - (T1036, T1589.001) → "Masquerading" + "Credentials"
#   - (T1036.005, T1037.001) → "Match Legitimate Name or Location" + "Logon Script (Windows)"
#   - (T1036.005, T1134.001) → "Match Legitimate Name or Location" + "Tool"
#   - (T1036.005, T1583.003) → "Match Legitimate Name or Location" + "Vulnerability Scanning"
#   - (T1036.005, T1598) → "Match Legitimate Name or Location" + "Phishing for Information"
#   - (T1037.001, T1039) → "Logon Script (Windows)" + "Data from Network Shared Drive"
#   - (T1037.001, T1040) → "Logon Script (Windows)" + "Network Sniffing"
#   - (T1037.001, T1056.001) → "Logon Script (Windows)" + "Keylogging"
#   - (T1037.001, T1057) → "Logon Script (Windows)" + "Process Discovery"
#   - (T1037.001, T1070.001) → "Logon Script (Windows)" + "Clear Windows Event Logs"
#   - (T1037.001, T1070.006) → "Logon Script (Windows)" + "Token Impersonation/Theft"
#   - (T1037.001, T1071.003) → "Logon Script (Windows)" + "Mail Protocols"
#   - (T1037.001, T1074.001) → "Logon Script (Windows)" + "Local Data Staging"
#   - (T1037.001, T1074.002) → "Logon Script (Windows)" + "Remote Data Staging"
#   - (T1037.001, T1078) → "Logon Script (Windows)" + "Virtual Private Server"
#   - (T1037.001, T1078.004) → "Logon Script (Windows)" + "Cloud Accounts"
#   - (T1037.001, T1083) → "Logon Script (Windows)" + "File and Directory Discovery"
#   - (T1037.001, T1090.002) → "Logon Script (Windows)" + "External Proxy"
#   - (T1037.001, T1090.003) → "Logon Script (Windows)" + "Multi-hop Proxy"
#   - (T1037.001, T1091) → "Logon Script (Windows)" + "Replication Through Removable Media"
#   - (T1037.001, T1098.002) → "Logon Script (Windows)" + "Additional Email Delegate Permissions"
#   - (T1037.001, T1102.002) → "Logon Script (Windows)" + "Bidirectional Communication"
#   - (T1037.001, T1110) → "Logon Script (Windows)" + "Brute Force"
#   - (T1037.001, T1110.001) → "Logon Script (Windows)" + "Password Guessing"
#   - (T1037.001, T1110.003) → "Logon Script (Windows)" + "Password Spraying"
#   - (T1037.001, T1113) → "Logon Script (Windows)" + "Screen Capture"
#   - (T1037.001, T1114.002) → "Logon Script (Windows)" + "Remote Email Collection"
#   - (T1037.001, T1119) → "Logon Script (Windows)" + "Automated Collection"
#   - (T1037.001, T1120) → "Logon Script (Windows)" + "Peripheral Device Discovery"
#   - (T1037.001, T1133) → "Logon Script (Windows)" + "External Remote Services"
#   - (T1037.001, T1134.001) → "Logon Script (Windows)" + "Tool"
#   - (T1037.001, T1140) → "Logon Script (Windows)" + "Deobfuscate/Decode Files or Information"
#   - (T1037.001, T1189) → "Logon Script (Windows)" + "Drive-by Compromise"
#   - (T1037.001, T1190) → "Logon Script (Windows)" + "Exploit Public-Facing Application"
#   - (T1037.001, T1199) → "Logon Script (Windows)" + "Valid Accounts"
#   - (T1037.001, T1210) → "Logon Script (Windows)" + "Exploitation of Remote Services"
#   - (T1037.001, T1213) → "Logon Script (Windows)" + "Data from Information Repositories"
#   - (T1037.001, T1213.002) → "Logon Script (Windows)" + "Sharepoint"
#   - (T1037.001, T1218.011) → "Logon Script (Windows)" + "Rundll32"
#   - (T1037.001, T1221) → "Logon Script (Windows)" + "Timestomp"
#   - (T1037.001, T1505.003) → "Logon Script (Windows)" + "Windows Command Shell"
#   - (T1037.001, T1528) → "Logon Script (Windows)" + "Symmetric Cryptography"
#   - (T1037.001, T1542.003) → "Logon Script (Windows)" + "Bootkit"
#   - (T1037.001, T1550.002) → "Logon Script (Windows)" + "Pass the Hash"
#   - (T1037.001, T1560) → "Logon Script (Windows)" + "Archive Collected Data"
#   - (T1037.001, T1560.001) → "Logon Script (Windows)" + "Archive via Utility"
#   - (T1037.001, T1564.001) → "Logon Script (Windows)" + "Hidden Files and Directories"
#   - (T1037.001, T1564.003) → "Logon Script (Windows)" + "Hidden Window"
#   - (T1037.001, T1567) → "Logon Script (Windows)" + "Exfiltration Over Web Service"
#   - (T1037.001, T1573.001) → "Logon Script (Windows)" + "Template Injection"
#   - (T1037.001, T1583.001) → "Logon Script (Windows)" + "Domains"
#   - (T1037.001, T1583.003) → "Logon Script (Windows)" + "Vulnerability Scanning"
#   - (T1037.001, T1583.006) → "Logon Script (Windows)" + "Web Shell"
#   - (T1037.001, T1584.008) → "Logon Script (Windows)" + "Network Devices"
#   - (T1037.001, T1586.002) → "Logon Script (Windows)" + "Email Accounts"
#   - (T1037.001, T1589.001) → "Logon Script (Windows)" + "Credentials"
#   - (T1037.001, T1595.002) → "Logon Script (Windows)" + "Web Protocols"
#   - (T1037.001, T1598) → "Logon Script (Windows)" + "Phishing for Information"
#   - (T1037.001, T1598.003) → "Logon Script (Windows)" + "Steal Application Access Token"
#   - (T1039, T1040) → "Data from Network Shared Drive" + "Network Sniffing"
#   - (T1039, T1068) → "Data from Network Shared Drive" + "Exploitation for Privilege Escalation"
#   - (T1039, T1071.003) → "Data from Network Shared Drive" + "Mail Protocols"
#   - (T1039, T1078.004) → "Data from Network Shared Drive" + "Cloud Accounts"
#   - (T1039, T1090.003) → "Data from Network Shared Drive" + "Multi-hop Proxy"
#   - (T1039, T1091) → "Data from Network Shared Drive" + "Replication Through Removable Media"
#   - (T1039, T1098.002) → "Data from Network Shared Drive" + "Additional Email Delegate Permissions"
#   - (T1039, T1102.002) → "Data from Network Shared Drive" + "Bidirectional Communication"
#   - (T1039, T1110.001) → "Data from Network Shared Drive" + "Password Guessing"
#   - (T1039, T1134.001) → "Data from Network Shared Drive" + "Tool"
#   - (T1039, T1204.001) → "Data from Network Shared Drive" + "Malicious Link"
#   - (T1039, T1528) → "Data from Network Shared Drive" + "Symmetric Cryptography"
#   - (T1039, T1542.003) → "Data from Network Shared Drive" + "Bootkit"
#   - (T1039, T1559.002) → "Data from Network Shared Drive" + "Dynamic Data Exchange"
#   - (T1039, T1564.001) → "Data from Network Shared Drive" + "Hidden Files and Directories"
#   - (T1039, T1566.002) → "Data from Network Shared Drive" + "Spearphishing Link"
#   - (T1039, T1567) → "Data from Network Shared Drive" + "Exfiltration Over Web Service"
#   - (T1039, T1583.003) → "Data from Network Shared Drive" + "Vulnerability Scanning"
#   - (T1039, T1583.006) → "Data from Network Shared Drive" + "Web Shell"
#   - (T1039, T1584.008) → "Data from Network Shared Drive" + "Network Devices"
#   - (T1039, T1586.002) → "Data from Network Shared Drive" + "Email Accounts"
#   - (T1039, T1595.002) → "Data from Network Shared Drive" + "Web Protocols"
#   - (T1039, T1598) → "Data from Network Shared Drive" + "Phishing for Information"
#   - (T1039, T1598.003) → "Data from Network Shared Drive" + "Steal Application Access Token"
#   - (T1040, T1070.001) → "Network Sniffing" + "Clear Windows Event Logs"
#   - (T1040, T1074.002) → "Network Sniffing" + "Remote Data Staging"
#   - (T1040, T1090.002) → "Network Sniffing" + "External Proxy"
#   - (T1040, T1090.003) → "Network Sniffing" + "Multi-hop Proxy"
#   - (T1040, T1091) → "Network Sniffing" + "Replication Through Removable Media"
#   - (T1040, T1098.002) → "Network Sniffing" + "Additional Email Delegate Permissions"
#   - (T1040, T1110.001) → "Network Sniffing" + "Password Guessing"
#   - (T1040, T1113) → "Network Sniffing" + "Screen Capture"
#   - (T1040, T1119) → "Network Sniffing" + "Automated Collection"
#   - (T1040, T1120) → "Network Sniffing" + "Peripheral Device Discovery"
#   - (T1040, T1134.001) → "Network Sniffing" + "Tool"
#   - (T1040, T1189) → "Network Sniffing" + "Drive-by Compromise"
#   - (T1040, T1210) → "Network Sniffing" + "Exploitation of Remote Services"
#   - (T1040, T1213.002) → "Network Sniffing" + "Sharepoint"
#   - (T1040, T1221) → "Network Sniffing" + "Timestomp"
#   - (T1040, T1528) → "Network Sniffing" + "Symmetric Cryptography"
#   - (T1040, T1542.003) → "Network Sniffing" + "Bootkit"
#   - (T1040, T1559.002) → "Network Sniffing" + "Dynamic Data Exchange"
#   - (T1040, T1560) → "Network Sniffing" + "Archive Collected Data"
#   - (T1040, T1564.001) → "Network Sniffing" + "Hidden Files and Directories"
#   - (T1040, T1567) → "Network Sniffing" + "Exfiltration Over Web Service"
#   - (T1040, T1583.003) → "Network Sniffing" + "Vulnerability Scanning"
#   - (T1040, T1584.008) → "Network Sniffing" + "Network Devices"
#   - (T1040, T1589.001) → "Network Sniffing" + "Credentials"
#   - (T1040, T1598) → "Network Sniffing" + "Phishing for Information"
#   - (T1056.001, T1110.001) → "Keylogging" + "Password Guessing"
#   - (T1056.001, T1134.001) → "Keylogging" + "Tool"
#   - (T1056.001, T1221) → "Keylogging" + "Timestomp"
#   - (T1056.001, T1528) → "Keylogging" + "Symmetric Cryptography"
#   - (T1056.001, T1559.002) → "Keylogging" + "Dynamic Data Exchange"
#   - (T1056.001, T1583.003) → "Keylogging" + "Vulnerability Scanning"
#   - (T1056.001, T1584.008) → "Keylogging" + "Network Devices"
#   - (T1056.001, T1598) → "Keylogging" + "Phishing for Information"
#   - (T1057, T1110.001) → "Process Discovery" + "Password Guessing"
#   - (T1057, T1134.001) → "Process Discovery" + "Tool"
#   - (T1057, T1199) → "Process Discovery" + "Valid Accounts"
#   - (T1057, T1528) → "Process Discovery" + "Symmetric Cryptography"
#   - (T1057, T1598) → "Process Discovery" + "Phishing for Information"
#   - (T1059.001, T1598) → "PowerShell" + "Phishing for Information"
#   - (T1059.003, T1090.003) → "None" + "Multi-hop Proxy"
#   - (T1059.003, T1110.001) → "None" + "Password Guessing"
#   - (T1059.003, T1528) → "None" + "Symmetric Cryptography"
#   - (T1068, T1091) → "Exploitation for Privilege Escalation" + "Replication Through Removable Media"
#   - (T1068, T1221) → "Exploitation for Privilege Escalation" + "Timestomp"
#   - (T1068, T1542.003) → "Exploitation for Privilege Escalation" + "Bootkit"
#   - (T1068, T1567) → "Exploitation for Privilege Escalation" + "Exfiltration Over Web Service"
#   - (T1068, T1584.008) → "Exploitation for Privilege Escalation" + "Network Devices"
#   - (T1070.001, T1078.004) → "Clear Windows Event Logs" + "Cloud Accounts"
#   - (T1070.001, T1090.003) → "Clear Windows Event Logs" + "Multi-hop Proxy"
#   - (T1070.001, T1091) → "Clear Windows Event Logs" + "Replication Through Removable Media"
#   - (T1070.001, T1098.002) → "Clear Windows Event Logs" + "Additional Email Delegate Permissions"
#   - (T1070.001, T1102.002) → "Clear Windows Event Logs" + "Bidirectional Communication"
#   - (T1070.001, T1110.001) → "Clear Windows Event Logs" + "Password Guessing"
#   - (T1070.001, T1120) → "Clear Windows Event Logs" + "Peripheral Device Discovery"
#   - (T1070.001, T1140) → "Clear Windows Event Logs" + "Deobfuscate/Decode Files or Information"
#   - (T1070.001, T1199) → "Clear Windows Event Logs" + "Valid Accounts"
#   - (T1070.001, T1213) → "Clear Windows Event Logs" + "Data from Information Repositories"
#   - (T1070.001, T1528) → "Clear Windows Event Logs" + "Symmetric Cryptography"
#   - (T1070.001, T1559.002) → "Clear Windows Event Logs" + "Dynamic Data Exchange"
#   - (T1070.001, T1567) → "Clear Windows Event Logs" + "Exfiltration Over Web Service"
#   - (T1070.001, T1573.001) → "Clear Windows Event Logs" + "Template Injection"
#   - (T1070.001, T1584.008) → "Clear Windows Event Logs" + "Network Devices"
#   - (T1070.001, T1586.002) → "Clear Windows Event Logs" + "Email Accounts"
#   - (T1070.001, T1598) → "Clear Windows Event Logs" + "Phishing for Information"
#   - (T1070.004, T1598) → "File Deletion" + "Phishing for Information"
#   - (T1070.006, T1091) → "Token Impersonation/Theft" + "Replication Through Removable Media"
#   - (T1070.006, T1113) → "Token Impersonation/Theft" + "Screen Capture"
#   - (T1070.006, T1120) → "Token Impersonation/Theft" + "Peripheral Device Discovery"
#   - (T1070.006, T1134.001) → "Token Impersonation/Theft" + "Tool"
#   - (T1070.006, T1210) → "Token Impersonation/Theft" + "Exploitation of Remote Services"
#   - (T1070.006, T1213) → "Token Impersonation/Theft" + "Data from Information Repositories"
#   - (T1070.006, T1221) → "Token Impersonation/Theft" + "Timestomp"
#   - (T1070.006, T1559.002) → "Token Impersonation/Theft" + "Dynamic Data Exchange"
#   - (T1070.006, T1567) → "Token Impersonation/Theft" + "Exfiltration Over Web Service"
#   - (T1070.006, T1583.003) → "Token Impersonation/Theft" + "Vulnerability Scanning"
#   - (T1070.006, T1584.008) → "Token Impersonation/Theft" + "Network Devices"
#   - (T1070.006, T1598) → "Token Impersonation/Theft" + "Phishing for Information"
#   - (T1071.001, T1110.001) → "Web Services" + "Password Guessing"
#   - (T1071.001, T1528) → "Web Services" + "Symmetric Cryptography"
#   - (T1071.001, T1584.008) → "Web Services" + "Network Devices"
#   - (T1071.001, T1598) → "Web Services" + "Phishing for Information"
#   - (T1071.003, T1074.002) → "Mail Protocols" + "Remote Data Staging"
#   - (T1071.003, T1078) → "Mail Protocols" + "Virtual Private Server"
#   - (T1071.003, T1078.004) → "Mail Protocols" + "Cloud Accounts"
#   - (T1071.003, T1090.002) → "Mail Protocols" + "External Proxy"
#   - (T1071.003, T1090.003) → "Mail Protocols" + "Multi-hop Proxy"
#   - (T1071.003, T1091) → "Mail Protocols" + "Replication Through Removable Media"
#   - (T1071.003, T1098.002) → "Mail Protocols" + "Additional Email Delegate Permissions"
#   - (T1071.003, T1110.001) → "Mail Protocols" + "Password Guessing"
#   - (T1071.003, T1110.003) → "Mail Protocols" + "Password Spraying"
#   - (T1071.003, T1113) → "Mail Protocols" + "Screen Capture"
#   - (T1071.003, T1119) → "Mail Protocols" + "Automated Collection"
#   - (T1071.003, T1134.001) → "Mail Protocols" + "Tool"
#   - (T1071.003, T1199) → "Mail Protocols" + "Valid Accounts"
#   - (T1071.003, T1210) → "Mail Protocols" + "Exploitation of Remote Services"
#   - (T1071.003, T1213.002) → "Mail Protocols" + "Sharepoint"
#   - (T1071.003, T1221) → "Mail Protocols" + "Timestomp"
#   - (T1071.003, T1528) → "Mail Protocols" + "Symmetric Cryptography"
#   - (T1071.003, T1542.003) → "Mail Protocols" + "Bootkit"
#   - (T1071.003, T1559.002) → "Mail Protocols" + "Dynamic Data Exchange"
#   - (T1071.003, T1567) → "Mail Protocols" + "Exfiltration Over Web Service"
#   - (T1071.003, T1573.001) → "Mail Protocols" + "Template Injection"
#   - (T1071.003, T1583.003) → "Mail Protocols" + "Vulnerability Scanning"
#   - (T1071.003, T1584.008) → "Mail Protocols" + "Network Devices"
#   - (T1071.003, T1589.001) → "Mail Protocols" + "Credentials"
#   - (T1071.003, T1595.002) → "Mail Protocols" + "Web Protocols"
#   - (T1071.003, T1598) → "Mail Protocols" + "Phishing for Information"
#   - (T1074.001, T1098.002) → "Local Data Staging" + "Additional Email Delegate Permissions"
#   - (T1074.001, T1110.001) → "Local Data Staging" + "Password Guessing"
#   - (T1074.001, T1134.001) → "Local Data Staging" + "Tool"
#   - (T1074.001, T1213) → "Local Data Staging" + "Data from Information Repositories"
#   - (T1074.001, T1528) → "Local Data Staging" + "Symmetric Cryptography"
#   - (T1074.001, T1567) → "Local Data Staging" + "Exfiltration Over Web Service"
#   - (T1074.001, T1598) → "Local Data Staging" + "Phishing for Information"
#   - (T1074.002, T1078.004) → "Remote Data Staging" + "Cloud Accounts"
#   - (T1074.002, T1091) → "Remote Data Staging" + "Replication Through Removable Media"
#   - (T1074.002, T1098.002) → "Remote Data Staging" + "Additional Email Delegate Permissions"
#   - (T1074.002, T1102.002) → "Remote Data Staging" + "Bidirectional Communication"
#   - (T1074.002, T1110) → "Remote Data Staging" + "Brute Force"
#   - (T1074.002, T1110.001) → "Remote Data Staging" + "Password Guessing"
#   - (T1074.002, T1120) → "Remote Data Staging" + "Peripheral Device Discovery"
#   - (T1074.002, T1218.011) → "Remote Data Staging" + "Rundll32"
#   - (T1074.002, T1221) → "Remote Data Staging" + "Timestomp"
#   - (T1074.002, T1528) → "Remote Data Staging" + "Symmetric Cryptography"
#   - (T1074.002, T1542.003) → "Remote Data Staging" + "Bootkit"
#   - (T1074.002, T1564.001) → "Remote Data Staging" + "Hidden Files and Directories"
#   - (T1074.002, T1567) → "Remote Data Staging" + "Exfiltration Over Web Service"
#   - (T1074.002, T1573.001) → "Remote Data Staging" + "Template Injection"
#   - (T1074.002, T1583.003) → "Remote Data Staging" + "Vulnerability Scanning"
#   - (T1074.002, T1583.006) → "Remote Data Staging" + "Web Shell"
#   - (T1074.002, T1584.008) → "Remote Data Staging" + "Network Devices"
#   - (T1074.002, T1595.002) → "Remote Data Staging" + "Web Protocols"
#   - (T1074.002, T1598) → "Remote Data Staging" + "Phishing for Information"
#   - (T1074.002, T1598.003) → "Remote Data Staging" + "Steal Application Access Token"
#   - (T1078, T1564.003) → "Virtual Private Server" + "Hidden Window"
#   - (T1078, T1567) → "Virtual Private Server" + "Exfiltration Over Web Service"
#   - (T1078, T1584.008) → "Virtual Private Server" + "Network Devices"
#   - (T1078, T1598) → "Virtual Private Server" + "Phishing for Information"
#   - (T1078.004, T1091) → "Cloud Accounts" + "Replication Through Removable Media"
#   - (T1078.004, T1102.002) → "Cloud Accounts" + "Bidirectional Communication"
#   - (T1078.004, T1110) → "Cloud Accounts" + "Brute Force"
#   - (T1078.004, T1113) → "Cloud Accounts" + "Screen Capture"
#   - (T1078.004, T1120) → "Cloud Accounts" + "Peripheral Device Discovery"
#   - (T1078.004, T1134.001) → "Cloud Accounts" + "Tool"
#   - (T1078.004, T1189) → "Cloud Accounts" + "Drive-by Compromise"
#   - (T1078.004, T1210) → "Cloud Accounts" + "Exploitation of Remote Services"
#   - (T1078.004, T1218.011) → "Cloud Accounts" + "Rundll32"
#   - (T1078.004, T1221) → "Cloud Accounts" + "Timestomp"
#   - (T1078.004, T1542.003) → "Cloud Accounts" + "Bootkit"
#   - (T1078.004, T1550.002) → "Cloud Accounts" + "Pass the Hash"
#   - (T1078.004, T1559.002) → "Cloud Accounts" + "Dynamic Data Exchange"
#   - (T1078.004, T1564.001) → "Cloud Accounts" + "Hidden Files and Directories"
#   - (T1078.004, T1564.003) → "Cloud Accounts" + "Hidden Window"
#   - (T1078.004, T1567) → "Cloud Accounts" + "Exfiltration Over Web Service"
#   - (T1078.004, T1583.001) → "Cloud Accounts" + "Domains"
#   - (T1078.004, T1584.008) → "Cloud Accounts" + "Network Devices"
#   - (T1078.004, T1598) → "Cloud Accounts" + "Phishing for Information"
#   - (T1078.004, T1598.003) → "Cloud Accounts" + "Steal Application Access Token"
#   - (T1083, T1110.001) → "File and Directory Discovery" + "Password Guessing"
#   - (T1083, T1134.001) → "File and Directory Discovery" + "Tool"
#   - (T1083, T1528) → "File and Directory Discovery" + "Symmetric Cryptography"
#   - (T1083, T1584.008) → "File and Directory Discovery" + "Network Devices"
#   - (T1090.002, T1091) → "External Proxy" + "Replication Through Removable Media"
#   - (T1090.002, T1120) → "External Proxy" + "Peripheral Device Discovery"
#   - (T1090.002, T1134.001) → "External Proxy" + "Tool"
#   - (T1090.002, T1213) → "External Proxy" + "Data from Information Repositories"
#   - (T1090.002, T1213.002) → "External Proxy" + "Sharepoint"
#   - (T1090.002, T1221) → "External Proxy" + "Timestomp"
#   - (T1090.002, T1567) → "External Proxy" + "Exfiltration Over Web Service"
#   - (T1090.002, T1583.003) → "External Proxy" + "Vulnerability Scanning"
#   - (T1090.002, T1584.008) → "External Proxy" + "Network Devices"
#   - (T1090.002, T1589.001) → "External Proxy" + "Credentials"
#   - (T1090.002, T1598) → "External Proxy" + "Phishing for Information"
#   - (T1090.002, T1598.003) → "External Proxy" + "Steal Application Access Token"
#   - (T1090.003, T1091) → "Multi-hop Proxy" + "Replication Through Removable Media"
#   - (T1090.003, T1102.002) → "Multi-hop Proxy" + "Bidirectional Communication"
#   - (T1090.003, T1110) → "Multi-hop Proxy" + "Brute Force"
#   - (T1090.003, T1113) → "Multi-hop Proxy" + "Screen Capture"
#   - (T1090.003, T1119) → "Multi-hop Proxy" + "Automated Collection"
#   - (T1090.003, T1120) → "Multi-hop Proxy" + "Peripheral Device Discovery"
#   - (T1090.003, T1134.001) → "Multi-hop Proxy" + "Tool"
#   - (T1090.003, T1210) → "Multi-hop Proxy" + "Exploitation of Remote Services"
#   - (T1090.003, T1213) → "Multi-hop Proxy" + "Data from Information Repositories"
#   - (T1090.003, T1213.002) → "Multi-hop Proxy" + "Sharepoint"
#   - (T1090.003, T1218.011) → "Multi-hop Proxy" + "Rundll32"
#   - (T1090.003, T1542.003) → "Multi-hop Proxy" + "Bootkit"
#   - (T1090.003, T1550.002) → "Multi-hop Proxy" + "Pass the Hash"
#   - (T1090.003, T1560.001) → "Multi-hop Proxy" + "Archive via Utility"
#   - (T1090.003, T1564.001) → "Multi-hop Proxy" + "Hidden Files and Directories"
#   - (T1090.003, T1564.003) → "Multi-hop Proxy" + "Hidden Window"
#   - (T1090.003, T1567) → "Multi-hop Proxy" + "Exfiltration Over Web Service"
#   - (T1090.003, T1583.003) → "Multi-hop Proxy" + "Vulnerability Scanning"
#   - (T1090.003, T1584.008) → "Multi-hop Proxy" + "Network Devices"
#   - (T1090.003, T1598) → "Multi-hop Proxy" + "Phishing for Information"
#   - (T1090.003, T1598.003) → "Multi-hop Proxy" + "Steal Application Access Token"
#   - (T1091, T1098.002) → "Replication Through Removable Media" + "Additional Email Delegate Permissions"
#   - (T1091, T1110) → "Replication Through Removable Media" + "Brute Force"
#   - (T1091, T1110.001) → "Replication Through Removable Media" + "Password Guessing"
#   - (T1091, T1110.003) → "Replication Through Removable Media" + "Password Spraying"
#   - (T1091, T1114.002) → "Replication Through Removable Media" + "Remote Email Collection"
#   - (T1091, T1120) → "Replication Through Removable Media" + "Peripheral Device Discovery"
#   - (T1091, T1133) → "Replication Through Removable Media" + "External Remote Services"
#   - (T1091, T1134.001) → "Replication Through Removable Media" + "Tool"
#   - (T1091, T1199) → "Replication Through Removable Media" + "Valid Accounts"
#   - (T1091, T1213) → "Replication Through Removable Media" + "Data from Information Repositories"
#   - (T1091, T1213.002) → "Replication Through Removable Media" + "Sharepoint"
# ...
#   - (T1003.003, T1497.001) → "NTDS" + "System Checks"
#   - (T1003.003, T1654) → "NTDS" + "Log Enumeration"
#   - (T1005, T1497.001) → "Data from Local System" + "System Checks"
#   - (T1005, T1654) → "Data from Local System" + "Log Enumeration"
#   - (T1012, T1074) → "Query Registry" + "Data Staged"
#   - (T1012, T1518) → "Query Registry" + "Software Discovery"
#   - (T1012, T1584.008) → "Query Registry" + "Network Devices"
#   - (T1012, T1654) → "Query Registry" + "Log Enumeration"
#   - (T1016, T1584.008) → "System Network Configuration Discovery" + "Network Devices"
#   - (T1016, T1654) → "System Network Configuration Discovery" + "Log Enumeration"
#   - (T1018, T1497.001) → "Remote System Discovery" + "System Checks"
#   - (T1018, T1584.008) → "Remote System Discovery" + "Network Devices"
#   - (T1018, T1654) → "Remote System Discovery" + "Log Enumeration"
#   - (T1033, T1584.008) → "System Owner/User Discovery" + "Network Devices"
#   - (T1033, T1654) → "System Owner/User Discovery" + "Log Enumeration"
#   - (T1036.005, T1074) → "Match Legitimate Name or Location" + "Data Staged"
#   - (T1047, T1584.008) → "Windows Management Instrumentation" + "Network Devices"
#   - (T1047, T1654) → "Windows Management Instrumentation" + "Log Enumeration"
#   - (T1049, T1074) → "System Network Connections Discovery" + "Data Staged"
#   - (T1049, T1584.008) → "System Network Connections Discovery" + "Network Devices"
#   - (T1057, T1074) → "Process Discovery" + "Data Staged"
#   - (T1069.001, T1074) → "Local Groups" + "Data Staged"
#   - (T1069.001, T1190) → "Local Groups" + "Exploit Public-Facing Application"
#   - (T1069.001, T1573.001) → "Local Groups" + "Symmetric Cryptography"
#   - (T1069.001, T1584.008) → "Local Groups" + "Network Devices"
#   - (T1069.001, T1654) → "Local Groups" + "Log Enumeration"
#   - (T1069.002, T1074) → "Domain Groups" + "Data Staged"
#   - (T1069.002, T1584.008) → "Domain Groups" + "Network Devices"
#   - (T1069.002, T1654) → "Domain Groups" + "Log Enumeration"
#   - (T1074, T1090) → "Data Staged" + "Proxy"
#   - (T1074, T1090.001) → "Data Staged" + "Internal Proxy"
#   - (T1074, T1190) → "Data Staged" + "Exploit Public-Facing Application"
#   - (T1074, T1497.001) → "Data Staged" + "System Checks"
#   - (T1074, T1505.003) → "Data Staged" + "Web Shell"
#   - (T1074, T1555) → "Data Staged" + "Credentials from Password Stores"
#   - (T1074, T1573.001) → "Data Staged" + "Symmetric Cryptography"
#   - (T1074, T1584.004) → "Data Staged" + "Server"
#   - (T1074, T1584.008) → "Data Staged" + "Network Devices"
#   - (T1074, T1654) → "Data Staged" + "Log Enumeration"
#   - (T1074.001, T1090) → "Local Data Staging" + "Proxy"
#   - (T1074.001, T1497.001) → "Local Data Staging" + "System Checks"
#   - (T1078.002, T1090.001) → "Domain Accounts" + "Internal Proxy"
#   - (T1078.002, T1497.001) → "Domain Accounts" + "System Checks"
#   - (T1078.002, T1555) → "Domain Accounts" + "Credentials from Password Stores"
#   - (T1078.002, T1573.001) → "Domain Accounts" + "Symmetric Cryptography"
#   - (T1078.002, T1584.008) → "Domain Accounts" + "Network Devices"
#   - (T1082, T1584.008) → "System Information Discovery" + "Network Devices"
#   - (T1082, T1654) → "System Information Discovery" + "Log Enumeration"
#   - (T1087.002, T1584.008) → "Domain Account" + "Network Devices"
#   - (T1087.002, T1654) → "Domain Account" + "Log Enumeration"
#   - (T1090, T1497.001) → "Proxy" + "System Checks"
#   - (T1090, T1555) → "Proxy" + "Credentials from Password Stores"
#   - (T1090, T1573.001) → "Proxy" + "Symmetric Cryptography"
#   - (T1090, T1584.008) → "Proxy" + "Network Devices"
#   - (T1090, T1654) → "Proxy" + "Log Enumeration"
#   - (T1090.001, T1497.001) → "Internal Proxy" + "System Checks"
#   - (T1090.001, T1518) → "Internal Proxy" + "Software Discovery"
#   - (T1090.001, T1584.008) → "Internal Proxy" + "Network Devices"
#   - (T1090.001, T1654) → "Internal Proxy" + "Log Enumeration"
#   - (T1190, T1497.001) → "Exploit Public-Facing Application" + "System Checks"
#   - (T1497.001, T1518) → "System Checks" + "Software Discovery"
#   - (T1497.001, T1560.001) → "System Checks" + "Archive via Utility"
#   - (T1497.001, T1570) → "System Checks" + "Lateral Tool Transfer"
#   - (T1497.001, T1584.004) → "System Checks" + "Server"
#   - (T1497.001, T1584.008) → "System Checks" + "Network Devices"
#   - (T1497.001, T1588.002) → "System Checks" + "Tool"
#   - (T1497.001, T1654) → "System Checks" + "Log Enumeration"
#   - (T1518, T1584.004) → "Software Discovery" + "Server"
#   - (T1518, T1584.008) → "Software Discovery" + "Network Devices"
#   - (T1518, T1654) → "Software Discovery" + "Log Enumeration"
#   - (T1555, T1570) → "Credentials from Password Stores" + "Lateral Tool Transfer"
#   - (T1555, T1584.004) → "Credentials from Password Stores" + "Server"
#   - (T1555, T1584.008) → "Credentials from Password Stores" + "Network Devices"
#   - (T1555, T1654) → "Credentials from Password Stores" + "Log Enumeration"
#   - (T1570, T1573.001) → "Lateral Tool Transfer" + "Symmetric Cryptography"
#   - (T1570, T1584.008) → "Lateral Tool Transfer" + "Network Devices"
#   - (T1570, T1654) → "Lateral Tool Transfer" + "Log Enumeration"
#   - (T1573.001, T1654) → "Symmetric Cryptography" + "Log Enumeration"
#   - (T1584.004, T1584.008) → "Server" + "Network Devices"
#   - (T1584.004, T1654) → "Server" + "Log Enumeration"
#   - (T1584.008, T1654) → "Network Devices" + "Log Enumeration"
#   - (T1588.002, T1654) → "Tool" + "Log Enumeration"
#
# Group: G1018 (TA2541)
#   - (T1016.001, T1055.012) → "Internet Connection Discovery" + "Process Hollowing"
#   - (T1027.002, T1573.002) → "Software Packing" + "Asymmetric Cryptography"
#   - (T1055, T1568) → "Process Injection" + "Dynamic Resolution"
#   - (T1055.012, T1568) → "Process Hollowing" + "Dynamic Resolution"
#   - (T1055.012, T1573.002) → "Process Hollowing" + "Asymmetric Cryptography"
#   - (T1055.012, T1588.001) → "Process Hollowing" + "Malware"
#   - (T1218.005, T1573.002) → "Mshta" + "Asymmetric Cryptography"
#   - (T1518.001, T1568) → "Security Software Discovery" + "Dynamic Resolution"
#   - (T1568, T1573.002) → "Dynamic Resolution" + "Asymmetric Cryptography"
#   - (T1568, T1588.001) → "Dynamic Resolution" + "Malware"
#   - (T1573.002, T1583.001) → "Asymmetric Cryptography" + "Domains"
#   - (T1573.002, T1583.006) → "Asymmetric Cryptography" + "Web Services"
#   - (T1573.002, T1588.001) → "Asymmetric Cryptography" + "Malware"
#   - (T1573.002, T1608.001) → "Asymmetric Cryptography" + "Upload Malware"
#
# Group: G1019 (MoustachedBouncer)
#   - (T1027.002, T1655.001) → "Software Packing" + "Match Legitimate Name or Location"
#   - (T1059.001, T1655.001) → "PowerShell" + "Match Legitimate Name or Location"
#   - (T1059.007, T1655.001) → "JavaScript" + "Match Legitimate Name or Location"
#   - (T1068, T1655.001) → "Exploitation for Privilege Escalation" + "Match Legitimate Name or Location"
#   - (T1074.002, T1090) → "Remote Data Staging" + "Proxy"
#   - (T1074.002, T1655.001) → "Remote Data Staging" + "Match Legitimate Name or Location"
#   - (T1090, T1655.001) → "Proxy" + "Match Legitimate Name or Location"
#   - (T1113, T1655.001) → "Screen Capture" + "Match Legitimate Name or Location"
#
# Group: G1020 (Mustard Tempest)
#   - (T1583.004, T1608.004) → "Server" + "Drive-by Target"
#
# Group: G1021 (Cinnamon Tempest)
#   - (T1021.002, T1080) → "SMB/Windows Admin Shares" + "Taint Shared Content"
#   - (T1021.002, T1484.001) → "SMB/Windows Admin Shares" + "Group Policy Modification"
#   - (T1059.006, T1078.002) → "Python" + "Domain Accounts"
#   - (T1059.006, T1484.001) → "Python" + "Group Policy Modification"
#   - (T1059.006, T1572) → "Python" + "Protocol Tunneling"
#   - (T1059.006, T1657) → "Python" + "Financial Theft"
#   - (T1078, T1080) → "Valid Accounts" + "Taint Shared Content"
#   - (T1078, T1484.001) → "Valid Accounts" + "Group Policy Modification"
#   - (T1078.002, T1080) → "Domain Accounts" + "Taint Shared Content"
#   - (T1078.002, T1574.001) → "Domain Accounts" + "DLL Search Order Hijacking"
#   - (T1078.002, T1657) → "Domain Accounts" + "Financial Theft"
#   - (T1080, T1090) → "Taint Shared Content" + "Proxy"
#   - (T1080, T1190) → "Taint Shared Content" + "Exploit Public-Facing Application"
#   - (T1080, T1484.001) → "Taint Shared Content" + "Group Policy Modification"
#   - (T1080, T1543.003) → "Taint Shared Content" + "Windows Service"
#   - (T1080, T1567.002) → "Taint Shared Content" + "Exfiltration to Cloud Storage"
#   - (T1080, T1572) → "Taint Shared Content" + "Protocol Tunneling"
#   - (T1080, T1574.001) → "Taint Shared Content" + "DLL Search Order Hijacking"
#   - (T1080, T1657) → "Taint Shared Content" + "Financial Theft"
#   - (T1090, T1484.001) → "Proxy" + "Group Policy Modification"
#   - (T1090, T1657) → "Proxy" + "Financial Theft"
#   - (T1140, T1484.001) → "Deobfuscate/Decode Files or Information" + "Group Policy Modification"
#   - (T1190, T1484.001) → "Exploit Public-Facing Application" + "Group Policy Modification"
#   - (T1484.001, T1543.003) → "Group Policy Modification" + "Windows Service"
#   - (T1484.001, T1567.002) → "Group Policy Modification" + "Exfiltration to Cloud Storage"
#   - (T1484.001, T1572) → "Group Policy Modification" + "Protocol Tunneling"
#   - (T1484.001, T1574.001) → "Group Policy Modification" + "DLL Search Order Hijacking"
#   - (T1484.001, T1574.002) → "Group Policy Modification" + "DLL Side-Loading"
#   - (T1484.001, T1588.002) → "Group Policy Modification" + "Tool"
#   - (T1484.001, T1657) → "Group Policy Modification" + "Financial Theft"
#   - (T1543.003, T1657) → "Windows Service" + "Financial Theft"
#   - (T1572, T1574.001) → "Protocol Tunneling" + "DLL Search Order Hijacking"
#   - (T1574.001, T1657) → "DLL Search Order Hijacking" + "Financial Theft"
#
# Group: G1022 (ToddyCat)
#   - (T1069.002, T1074.002) → "Domain Groups" + "Remote Data Staging"
#   - (T1069.002, T1095) → "Domain Groups" + "Non-Application Layer Protocol"
#   - (T1069.002, T1564.003) → "Domain Groups" + "Hidden Window"
#   - (T1074.002, T1562.004) → "Remote Data Staging" + "Disable or Modify System Firewall"
#   - (T1087.002, T1564.003) → "Domain Account" + "Hidden Window"
#   - (T1095, T1106) → "Non-Application Layer Protocol" + "Native API"
#   - (T1095, T1518.001) → "Non-Application Layer Protocol" + "Security Software Discovery"
#   - (T1095, T1562.004) → "Non-Application Layer Protocol" + "Disable or Modify System Firewall"
#   - (T1566.003, T1567.002) → "Spearphishing via Service" + "Exfiltration to Cloud Storage"
#
# Group: G1023 (APT5)
#   - (T1003.001, T1053.003) → "LSASS Memory" + "Cron"
#   - (T1003.001, T1070) → "LSASS Memory" + "Indicator Removal"
#   - (T1003.002, T1053.003) → "Security Account Manager" + "Cron"
#   - (T1003.002, T1070) → "Security Account Manager" + "Indicator Removal"
#   - (T1003.002, T1654) → "Security Account Manager" + "Log Enumeration"
#   - (T1021.001, T1053.003) → "Remote Desktop Protocol" + "Cron"
#   - (T1021.001, T1078.004) → "Remote Desktop Protocol" + "Cloud Accounts"
#   - (T1021.001, T1654) → "Remote Desktop Protocol" + "Log Enumeration"
#   - (T1021.004, T1055) → "SSH" + "Process Injection"
#   - (T1021.004, T1078.002) → "SSH" + "Domain Accounts"
#   - (T1021.004, T1078.004) → "SSH" + "Cloud Accounts"
#   - (T1021.004, T1562.006) → "SSH" + "Indicator Blocking"
#   - (T1021.004, T1654) → "SSH" + "Log Enumeration"
#   - (T1053.003, T1055) → "Cron" + "Process Injection"
#   - (T1053.003, T1070) → "Cron" + "Indicator Removal"
#   - (T1053.003, T1070.003) → "Cron" + "Clear Command History"
#   - (T1053.003, T1074.001) → "Cron" + "Local Data Staging"
#   - (T1053.003, T1078.002) → "Cron" + "Domain Accounts"
#   - (T1053.003, T1078.004) → "Cron" + "Cloud Accounts"
#   - (T1053.003, T1098) → "Cron" + "Account Manipulation"
#   - (T1053.003, T1136.001) → "Cron" + "Local Account"
#   - (T1053.003, T1560.001) → "Cron" + "Archive via Utility"
#   - (T1053.003, T1562.006) → "Cron" + "Indicator Blocking"
#   - (T1053.003, T1654) → "Cron" + "Log Enumeration"
#   - (T1055, T1070) → "Process Injection" + "Indicator Removal"
#   - (T1055, T1078.004) → "Process Injection" + "Cloud Accounts"
#   - (T1055, T1654) → "Process Injection" + "Log Enumeration"
#   - (T1056.001, T1654) → "Keylogging" + "Log Enumeration"
#   - (T1057, T1562.006) → "Process Discovery" + "Indicator Blocking"
#   - (T1070, T1078.002) → "Indicator Removal" + "Domain Accounts"
#   - (T1070, T1078.004) → "Indicator Removal" + "Cloud Accounts"
#   - (T1070, T1136.001) → "Indicator Removal" + "Local Account"
#   - (T1070, T1190) → "Indicator Removal" + "Exploit Public-Facing Application"
#   - (T1070, T1505.003) → "Indicator Removal" + "Web Shell"
#   - (T1070, T1560.001) → "Indicator Removal" + "Archive via Utility"
#   - (T1070, T1562.006) → "Indicator Removal" + "Indicator Blocking"
#   - (T1070, T1654) → "Indicator Removal" + "Log Enumeration"
#   - (T1070.003, T1078.004) → "Clear Command History" + "Cloud Accounts"
#   - (T1070.003, T1654) → "Clear Command History" + "Log Enumeration"
#   - (T1070.006, T1562.006) → "Timestomp" + "Indicator Blocking"
#   - (T1070.006, T1654) → "Timestomp" + "Log Enumeration"
#   - (T1074.001, T1562.006) → "Local Data Staging" + "Indicator Blocking"
#   - (T1078.002, T1078.004) → "Domain Accounts" + "Cloud Accounts"
#   - (T1078.002, T1562.006) → "Domain Accounts" + "Indicator Blocking"
#   - (T1078.004, T1098) → "Cloud Accounts" + "Account Manipulation"
#   - (T1078.004, T1136.001) → "Cloud Accounts" + "Local Account"
#   - (T1078.004, T1562.006) → "Cloud Accounts" + "Indicator Blocking"
#   - (T1078.004, T1654) → "Cloud Accounts" + "Log Enumeration"
#   - (T1083, T1654) → "File and Directory Discovery" + "Log Enumeration"
#   - (T1098, T1654) → "Account Manipulation" + "Log Enumeration"
#   - (T1136.001, T1654) → "Local Account" + "Log Enumeration"
#   - (T1505.003, T1562.006) → "Web Shell" + "Indicator Blocking"
#   - (T1562.006, T1654) → "Indicator Blocking" + "Log Enumeration"
#
# Group: G1024 (Akira)
#   - (T1018, T1531) → "Remote System Discovery" + "Account Access Removal"
#   - (T1213.002, T1219) → "Sharepoint" + "Remote Access Software"
#   - (T1213.002, T1486) → "Sharepoint" + "Data Encrypted for Impact"
#   - (T1213.002, T1657) → "Sharepoint" + "Financial Theft"
#   - (T1219, T1482) → "Remote Access Software" + "Domain Trust Discovery"
#   - (T1219, T1531) → "Remote Access Software" + "Account Access Removal"
#   - (T1482, T1531) → "Domain Trust Discovery" + "Account Access Removal"
#   - (T1482, T1657) → "Domain Trust Discovery" + "Financial Theft"
#   - (T1486, T1531) → "Data Encrypted for Impact" + "Account Access Removal"
#   - (T1531, T1560.001) → "Account Access Removal" + "Archive via Utility"
#   - (T1531, T1567.002) → "Account Access Removal" + "Exfiltration to Cloud Storage"
#   - (T1531, T1657) → "Account Access Removal" + "Financial Theft"
#
# Group: G1026 (Malteiro)
#   - (T1027.013, T1614.001) → "Encrypted/Encoded File" + "System Language Discovery"
#   - (T1027.013, T1657) → "Encrypted/Encoded File" + "Financial Theft"
#   - (T1055.001, T1555) → "Dynamic-link Library Injection" + "Credentials from Password Stores"
#   - (T1055.001, T1614.001) → "Dynamic-link Library Injection" + "System Language Discovery"
#   - (T1055.001, T1657) → "Dynamic-link Library Injection" + "Financial Theft"
#   - (T1059.005, T1614.001) → "Visual Basic" + "System Language Discovery"
#   - (T1204.002, T1614.001) → "Malicious File" + "System Language Discovery"
#   - (T1204.002, T1657) → "Malicious File" + "Financial Theft"
#   - (T1518.001, T1614.001) → "Security Software Discovery" + "System Language Discovery"
#   - (T1518.001, T1657) → "Security Software Discovery" + "Financial Theft"
#   - (T1555, T1614.001) → "Credentials from Password Stores" + "System Language Discovery"
#   - (T1555, T1657) → "Credentials from Password Stores" + "Financial Theft"
#   - (T1555.003, T1614.001) → "Credentials from Web Browsers" + "System Language Discovery"
#   - (T1555.003, T1657) → "Credentials from Web Browsers" + "Financial Theft"
#   - (T1566.001, T1614.001) → "Spearphishing Attachment" + "System Language Discovery"
#   - (T1566.001, T1657) → "Spearphishing Attachment" + "Financial Theft"
#   - (T1614.001, T1657) → "System Language Discovery" + "Financial Theft"
#
# Group: G1028 (APT-C-23)
#   - (T1655.001, T1660) → "Match Legitimate Name or Location" + "Phishing"

# %%
def find_unique_technique_triplets_with_names(json_path):
    """
    Analyze groups to find unique technique triplets (excluding globally unique techniques and pairs),
    and print both technique IDs and names.

    Parameters
    ----------
    json_path : str
        Path to JSON file containing techniques_map.

    Returns
    -------
    dict
        Summary of analysis, including groups with unique triplets and newly discovered unique triplet groups.
    """
    with open(json_path, 'r') as f:
        data = json.load(f)

    # Step 1: Build technique-to-groups mapping
    technique_to_groups = defaultdict(set)
    for group_id, info in data.items():
        for tech in info.get("items", []):
            technique_to_groups[tech].add(group_id)

    # Step 2: Identify globally unique techniques
    globally_unique_techniques = {tech for tech, groups in technique_to_groups.items() if len(groups) == 1}

    # Step 3: Identify globally unique technique pairs
    pair_to_groups = defaultdict(set)
    group_to_pairs = dict()

    for group_id, info in data.items():
        techs = [t for t in info.get("items", []) if t not in globally_unique_techniques]
        pairs = list(combinations(sorted(techs), 2))
        group_to_pairs[group_id] = pairs
        for pair in pairs:
            pair_to_groups[pair].add(group_id)

    unique_pairs = {pair for pair, groups in pair_to_groups.items() if len(groups) == 1}
    unique_pair_techniques = set(t for pair in unique_pairs for t in pair)

    # Step 4: Build triplet-to-groups and group-to-triplets mappings
    triplet_to_groups = defaultdict(set)
    group_to_triplets = dict()

    for group_id, info in data.items():
        techs = info.get("items", [])
        tech_names = info.get("technique name", [])
        tech_map = dict(zip(techs, tech_names))
        filtered_techs = [
            t for t in techs
            if t not in globally_unique_techniques and t not in unique_pair_techniques
        ]
        triplets = list(combinations(sorted(filtered_techs), 3))
        group_to_triplets[group_id] = {
            "triplets": triplets,
            "tech_map": tech_map,
            "name": info.get("name", "")
        }
        for triplet in triplets:
            triplet_to_groups[triplet].add(group_id)

    # Step 5: Identify unique triplets (appear in only one group)
    unique_triplets = {triplet for triplet, groups in triplet_to_groups.items() if len(groups) == 1}

    # Step 6: Find which groups contain at least one unique triplet
    groups_with_unique_triplets = defaultdict(list)
    for group_id, triplet_info in group_to_triplets.items():
        for triplet in triplet_info["triplets"]:
            if triplet in unique_triplets:
                groups_with_unique_triplets[group_id].append(triplet)

    # Compare to groups that already had globally unique techniques or unique pairs
    groups_with_unique_techs = {group_id for group_id, info in data.items()
                                 if any(t in globally_unique_techniques for t in info.get("items", []))}
    groups_with_unique_pairs = {group_id for group_id, pairs in group_to_pairs.items()
                                 if any(p in unique_pairs for p in pairs)}
    previously_identified_groups = groups_with_unique_techs.union(groups_with_unique_pairs)

    new_unique_triplet_groups = set(groups_with_unique_triplets) - previously_identified_groups

    # Step 7: Print summary
    print(f"Total groups with globally unique techniques: {len(groups_with_unique_techs)}")
    print(f"Total groups with unique technique pairs: {len(groups_with_unique_pairs)}")
    print(f"Total groups with unique technique triplets (excluding above): {len(groups_with_unique_triplets)}")
    print(f"New groups with only unique triplets: {len(new_unique_triplet_groups)}\n")

    for group_id in sorted(groups_with_unique_triplets):
        info = group_to_triplets[group_id]
        tech_map = info["tech_map"]
        print(f"Group: {group_id} ({info['name']})")
        for t1, t2, t3 in groups_with_unique_triplets[group_id]:
            print(f"  - ({t1}, {t2}, {t3}) → \"{tech_map.get(t1)}\" + \"{tech_map.get(t2)}\" + \"{tech_map.get(t3)}\"")
        print()

    return {
        "groups_with_unique_triplets": groups_with_unique_triplets,
        "new_unique_triplet_groups": new_unique_triplet_groups,
        "all_unique_triplets": unique_triplets
    }

# %%
find_unique_technique_triplets_with_names(json_path)
# Out:
# 🔹 Total groups with globally unique techniques: 52
# 🔹 Total groups with unique technique pairs: 112
# 🔍 Total groups with unique technique triplets (excluding above): 0
# 🆕 New groups with only unique triplets: 0
# {'groups_with_unique_triplets': defaultdict(list, {}),
#  'new_unique_triplet_groups': set(),
#  'all_unique_triplets': set()}
