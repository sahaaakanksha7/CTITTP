# %%
import pandas as pd
import json

# Function to load groups from an Excel file and create a dictionary
def load_groups_from_excel(file_path, sheet_name):
    # Read the Excel file
    df = pd.read_excel(file_path, sheet_name=sheet_name)
    # Extract the relevant columns: 'ID', 'Name', 'Associated Groups'
    df_subset = df[['ID', 'name', 'associated groups']]
    # Create a dictionary for groups
    group_dict = {}
    for _, row in df_subset.iterrows():
        group_id = row['ID']
        group_name = row['name']
        associated_groups = row['associated groups']
        # Add the group information to the dictionary
        group_dict[group_id] = {
            'name': group_name,
            'associated_groups': associated_groups
        }
    return group_dict

# Step 1: Load the enterprise groups mapping from the local Excel file
enterprise_file_path = r"C:\Users\ricewater\Documents\CTITTP\ATTACK Excel sheets\enterprise-attack-v15.1-groups.xlsx"  
enterprise_groups = load_groups_from_excel(enterprise_file_path, sheet_name="groups")

# Step 2: Load the ICS groups mapping from the local Excel file
ics_file_path = r"C:\Users\ricewater\Documents\CTITTP\ATTACK Excel sheets\ics-attack-v15.1-groups.xlsx" 
ics_groups = load_groups_from_excel(ics_file_path, sheet_name="groups")

# Step 3: Load the Mobile groups mapping from the local Excel file
mobile_file_path = r"C:\Users\ricewater\Documents\CTITTP\ATTACK Excel sheets\mobile-attack-v15.1-groups.xlsx"
mobile_groups = load_groups_from_excel(mobile_file_path, sheet_name="groups")

# Step 4: Identify and add unique ICS and Mobile group IDs not in Enterprise
for group_id, group_info in ics_groups.items():
    if group_id not in enterprise_groups:
        # Add the unique ICS group to the enterprise groups mapping
        enterprise_groups[group_id] = group_info

for group_id, group_info in mobile_groups.items():
    if group_id not in enterprise_groups:
        # Add the unique Mobile group to the enterprise groups mapping
        enterprise_groups[group_id] = group_info

# Step 5: Optionally, export the updated group mapping to a new JSON file
with open('group_mapping_MITRE.json', 'w') as f:
    json.dump(enterprise_groups, f, indent=4)

# print("Updated group mapping exported to 'updated_group_mapping.json'.")

# Step 6: Display the counts and first few entries
print(f"\nTotal groups in updated mapping: {len(enterprise_groups)}")
print("\nSome example group mappings:")
for group_id, group_info in list(enterprise_groups.items())[:5]:  # Display first 5 for example
    print(f"ID: {group_id}, Name: {group_info['name']}, Associated Groups: {group_info['associated_groups']}")
# Out:
# Total groups in updated mapping: 152
#
# Some example group mappings:
# ID: G1028, Name: APT-C-23, Associated Groups: Arid Viper, Big Bang APT, Desert Falcon, Grey Karkadann, Mantis, TAG-63, Two-tailed Scorpion
# ID: G0099, Name: APT-C-36, Associated Groups: Blind Eagle
# ID: G0006, Name: APT1, Associated Groups: Comment Crew, Comment Group, Comment Panda
# ID: G0005, Name: APT12, Associated Groups: DNSCALC, DynCalc, IXESHE, Numbered Panda
# ID: G0023, Name: APT16, Associated Groups: nan

# %%
import json

# Function to read the actors data from the JSON file
def read_actors_from_file(filename="actors_data.json"):
    try:
        with open(filename, "r") as json_file:
            actors_data = json.load(json_file)  # Load the JSON data from the file
            return actors_data
    except FileNotFoundError:
        print(f"File {filename} not found.")
        return None
    except json.JSONDecodeError:
        print("Error decoding the JSON data.")
        return None

# Call the function to read the actors from the JSON file
malpedia_actors_data = read_actors_from_file()

# %%
# Compare MITRE group names and synonyms with Malpedia actors
def find_intersection_with_malpedia_actors(malpedia_actors_data, mitre_group_mappings):
    intersection = []  # Store MITRE groups that intersect with Malpedia actors
    unique_group_ids = set()  # To store unique group IDs for intersection
    mitre_groups_not_in_malpedia = []  # Store MITRE groups not found in Malpedia

    # Loop through each MITRE group in mitre_group_mappings
    for group_id, group_info in mitre_group_mappings.items():
        group_name = group_info['name'].lower()  # Normalize to lowercase for comparison
        associated_groups = group_info.get('associated_groups', '')

        # Normalize associated_groups to lowercase and ensure it's a list for iteration
        if isinstance(associated_groups, float) or associated_groups is None:
            associated_groups = ''
        associated_groups = [ag.lower() for ag in associated_groups] if isinstance(associated_groups, list) else [associated_groups.lower()]

        found_match = False

        # Loop through each actor in Malpedia actors data
        for actor_id, actor_info in malpedia_actors_data.items():
            actor_name = actor_info['value'].lower()  # Normalize actor name to lowercase
            synonyms = [synonym.lower() for synonym in actor_info.get('meta', {}).get('synonyms', [])]  # Normalize synonyms

            # Check if group_name or associated_groups match with Malpedia actor name or synonyms
            if group_name == actor_name or group_name in synonyms:
                intersection.append((group_name, actor_name, group_id))  # Found intersection with group_name
                unique_group_ids.add(group_id)
                found_match = True
                break  # No need to check further if match is found
            elif any(ag == actor_name or ag in synonyms for ag in associated_groups):
                intersection.append((group_name, actor_name, group_id))  # Found intersection with associated group
                unique_group_ids.add(group_id)
                found_match = True
                break

        # If no match was found for this MITRE group, add it to the "not in Malpedia" list
        if not found_match:
            mitre_groups_not_in_malpedia.append((group_name, group_id))

    return intersection, unique_group_ids, mitre_groups_not_in_malpedia


# Load the MITRE group mappings (this should be the mappings created from the Excel files)
group_mappings_file_path = 'group_mapping_MITRE.json'  # Replace with actual path to group mappings
with open(group_mappings_file_path, 'r') as f:
    mitre_group_mappings = json.load(f)

# Find the intersection
intersection, unique_group_ids, mitre_groups_not_in_malpedia = find_intersection_with_malpedia_actors(actors_data, mitre_group_mappings)

# Print the intersection results
print(f"Total intersection based on unique group IDs: {len(unique_group_ids)}")
if intersection:
    print("\nIntersection found between MITRE groups and Malpedia actors:")
    for group_name, actor_name, group_id in intersection:
        print(f"MITRE Group: {group_name} | Malpedia Actor: {actor_name} | Group ID: {group_id}")
else:
    print("No intersection found between MITRE groups and Malpedia actors.")

# Print the MITRE groups not present in Malpedia
if mitre_groups_not_in_malpedia:
    print(f"\nTotal MITRE groups not present in Malpedia: {len(mitre_groups_not_in_malpedia)}")
    for group_name, group_id in mitre_groups_not_in_malpedia:
        print(f"MITRE Group: {group_name} | Group ID: {group_id}")
# Out:
# Total intersection based on unique group IDs: 137
#
# Intersection found between MITRE groups and Malpedia actors:
# MITRE Group: apt-c-23 | Malpedia Actor: aridviper | Group ID: G1028
# MITRE Group: apt-c-36 | Malpedia Actor: apt-c-36 | Group ID: G0099
# MITRE Group: apt1 | Malpedia Actor: apt1 | Group ID: G0006
# MITRE Group: apt12 | Malpedia Actor: apt12 | Group ID: G0005
# MITRE Group: apt16 | Malpedia Actor: apt16 | Group ID: G0023
# MITRE Group: apt17 | Malpedia Actor: apt17 | Group ID: G0025
# MITRE Group: apt18 | Malpedia Actor: apt18 | Group ID: G0026
# MITRE Group: apt19 | Malpedia Actor: apt19 | Group ID: G0073
# MITRE Group: apt28 | Malpedia Actor: apt28 | Group ID: G0007
# MITRE Group: apt29 | Malpedia Actor: apt29 | Group ID: G0016
# MITRE Group: apt3 | Malpedia Actor: apt3 | Group ID: G0022
# MITRE Group: apt30 | Malpedia Actor: apt30 | Group ID: G0013
# MITRE Group: apt32 | Malpedia Actor: apt32 | Group ID: G0050
# MITRE Group: apt33 | Malpedia Actor: apt33 | Group ID: G0064
# MITRE Group: apt37 | Malpedia Actor: apt37 | Group ID: G0067
# MITRE Group: apt38 | Malpedia Actor: lazarus group | Group ID: G0082
# MITRE Group: apt39 | Malpedia Actor: apt39 | Group ID: G0087
# MITRE Group: apt41 | Malpedia Actor: apt41 | Group ID: G0096
# MITRE Group: apt5 | Malpedia Actor: apt5 | Group ID: G1023
# MITRE Group: ajax security team | Malpedia Actor: flying kitten | Group ID: G0130
# MITRE Group: akira | Malpedia Actor: storm-1567 | Group ID: G1024
# MITRE Group: andariel | Malpedia Actor: lazarus group | Group ID: G0138
# MITRE Group: aoqin dragon | Malpedia Actor: aoqin dragon | Group ID: G1007
# MITRE Group: aquatic panda | Malpedia Actor: earth lusca | Group ID: G0143
# MITRE Group: axiom | Malpedia Actor: apt17 | Group ID: G0001
# MITRE Group: bitter | Malpedia Actor: hazy tiger | Group ID: G1002
# MITRE Group: bronze butler | Malpedia Actor: tick | Group ID: G0060
# MITRE Group: backdoordiplomacy | Malpedia Actor: backdoordiplomacy | Group ID: G0135
# MITRE Group: blackoasis | Malpedia Actor: blackoasis | Group ID: G0063
# MITRE Group: blacktech | Malpedia Actor: blacktech | Group ID: G0098
# MITRE Group: carbanak | Malpedia Actor: fin7 | Group ID: G0008
# MITRE Group: cinnamon tempest | Malpedia Actor: bronze starlight | Group ID: G1021
# MITRE Group: cleaver | Malpedia Actor: cleaver | Group ID: G0003
# MITRE Group: cobalt group | Malpedia Actor: cobalt | Group ID: G0080
# MITRE Group: copykittens | Malpedia Actor: copykittens | Group ID: G0052
# MITRE Group: dark caracal | Malpedia Actor: dark caracal | Group ID: G0070
# MITRE Group: darkhydrus | Malpedia Actor: darkhydrus | Group ID: G0079
# MITRE Group: darkvishnya | Malpedia Actor: darkvishnya | Group ID: G0105
# MITRE Group: darkhotel | Malpedia Actor: darkhotel | Group ID: G0012
# MITRE Group: deep panda | Malpedia Actor: apt19 | Group ID: G0009
# MITRE Group: dragonok | Malpedia Actor: dragonok | Group ID: G0017
# MITRE Group: dragonfly | Malpedia Actor: energetic bear | Group ID: G0035
# MITRE Group: exotic lily | Malpedia Actor: exotic lily | Group ID: G1011
# MITRE Group: earth lusca | Malpedia Actor: earth lusca | Group ID: G1006
# MITRE Group: elderwood | Malpedia Actor: beijing group | Group ID: G0066
# MITRE Group: ember bear | Malpedia Actor: saintbear | Group ID: G1003
# MITRE Group: evilnum | Malpedia Actor: evilnum | Group ID: G0120
# MITRE Group: fin10 | Malpedia Actor: fin10 | Group ID: G0051
# MITRE Group: fin13 | Malpedia Actor: fin13 | Group ID: G1016
# MITRE Group: fin4 | Malpedia Actor: wolf spider | Group ID: G0085
# MITRE Group: fin5 | Malpedia Actor: fin5 | Group ID: G0053
# MITRE Group: fin6 | Malpedia Actor: fin6 | Group ID: G0037
# MITRE Group: fin7 | Malpedia Actor: fin7 | Group ID: G0046
# MITRE Group: fin8 | Malpedia Actor: fin8 | Group ID: G0061
# MITRE Group: ferocious kitten | Malpedia Actor: ferocious kitten | Group ID: G0137
# MITRE Group: fox kitten | Malpedia Actor: fox kitten | Group ID: G0117
# MITRE Group: gallium | Malpedia Actor: gallium | Group ID: G0093
# MITRE Group: gcman | Malpedia Actor: gcman | Group ID: G0036
# MITRE Group: gold southfield | Malpedia Actor: gold southfield | Group ID: G0115
# MITRE Group: gallmaker | Malpedia Actor: gallmaker | Group ID: G0084
# MITRE Group: gamaredon group | Malpedia Actor: gamaredon group | Group ID: G0047
# MITRE Group: gorgon group | Malpedia Actor: the gorgon group | Group ID: G0078
# MITRE Group: group5 | Malpedia Actor: group5 | Group ID: G0043
# MITRE Group: hafnium | Malpedia Actor: hafnium | Group ID: G0125
# MITRE Group: hexane | Malpedia Actor: lyceum | Group ID: G1001
# MITRE Group: higaisa | Malpedia Actor: higaisa | Group ID: G0126
# MITRE Group: indigozebra | Malpedia Actor: indigozebra | Group ID: G0136
# MITRE Group: indrik spider | Malpedia Actor: indrik spider | Group ID: G0119
# MITRE Group: ke3chang | Malpedia Actor: apt15 | Group ID: G0004
# MITRE Group: kimsuky | Malpedia Actor: kimsuky | Group ID: G0094
# MITRE Group: lapsus$ | Malpedia Actor: lapsus | Group ID: G1004
# MITRE Group: lazarus group | Malpedia Actor: lazarus group | Group ID: G0032
# MITRE Group: leafminer | Malpedia Actor: raspite | Group ID: G0077
# MITRE Group: leviathan | Malpedia Actor: apt40 | Group ID: G0065
# MITRE Group: lotus blossom | Malpedia Actor: lotus panda | Group ID: G0030
# MITRE Group: luminousmoth | Malpedia Actor: mustang panda | Group ID: G1014
# MITRE Group: machete | Malpedia Actor: el machete | Group ID: G0095
# MITRE Group: magic hound | Malpedia Actor: apt35 | Group ID: G0059
# MITRE Group: malteiro | Malpedia Actor: malteiro | Group ID: G1026
# MITRE Group: metador | Malpedia Actor: metador | Group ID: G1013
# MITRE Group: moafee | Malpedia Actor: dragonok | Group ID: G0002
# MITRE Group: mofang | Malpedia Actor: mofang | Group ID: G0103
# MITRE Group: molerats | Malpedia Actor: molerats | Group ID: G0021
# MITRE Group: moses staff | Malpedia Actor: mosesstaff | Group ID: G1009
# MITRE Group: moustachedbouncer | Malpedia Actor: moustachedbouncer | Group ID: G1019
# MITRE Group: muddywater | Malpedia Actor: muddywater | Group ID: G0069
# MITRE Group: mustang panda | Malpedia Actor: mustang panda | Group ID: G0129
# MITRE Group: mustard tempest | Malpedia Actor: mustard tempest | Group ID: G1020
# MITRE Group: neodymium | Malpedia Actor: neodymium | Group ID: G0055
# MITRE Group: naikon | Malpedia Actor: naikon | Group ID: G0019
# MITRE Group: nomadic octopus | Malpedia Actor: dustsquad | Group ID: G0133
# MITRE Group: oilrig | Malpedia Actor: chrysene | Group ID: G0049
# MITRE Group: orangeworm | Malpedia Actor: orangeworm | Group ID: G0071
# MITRE Group: platinum | Malpedia Actor: platinum | Group ID: G0068
# MITRE Group: polonium | Malpedia Actor: polonium | Group ID: G1005
# MITRE Group: promethium | Malpedia Actor: promethium | Group ID: G0056
# MITRE Group: patchwork | Malpedia Actor: quilted tiger | Group ID: G0040
# MITRE Group: poseidon group | Malpedia Actor: poseidon group | Group ID: G0033
# MITRE Group: putter panda | Malpedia Actor: apt2 | Group ID: G0024
# MITRE Group: rtm | Malpedia Actor: rtm | Group ID: G0048
# MITRE Group: rancor | Malpedia Actor: rancor | Group ID: G0075
# MITRE Group: rocke | Malpedia Actor: rocke | Group ID: G0106
# MITRE Group: scarlet mimic | Malpedia Actor: scarlet mimic | Group ID: G0029
# MITRE Group: scattered spider | Malpedia Actor: scattered spider | Group ID: G1015
# MITRE Group: sidecopy | Malpedia Actor: sidecopy | Group ID: G1008
# MITRE Group: sidewinder | Malpedia Actor: razor tiger | Group ID: G0121
# MITRE Group: silence | Malpedia Actor: silence group | Group ID: G0091
# MITRE Group: silent librarian | Malpedia Actor: silent librarian | Group ID: G0122
# MITRE Group: silverterrier | Malpedia Actor: silverterrier | Group ID: G0083
# MITRE Group: sowbug | Malpedia Actor: sowbug | Group ID: G0054
# MITRE Group: stealth falcon | Malpedia Actor: stealth falcon | Group ID: G0038
# MITRE Group: strider | Malpedia Actor: projectsauron | Group ID: G0041
# MITRE Group: suckfly | Malpedia Actor: apt22 | Group ID: G0039
# MITRE Group: ta2541 | Malpedia Actor: ta2541 | Group ID: G1018
# MITRE Group: ta459 | Malpedia Actor: ta459 | Group ID: G0062
# MITRE Group: ta505 | Malpedia Actor: fin11 | Group ID: G0092
# MITRE Group: ta551 | Malpedia Actor: gold cabin | Group ID: G0127
# MITRE Group: temp.veles | Malpedia Actor: temp.veles | Group ID: G0088
# MITRE Group: teamtnt | Malpedia Actor: teamtnt | Group ID: G0139
# MITRE Group: thrip | Malpedia Actor: thrip | Group ID: G0076
# MITRE Group: toddycat | Malpedia Actor: toddycat | Group ID: G1022
# MITRE Group: tonto team | Malpedia Actor: tonto team | Group ID: G0131
# MITRE Group: transparent tribe | Malpedia Actor: operation c-major | Group ID: G0134
# MITRE Group: tropic trooper | Malpedia Actor: apt23 | Group ID: G0081
# MITRE Group: turla | Malpedia Actor: turla | Group ID: G0010
# MITRE Group: volatile cedar | Malpedia Actor: volatile cedar | Group ID: G0123
# MITRE Group: volt typhoon | Malpedia Actor: volt typhoon | Group ID: G1017
# MITRE Group: wirte | Malpedia Actor: wirte | Group ID: G0090
# MITRE Group: whitefly | Malpedia Actor: whitefly | Group ID: G0107
# MITRE Group: windshift | Malpedia Actor: bahamut | Group ID: G0112
# MITRE Group: winnti group | Malpedia Actor: apt41 | Group ID: G0044
# MITRE Group: wizard spider | Malpedia Actor: wizard spider | Group ID: G0102
# MITRE Group: zirconium | Malpedia Actor: apt31 | Group ID: G0128
# MITRE Group: admin@338 | Malpedia Actor: temper panda | Group ID: G0018
# MITRE Group: allanite | Malpedia Actor: allanite | Group ID: G1000
# MITRE Group: bouncing golf | Malpedia Actor: domestic kitten | Group ID: G0097
# MITRE Group: unc788 | Malpedia Actor: apt42 | Group ID: G1029
#
# Total MITRE groups not present in Malpedia: 15
# MITRE Group: blue mockingbird | Group ID: G0108
# MITRE Group: curium | Group ID: G1012
# MITRE Group: chimera | Group ID: G0114
# MITRE Group: confucius | Group ID: G0142
# MITRE Group: equation | Group ID: G0020
# MITRE Group: inception | Group ID: G0100
# MITRE Group: lazyscripter | Group ID: G0140
# MITRE Group: pittytiger | Group ID: G0011
# MITRE Group: sandworm team | Group ID: G0034
# MITRE Group: the white company | Group ID: G0089
# MITRE Group: threat group-1314 | Group ID: G0028
# MITRE Group: threat group-3390 | Group ID: G0027
# MITRE Group: windigo | Group ID: G0124
# MITRE Group: menupass | Group ID: G0045
# MITRE Group: cyberav3ngers | Group ID: G1027
